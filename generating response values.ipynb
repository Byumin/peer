# %% [markdown]
# 채점해볼 수 있는 페이크 데이터 생성

# %%
# 지명 데이터 생성
# 지명 문항은 PN1-PN19까지 총 19문항
# 지명 문항 데이터 불러오기
import pandas as pd
import requests
from io import BytesIO
url = "https://github.com/Byumin/peer/raw/refs/heads/item/item_info.xlsx"
response = requests.get(url)
response.raise_for_status()
df = pd.read_excel(BytesIO(response.content))
df
point_item = df[df['reporting']=='또래지명']
point_item
# Out:
#     Unnamed: 0      scale reporting    no                     item reverse
# 0            0     지각된 인기      또래지명   PN1                가장 인기가 있는       N
# 1            1     사회적 선호      또래지명   PN2              가장 같이 놀고 싶은       N
# 2            2     사회적 선호      또래지명   PN3              가장 같이 놀기 싫은       N
# 3            3    외현적 공격성      또래지명   PN4  문제를 일으키는/학교의 규칙을 지키지 않는       N
# 4            4    외현적 공격성      또래지명   PN5                   싸움을 하는       N
# 5            5    관계적 공격성      또래지명   PN6     험담을 하거나 다른 친구를 소외시키는       N
# 6            6    관계적 공격성      또래지명   PN7              나쁜 소문을 퍼뜨리는       N
# 7            7       친사회성      또래지명   PN8                      친절한       N
# 8            8       친사회성      또래지명   PN9                     협력적인       N
# 15          15  또래 괴롭힘 가해      또래지명  PN10        친구를 괴롭히는 행동을 시작하는       N
# 16          16  또래 괴롭힘 가해      또래지명  PN11     괴롭힘에 다른 사람을 참여하도록 하는       N
# ...

# %%
# 자기보고 문항 데이터 불러오기
self_item = df[df['reporting']=='자기보고(5점 리커트)']
self_item
# Out:
#      Unnamed: 0        scale     reporting    no                        item  \
# 9             9         인기추구  자기보고(5점 리커트)   SR1      나는 인기있는 아이와 친구가 되고 싶다.
# 10           10         인기추구  자기보고(5점 리커트)   SR2         나는 인기있는 무리에 속하고 싶다.
# 11           11         인기추구  자기보고(5점 리커트)   SR3          나는 인기있는 사람이 되고 싶다.
# 12           12       인기상실불안  자기보고(5점 리커트)   SR4  나는 인기없는 아이와는 친구가 되고 싶지 않다.
# 13           13       인기상실불안  자기보고(5점 리커트)   SR5      나는 인기없는 무리에 속하고 싶지 않다.
# ..          ...          ...           ...   ...                         ...
# 121         121  또래관계 교사 민감성  자기보고(5점 리커트)   TR6    이 아이는 친구를 괴롭히는 행동을 시작한다.
# 122         122  또래관계 교사 민감성  자기보고(5점 리커트)   TR7     이 아이는 친구들에게 자주 놀림을 당한다.
# 123         123  또래관계 교사 민감성  자기보고(5점 리커트)   TR8                 이 아이는 친절하다.
# 124         124  또래관계 교사 민감성  자기보고(5점 리커트)   TR9       이 아이는 학교에서 잘하려고 노력한다.
# 125         125  또래관계 교사 민감성  자기보고(5점 리커트)  TR10    이 아이는 수업 시간에 기분이 좋아 보인다.
#
#     reverse
# 9         N
# 10        N
# ...

# %%
# 20명의 학생의 19문항의 응답 데이터 생성
# 1대1 서로가 서로를 랜덤하게 지목한 데이터 생성
import numpy as np
import pandas as pd
import random

# 학생 수 및 문항 수 정의
num_students = 20
num_questions = len(point_item)

# 학생 이름 생성
students = [f"student{i+1}" for i in range(num_students)]

# 1대1 또래지명 데이터 생성_동일한 학생을 중복 지목하지 않음
point_df = pd.DataFrame()

for i in range(num_questions) :
    np.random.seed(i)
    #pairings = np.random.permutation(students)
    point_item_no = [f'PN{i+1}']*num_students
    student_designation = students.copy()
    
    #가중치 생성하기 위해 난수
    rand_values = [x for x in np.round(np.random.rand(len(students)),2)]
    weights = [x/sum(rand_values) for x in rand_values]
    print(weights)
    
    student_nomination = random.choices(students, weights=weights, k=num_students)
    #student_nomination = random.sample(students, num_students)
    temp_df = pd.DataFrame({'point_item_no' : point_item_no, 'student_designation' : student_designation, 'student_nomination' : student_nomination})
    point_df = pd.concat([point_df, temp_df], axis=0, ignore_index=True)
    
point_df
# Out:
# [0.047291487532244214, 0.06190885640584696, 0.05159071367153913, 0.04643164230438523, 0.036113499570077395, 0.055889939810834066, 0.03783319002579537, 0.07652622527944972, 0.08254514187446262, 0.032674118658641456, 0.06792777300085986, 0.04557179707652624, 0.04901117798796217, 0.07996560619088566, 0.0060189165950129, 0.00773860705073087, 0.0017196904557179712, 0.0713671539122958, 0.06706792777300088, 0.07480653482373174]
# [0.05698778833107192, 0.09769335142469472, 0.0, 0.0407055630936228, 0.0203527815468114, 0.01221166892808684, 0.02578018995929444, 0.04748982360922659, 0.0542740841248304, 0.07327001356852104, 0.05698778833107192, 0.09362279511533243, 0.0271370420624152, 0.11940298507462688, 0.00407055630936228, 0.09090909090909093, 0.05698778833107192, 0.07598371777476257, 0.01899592944369064, 0.0271370420624152]
# ...

# %%
# 제대로 나왔는지 확인
point_df.to_excel('point_df.xlsx', index=False)

# %%
# 자기보고 응답 데이터 생성
# 10명의 학생

num_students = 20
num_questions = len(self_item)

# 학생 이름 생성
students = [f"student{i+1}" for i in range(num_students)]

# 문항 응답 데이터 생성 (1~5점 랜덤 부여)
responses = np.random.randint(1, 6, size=(num_students, num_questions))
responses = pd.DataFrame(responses, columns=self_item['no'].to_list())

students_df = pd.DataFrame({'students' : students})
self_df = pd.concat([students_df, responses], axis=1, ignore_index=False)
self_df
# Out:
#      students  SR1  SR2  SR3  SR4  SR5  SR6  SR7  SR8  SR9  ...  TSR23  TR2  \
# 0    student1    2    3    3    3    4    4    3    5    4  ...      1    2
# 1    student2    4    4    2    4    3    3    1    4    3  ...      2    3
# 2    student3    4    2    3    5    3    1    1    5    3  ...      4    3
# 3    student4    4    4    1    2    3    5    3    1    5  ...      2    1
# 4    student5    3    5    3    5    1    4    2    1    4  ...      4    1
# 5    student6    2    4    2    3    5    4    5    5    4  ...      3    4
# 6    student7    5    4    2    1    2    2    1    2    3  ...      1    3
# 7    student8    4    1    3    5    2    5    5    2    3  ...      2    2
# 8    student9    1    5    1    5    4    3    2    3    2  ...      2    3
# 9   student10    4    1    2    3    1    3    3    4    1  ...      3    5
# 10  student11    1    3    4    4    4    5    3    2    2  ...      2    4
# ...

# %%
# 제대로 나왔는지 확인
self_df.to_excel('self_df.xlsx', index=False)
