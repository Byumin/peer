# %% [markdown]
# # 공격성 규범 점수

# %% [markdown]
# ## 평가내역에 따른 공격성 규범 산출

# %%
import sys
print(sys.executable)   # 예: C:\ProgramData\anaconda3\python.exe
print(sys.path)         # 패키지 탐색 경로(여기에 site-packages가 있어야 import 가능)
# Out:
# c:\ProgramData\anaconda3\python.exe
# ['c:\\ProgramData\\anaconda3\\python313.zip', 'c:\\ProgramData\\anaconda3\\DLLs', 'c:\\ProgramData\\anaconda3\\Lib', 'c:\\ProgramData\\anaconda3', '', 'C:\\Users\\USER\\AppData\\Roaming\\Python\\Python313\\site-packages', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\win32\\lib', 'c:\\ProgramData\\anaconda3\\Lib\\site-packages\\Pythonwin']

# %%
# SELECT * FROM "schoolfriends-kmj"."school_class" WHERE class_code = 'AD00012025115D1E4'
import awswrangler as wr
query_df = wr.athena.read_sql_query(
    """
    select *
    from school_class
    where class_code = 'AD00012025115D1E4'
    """
    , database="schoolfriends-kmj"
)

# %%
import awswrangler as wr
query_df = wr.athena.read_sql_query(
    """
    select a.school_code, a.school_name, b.school_grade, b.school_num, b.class_name, c.psy_name, c.psy_code, c.close_yn, f.student_num, d.target_code, e.user_testing_no, e.question_no, e.student_code 
    from school_info a
    inner join school_class b on a.school_code = b.school_code
    inner join psy_class c on b.class_code = c.class_code
    inner join psy_target_detail d on c.class_code = d.class_code and c.psy_code = d.psy_code
    inner join at_user_testing_paper_pn e on d.user_testing_no = e.user_testing_no
    inner join school_student f on d.target_code = f.student_code and d.class_code = f.class_code
    where c.close_yn = 'Y' and e.question_no in (4, 5, 6, 7, 12)
    """
    , database="schoolfriends-kmj"
)

# %%
query_df
# Out:
#       school_code school_name  school_grade  school_num class_name  \
# 0          AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 1          AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 2          AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 3          AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 4          AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# ...           ...         ...           ...         ...        ...
# 17980      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 17981      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 17982      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 17983      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 17984      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
#
#            psy_name       psy_code close_yn  student_num  \
# 0      "25년 7월 1회차"  P20250716BE86        Y         <NA>
# 1      "25년 7월 1회차"  P20250716BE86        Y         <NA>
# 2      "25년 7월 1회차"  P20250716BE86        Y         <NA>
# 3      "25년 7월 1회차"  P20250716BE86        Y         <NA>
# 4      "25년 7월 1회차"  P20250716BE86        Y         <NA>
# ...             ...            ...      ...          ...
# 17980  "25년 7월 1회차"  P20250722BAB6        Y         <NA>
# 17981  "25년 7월 1회차"  P20250722BAB6        Y         <NA>
# 17982  "25년 7월 1회차"  P20250722BAB6        Y         <NA>
# 17983  "25년 7월 1회차"  P20250722BAB6        Y         <NA>
# 17984  "25년 7월 1회차"  P20250722BAB6        Y         <NA>
#
#                 target_code         user_testing_no  question_no  \
# 0      AC000120256042D2E020  "557b6318ba464b62be79"            4
# 1      AC000120256042D2E020  "557b6318ba464b62be79"            5
# 2      AC000120256042D2E020  "557b6318ba464b62be79"            6
# 3      AC000120256042D2E020  "557b6318ba464b62be79"            6
# 4      AC000120256042D2E020  "557b6318ba464b62be79"            6
# ...                     ...                     ...          ...
# 17980  TC046120256076567001    eeaf384f0e31454cb6d0            5
# 17981  TC046120256076567001    eeaf384f0e31454cb6d0            5
# 17982  TC046120256076567001    eeaf384f0e31454cb6d0            6
# 17983  TC046120256076567001    eeaf384f0e31454cb6d0            7
# 17984  TC046120256076567001    eeaf384f0e31454cb6d0           12
#
#                student_code
# 0      AC000120256042D2E003
# 1      AC000120256042D2E003
# 2      AC000120256042D2E003
# 3      AC000120256042D2E009
# 4      AC000120256042D2E012
# ...                     ...
# 17980  TC046120256076567011
# 17981  TC046120256076567014
# 17982                    ""
# 17983                    ""
# 17984  TC046120256076567021
#
# [17985 rows x 13 columns]

# %%
query_df.columns
# Out:
# Index(['school_code', 'school_name', 'school_grade', 'school_num',
#        'class_name', 'psy_name', 'psy_code', 'close_yn', 'student_num',
#        'target_code', 'user_testing_no', 'question_no', 'student_code'],
#       dtype='object')

# %%
# 지명수 구하는 함수
def count_point(df, student_list, item_no) :
    import pandas as pd
    if df['psy_code'].nunique() > 1 :
        raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
    else :
        temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
        count_list = []
        for student in student_list :
            if len(temp_df[temp_df['student_code']==student]) >= 1 :
                freq = len(temp_df[temp_df['student_code']==student])
            elif len(temp_df[temp_df['student_code']==student]) == 0 :
                freq = 0
            count_list.append(freq)
        count_point_df = pd.DataFrame({'student_code': student_list, 'num_point': count_list})
        return count_point_df, df['psy_code'].iloc[0]

# 학생 리스트 구하는 함수
def student_list(df) :
    student_list = df['target_code'].unique().tolist()
    return student_list, df['psy_code'].iloc[0]

# %%
df = query_df[query_df['psy_name'].str.contains('25년 11월_1차')]
print(df)
# Out:
#      school_code school_name  school_grade  school_num class_name  \
# 5216      AD0001       학지중학교          <NA>        <NA>         ""
# 5217      AD0001       학지중학교          <NA>        <NA>         ""
# 5218      AD0001       학지중학교          <NA>        <NA>         ""
# 5219      AD0001       학지중학교          <NA>        <NA>         ""
# 5220      AD0001       학지중학교          <NA>        <NA>         ""
# ...          ...         ...           ...         ...        ...
# 5410      AD0001       학지중학교          <NA>        <NA>         ""
# 5411      AD0001       학지중학교          <NA>        <NA>         ""
# 5412      AD0001       학지중학교          <NA>        <NA>         ""
# 5413      AD0001       학지중학교          <NA>        <NA>         ""
# 5414      AD0001       학지중학교          <NA>        <NA>         ""
#
#           psy_name       psy_code close_yn  student_num           target_code  \
# 5216  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4020
# 5217  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4020
# 5218  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4020
# 5219  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4020
# 5220  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4020
# ...            ...            ...      ...          ...                   ...
# 5410  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4001
# 5411  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4001
# 5412  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4001
# 5413  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4001
# 5414  "25년 11월_1차"  P202511122059        Y         <NA>  AD00012025115D1E4001
#
#              user_testing_no  question_no          student_code
# 5216  "8916207158814a67abc2"            4  AD00012025115D1E4003
# 5217  "8916207158814a67abc2"            4  AD00012025115D1E4008
# 5218  "8916207158814a67abc2"            4  AD00012025115D1E4010
# 5219  "8916207158814a67abc2"            4  AD00012025115D1E4019
# 5220  "8916207158814a67abc2"            5  AD00012025115D1E4010
# ...                      ...          ...                   ...
# 5410  "5021a196f7c74c81a151"           12  AD00012025115D1E4007
# 5411  "5021a196f7c74c81a151"           12  AD00012025115D1E4009
# 5412  "5021a196f7c74c81a151"           12  AD00012025115D1E4010
# 5413  "5021a196f7c74c81a151"           12  AD00012025115D1E4012
# 5414  "5021a196f7c74c81a151"           12  AD00012025115D1E4013
#
# [199 rows x 13 columns]

# %%
#! 디버깅용으로 데이터 엑셀로 저장
import pandas as pd
df.to_excel(f'scoring_etl_check_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.xlsx', index=False)

# %%
student_list_obj, psy_code = student_list(df)
print(student_list_obj, psy_code)
print(len(student_list_obj))
# Out:
# ['AD00012025115D1E4020', 'AD00012025115D1E4019', 'AD00012025115D1E4018', 'AD00012025115D1E4017', 'AD00012025115D1E4016', 'AD00012025115D1E4015', 'AD00012025115D1E4014', 'AD00012025115D1E4013', 'AD00012025115D1E4012', 'AD00012025115D1E4011', 'AD00012025115D1E4010', 'AD00012025115D1E4009', 'AD00012025115D1E4008', 'AD00012025115D1E4007', 'AD00012025115D1E4006', 'AD00012025115D1E4005', 'AD00012025115D1E4004', 'AD00012025115D1E4003', 'AD00012025115D1E4002', 'AD00012025115D1E4001'] P202511122059
# 20

# %%
aggression_point_df, psy_code = count_point(df, student_list_obj, [6,7])
n14_point_df, psy_code = count_point(df, student_list_obj, [12])
print(aggression_point_df, psy_code)
print(n14_point_df, psy_code)
# Out:
#             student_code  num_point
# 0   AD00012025115D1E4020         15
# 1   AD00012025115D1E4019          1
# 2   AD00012025115D1E4018         18
# 3   AD00012025115D1E4017          2
# 4   AD00012025115D1E4016         13
# 5   AD00012025115D1E4015          2
# 6   AD00012025115D1E4014          0
# 7   AD00012025115D1E4013          0
# 8   AD00012025115D1E4012         13
# 9   AD00012025115D1E4011          0
# 10  AD00012025115D1E4010          0
# 11  AD00012025115D1E4009          0
# 12  AD00012025115D1E4008          0
# 13  AD00012025115D1E4007          3
# 14  AD00012025115D1E4006          1
# 15  AD00012025115D1E4005          0
# 16  AD00012025115D1E4004         13
# 17  AD00012025115D1E4003          0
# 18  AD00012025115D1E4002          0
# 19  AD00012025115D1E4001          0 P202511122059
#             student_code  num_point
# 0   AD00012025115D1E4020          2
# 1   AD00012025115D1E4019          0
# 2   AD00012025115D1E4018          4
# 3   AD00012025115D1E4017          0
# 4   AD00012025115D1E4016          8
# 5   AD00012025115D1E4015          0
# 6   AD00012025115D1E4014          0
# 7   AD00012025115D1E4013          4
# 8   AD00012025115D1E4012          7
# 9   AD00012025115D1E4011          0
# 10  AD00012025115D1E4010          3
# 11  AD00012025115D1E4009          6
# 12  AD00012025115D1E4008          0
# 13  AD00012025115D1E4007          2
# 14  AD00012025115D1E4006          3
# 15  AD00012025115D1E4005          0
# 16  AD00012025115D1E4004          2
# 17  AD00012025115D1E4003          0
# 18  AD00012025115D1E4002          0
# 19  AD00012025115D1E4001          1 P202511122059

# %%
def aggression_norms(df, celling_parameter=67) :
    import pandas as pd
    student_list_obj, psy_code = student_list(df)
    aggression_point_df, psy_code = count_point(df, student_list_obj, [6,7])
    n14_point_df, psy_code = count_point(df, student_list_obj, [12])

    aggression_norms_df = pd.merge(aggression_point_df, n14_point_df, on='student_code', suffixes=('_agg', '_12no'))
    aggression_norms_df['agg*12no_num_point'] = aggression_norms_df['num_point_agg'] * aggression_norms_df['num_point_12no']
    aggression_norms_df.sort_values(by='agg*12no_num_point', ascending=False, inplace=True)
    
    top5_aggression_norms_df = aggression_norms_df.head(5)
    top5_mean = top5_aggression_norms_df['agg*12no_num_point'].mean()
    total_mean = aggression_norms_df['agg*12no_num_point'].mean()
    weighted_mean = 0.4 * (top5_mean) + 0.6 * (total_mean)
    weighted_mean = 4 * ((min(max(weighted_mean, 0), celling_parameter)-0)/celling_parameter)+1
    result_df = pd.DataFrame({'psy_code': [psy_code], 'top5_mean': [top5_mean], 'total_mean': [total_mean], 'weighted_mean': [weighted_mean]})
    result_df['reg_date'] = pd.Timestamp.now()
    result_df['purpose'] = f'"purpose=calibration;celling_parameter={celling_parameter};author=Yumin"'
    return result_df

# %%
result_df = aggression_norms(df)
print(result_df)
# Out:
#         psy_code  top5_mean  total_mean  weighted_mean  \
# 0  P202511122059       64.6        16.6       3.137313
#
#                     reg_date  \
# 0 2025-11-14 17:41:47.075039
#
#                                              purpose
# 0  "purpose=calibration;celling_parameter=67;auth...

# %% [markdown]
# ## raw 쿼리 결과 -> 그룹별 채점 결과 변환

# %%
import awswrangler as wr
query_df = wr.athena.read_sql_query(
    """
    select a.school_code, a.school_name, b.school_grade, b.school_num, b.class_name, c.psy_name, c.psy_code, c.close_yn, f.student_num, d.target_code, e.user_testing_no, e.question_no, e.student_code 
    from school_info a
    inner join school_class b on a.school_code = b.school_code
    inner join psy_class c on b.class_code = c.class_code
    inner join psy_target d on c.class_code = d.class_code and c.psy_code = d.psy_code
    inner join at_user_testing_paper_pn e on d.user_testing_no = e.user_testing_no
    inner join school_student f on d.target_code = f.student_code and d.class_code = f.class_code
    where c.close_yn = 'Y' and e.question_no in (4,5,6,7,14)
    """
    , database="schoolfriends")

# %%
query_df
# Out:
#      school_code school_name school_grade school_num class_name      psy_name  \
# 0       PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 1       PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 2       PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 3       PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 4       PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# ...          ...         ...          ...        ...        ...           ...
# 8489    PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 8490    PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 8491    PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 8492    PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
# 8493    PERSONAL    PERSONAL          "6"        "1"    "6학년2반"  "25년 7월 1회차"
#
#            psy_code close_yn  student_num              target_code  \
# 0     P20250711FD39        Y         <NA>  M1000005520256019C95008
# 1     P20250711FD39        Y         <NA>  M1000005520256019C95008
# 2     P20250711FD39        Y         <NA>  M1000005520256019C95008
# 3     P20250711FD39        Y         <NA>  M1000005520256019C95008
# 4     P20250711FD39        Y         <NA>  M1000005520256019C95008
# ...             ...      ...          ...                      ...
# 8489  P20250711FD39        Y         <NA>  M1000005520256019C95008
# 8490  P20250711FD39        Y         <NA>  M1000005520256019C95008
# 8491  P20250711FD39        Y         <NA>  M1000005520256019C95008
# 8492  P20250711FD39        Y         <NA>  M1000005520256019C95008
# 8493  P20250711FD39        Y         <NA>  M1000005520256019C95008
#
#            user_testing_no  question_no             student_code
# 0     ec497b0eb6ae49368fe5            6  M1000005520256019C95007
# 1     ec497b0eb6ae49368fe5            6  M1000005520256019C95009
# 2     ec497b0eb6ae49368fe5            7  M1000005520256019C95004
# 3     ec497b0eb6ae49368fe5            7  M1000005520256019C95005
# 4     ec497b0eb6ae49368fe5            7  M1000005520256019C95010
# ...                    ...          ...                      ...
# 8489  ec497b0eb6ae49368fe5            4  M1000005520256019C95007
# 8490  ec497b0eb6ae49368fe5            4  M1000005520256019C95009
# 8491  ec497b0eb6ae49368fe5            5  M1000005520256019C95006
# 8492  ec497b0eb6ae49368fe5            5  M1000005520256019C95007
# 8493  ec497b0eb6ae49368fe5            6  M1000005520256019C95006
#
# [8494 rows x 13 columns]

# %%
import pandas as pd

psy_code_grouped = query_df.groupby('psy_code')
result_df = pd.DataFrame()
for psy_code, group in psy_code_grouped :
    result_df = pd.concat([result_df, aggression_norms(group)])

# %%
result_df
# Out:
#         psy_code   top5_mean  total_mean  weighted_mean  \
# 0  P202507041AFF   17.200000   17.200000       2.026866
# 0  P202507046A44    8.400000    8.400000       1.501493
# 0  P202507075FAD    3.500000    3.500000       1.208955
# 0  P202507086502    6.000000    6.000000       1.358209
# 0  P20250708740B   70.000000   36.200000       3.968358
# 0  P2025070965A7    2.000000    2.000000       1.119403
# 0  P202507098064    2.333333    2.333333       1.139303
# 0  P202507118C5B    2.000000    2.000000       1.119403
# 0  P20250711FD39   50.800000   27.800000       3.208955
# 0  P202507154E91  186.400000   59.782609       5.000000
# 0  P20250716280A    0.000000    0.000000       1.000000
# 0  P202507169BCD   45.600000   13.956522       2.588890
# 0  P20250716BB5E   54.200000   14.720000       2.821612
# 0  P20250716BE86    1.000000    0.250000       1.032836
# 0  P20250716CD70    0.000000    0.000000       1.000000
# 0  P202507183B0A   27.800000   11.571429       2.078380
# 0  P20250718B4BE   28.400000   11.363636       2.085265
# 0  P202507213ACA  114.800000   42.600000       5.000000
# 0  P202507217086   59.000000   20.956522       3.159637
# 0  P2025072176E5  103.000000   28.818182       4.491995
# 0  P20250721C339    0.000000    0.000000       1.000000
# 0  P2025072289FD   91.600000   27.434783       4.170201
# 0  P20250722BAB6   69.200000   31.687500       3.787612
# 0  P20250722D67F   95.400000   29.238095       4.325544
# 0  P2025072408CB   50.800000   18.952381       2.892026
# 0  P2025080762D7    0.000000    0.000000       1.000000
# 0  P202508119E7D    3.800000    3.800000       1.226866
# 0  P202509103074   24.000000    5.714286       1.777825
# 0  P20250915C976  131.000000   43.772727       5.000000
# 0  P20250919CEAA   86.000000   31.470588       4.181036
# 0  P2025092177FC  138.600000   34.964286       5.000000
# 0  P20250922AC9C   46.400000   12.791667       2.566269
# 0  P20250922E632   19.200000    7.700000       1.734328
# 0  P20250924E81F   99.000000   27.304348       4.342245
# 0  P202509256309   22.600000    8.666667       1.850149
# 0  P202509261CF3  262.400000   82.617647       5.000000
# 0  P202509265DB4   68.400000   23.090909       3.460570
# 0  P20250926990C   14.400000    5.333333       1.534925
# 0  P20250926E621   85.200000   29.440000       4.089194
# 0  P20250926F99B   12.200000    6.400000       1.520597
# 0  P202509297849   48.400000   18.391304       2.814614
# 0  P20250929B2C3  109.200000   32.285714       4.764264
#
#                     reg_date  \
# 0 2025-09-30 17:38:27.416093
# 0 2025-09-30 17:38:27.422828
# 0 2025-09-30 17:38:27.429166
# 0 2025-09-30 17:38:27.434944
# 0 2025-09-30 17:38:27.462677
# 0 2025-09-30 17:38:27.467758
# 0 2025-09-30 17:38:27.472969
# 0 2025-09-30 17:38:27.478356
# 0 2025-09-30 17:38:27.489476
# 0 2025-09-30 17:38:27.513235
# 0 2025-09-30 17:38:27.516281
# 0 2025-09-30 17:38:27.540153
# 0 2025-09-30 17:38:27.565428
# 0 2025-09-30 17:38:27.584051
# 0 2025-09-30 17:38:27.587003
# 0 2025-09-30 17:38:27.609205
# 0 2025-09-30 17:38:27.635969
# 0 2025-09-30 17:38:27.658118
# 0 2025-09-30 17:38:27.682451
# 0 2025-09-30 17:38:27.705039
# 0 2025-09-30 17:38:27.708146
# 0 2025-09-30 17:38:27.734116
# 0 2025-09-30 17:38:27.752782
# 0 2025-09-30 17:38:27.773663
# 0 2025-09-30 17:38:27.796808
# 0 2025-09-30 17:38:27.800294
# 0 2025-09-30 17:38:27.807209
# 0 2025-09-30 17:38:27.828820
# 0 2025-09-30 17:38:27.852630
# 0 2025-09-30 17:38:27.871704
# 0 2025-09-30 17:38:27.901081
# 0 2025-09-30 17:38:27.926908
# 0 2025-09-30 17:38:27.947844
# 0 2025-09-30 17:38:27.970755
# 0 2025-09-30 17:38:27.990086
# 0 2025-09-30 17:38:28.026582
# 0 2025-09-30 17:38:28.050723
# 0 2025-09-30 17:38:28.066817
# 0 2025-09-30 17:38:28.092984
# 0 2025-09-30 17:38:28.109293
# 0 2025-09-30 17:38:28.134204
# 0 2025-09-30 17:38:28.156313
#
#                                              purpose
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...
# 0  "purpose=calibration;celling_parameter=67;auth...

# %%
# 언제 등록하고 목적이 무엇인지 같이 기록
result_df['reg_date'] = pd.Timestamp.now()
result_df['purpose'] = '"purpose=calibration;celling_parameter=67;author=Yumin"'

# %%
# 결과를 S3에 저장
wr.s3.to_csv(result_df, f's3://schoolfriends-bym/result/aggression_norms/aggression_norms_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)
# Out:
# {'paths': ['s3://schoolfriends-bym/result/aggression_norms/aggression_norms_20250908_094510.csv'],
#  'partitions_values': {}}

# %%
# s3_folder_macro 소스에서 크롤러 생성해서 테이블화

# %% [markdown]
# ## celling_parameter range로 조정하여 탐색

# %%
def search_celling_aggression_norms(df, celling_parameter) :
    import pandas as pd
    student_list_obj, psy_code = student_list(df)
    aggression_point_df, psy_code = count_point(df, student_list_obj, [4,5,6,7])
    n14_point_df, psy_code = count_point(df, student_list_obj, [14])

    aggression_norms_df = pd.merge(aggression_point_df, n14_point_df, on='student_code', suffixes=('_agg', '_14no'))
    aggression_norms_df['agg*14no_num_point'] = aggression_norms_df['num_point_agg'] * aggression_norms_df['num_point_14no']
    aggression_norms_df.sort_values(by='agg*14no_num_point', ascending=False, inplace=True)
    
    top5_aggression_norms_df = aggression_norms_df.head(5)
    top5_mean = top5_aggression_norms_df['agg*14no_num_point'].mean()
    total_mean = aggression_norms_df['agg*14no_num_point'].mean()
    weighted_mean = 0.4 * (top5_mean) + 0.6 * (total_mean)
    weighted_mean_Normalization = 4 * ((min(max(weighted_mean, 0), celling_parameter)-0)/celling_parameter)+1
    result_df = pd.DataFrame({'psy_code': [psy_code], 'top5_mean': [top5_mean], 'total_mean': [total_mean], 'weighted_mean': [weighted_mean], 'weighted_mean_Normalization': [weighted_mean_Normalization]})
    result_df['reg_date'] = pd.Timestamp.now()
    result_df['purpose'] = f'"purpose=calibration;celling_parameter={celling_parameter};author=Yumin"'
    return result_df

# %%
import awswrangler as wr
query_df = wr.athena.read_sql_query(
    """
    select a.school_code, a.school_name, b.school_grade, b.school_num, b.class_name, c.psy_name, c.psy_code, c.close_yn, f.student_num, d.target_code, e.user_testing_no, e.question_no, e.student_code 
    from school_info a
    inner join school_class b on a.school_code = b.school_code
    inner join psy_class c on b.class_code = c.class_code
    inner join psy_target d on c.class_code = d.class_code and c.psy_code = d.psy_code
    inner join at_user_testing_paper_pn e on d.user_testing_no = e.user_testing_no
    inner join school_student f on d.target_code = f.student_code and d.class_code = f.class_code
    where c.close_yn = 'Y' and e.question_no in (4,5,6,7,14)
    """
    , database="schoolfriends")

# %%
query_df
# Out:
#      school_code school_name  school_grade  school_num class_name  \
# 0         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 1         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 2         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 3         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 4         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# ...          ...         ...           ...         ...        ...
# 8489      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8490      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8491      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8492      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8493      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
#
#           psy_name       psy_code close_yn  student_num           target_code  \
# 0     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 1     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 2     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 3     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 4     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# ...            ...            ...      ...          ...                   ...
# 8489  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8490  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8491  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8492  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8493  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
#
#              user_testing_no  question_no          student_code
# 0     "557b6318ba464b62be79"            4  AC000120256042D2E003
# 1     "557b6318ba464b62be79"            5  AC000120256042D2E003
# 2     "557b6318ba464b62be79"            6  AC000120256042D2E003
# 3     "557b6318ba464b62be79"            6  AC000120256042D2E009
# 4     "557b6318ba464b62be79"            6  AC000120256042D2E012
# ...                      ...          ...                   ...
# 8489    eeaf384f0e31454cb6d0            6                    ""
# 8490    eeaf384f0e31454cb6d0            7                    ""
# 8491    eeaf384f0e31454cb6d0           14  TC046120256076567012
# 8492    eeaf384f0e31454cb6d0           14  TC046120256076567021
# 8493    eeaf384f0e31454cb6d0           14  TC046120256076567022
#
# [8494 rows x 13 columns]

# %%
import pandas as pd

psy_code_grouped = query_df.groupby('psy_code')
result_df = pd.DataFrame()
for parameter in range(30, 100) :
    print(f'celling_parameter: {parameter}')
    for psy_code, group in psy_code_grouped :
        result_df = pd.concat([result_df, search_celling_aggression_norms(group, celling_parameter=parameter)])
# Out:
# celling_parameter: 30
# celling_parameter: 31
# celling_parameter: 32
# celling_parameter: 33
# celling_parameter: 34
# celling_parameter: 35
# celling_parameter: 36
# celling_parameter: 37
# celling_parameter: 38
# celling_parameter: 39
# celling_parameter: 40
# celling_parameter: 41
# celling_parameter: 42
# celling_parameter: 43
# celling_parameter: 44
# celling_parameter: 45
# celling_parameter: 46
# celling_parameter: 47
# celling_parameter: 48
# celling_parameter: 49
# celling_parameter: 50
# celling_parameter: 51
# celling_parameter: 52
# celling_parameter: 53
# celling_parameter: 54
# celling_parameter: 55
# celling_parameter: 56
# celling_parameter: 57
# celling_parameter: 58
# celling_parameter: 59
# celling_parameter: 60
# celling_parameter: 61
# celling_parameter: 62
# celling_parameter: 63
# celling_parameter: 64
# celling_parameter: 65
# celling_parameter: 66
# celling_parameter: 67
# celling_parameter: 68
# celling_parameter: 69
# celling_parameter: 70
# celling_parameter: 71
# celling_parameter: 72
# celling_parameter: 73
# celling_parameter: 74
# celling_parameter: 75
# celling_parameter: 76
# celling_parameter: 77
# celling_parameter: 78
# celling_parameter: 79
# celling_parameter: 80
# celling_parameter: 81
# celling_parameter: 82
# celling_parameter: 83
# celling_parameter: 84
# celling_parameter: 85
# celling_parameter: 86
# celling_parameter: 87
# celling_parameter: 88
# celling_parameter: 89
# celling_parameter: 90
# celling_parameter: 91
# celling_parameter: 92
# celling_parameter: 93
# celling_parameter: 94
# celling_parameter: 95
# celling_parameter: 96
# celling_parameter: 97
# celling_parameter: 98
# celling_parameter: 99

# %%
print(result_df)
# Out:
#          psy_code  top5_mean  total_mean  weighted_mean  \
# 0   P202507041AFF       17.2   17.200000      17.200000
# 0   P202507046A44        8.4    8.400000       8.400000
# 0   P202507075FAD        3.5    3.500000       3.500000
# 0   P202507086502        6.0    6.000000       6.000000
# 0   P20250708740B       70.0   36.200000      49.720000
# ..            ...        ...         ...            ...
# 0   P20250926990C       14.4    5.333333       8.960000
# 0   P20250926E621       85.2   29.440000      51.744000
# 0   P20250926F99B       12.2    6.400000       8.720000
# 0   P202509297849       48.4   18.391304      30.394783
# 0   P20250929B2C3      109.2   32.285714      63.051429
#
#     weighted_mean_Normalization                   reg_date  \
# 0                      3.293333 2025-10-01 14:10:18.242565
# 0                      2.120000 2025-10-01 14:10:18.249522
# 0                      1.466667 2025-10-01 14:10:18.256045
# 0                      1.800000 2025-10-01 14:10:18.262170
# 0                      5.000000 2025-10-01 14:10:18.288931
# ..                          ...                        ...
# 0                      1.362020 2025-10-01 14:11:11.286226
# 0                      3.090667 2025-10-01 14:11:11.313571
# 0                      1.352323 2025-10-01 14:11:11.330214
# 0                      2.228072 2025-10-01 14:11:11.354144
# 0                      3.547532 2025-10-01 14:11:11.376712
#
#                                               purpose
# 0   "purpose=calibration;celling_parameter=30;auth...
# 0   "purpose=calibration;celling_parameter=30;auth...
# 0   "purpose=calibration;celling_parameter=30;auth...
# 0   "purpose=calibration;celling_parameter=30;auth...
# 0   "purpose=calibration;celling_parameter=30;auth...
# ..                                                ...
# 0   "purpose=calibration;celling_parameter=99;auth...
# 0   "purpose=calibration;celling_parameter=99;auth...
# 0   "purpose=calibration;celling_parameter=99;auth...
# 0   "purpose=calibration;celling_parameter=99;auth...
# 0   "purpose=calibration;celling_parameter=99;auth...
#
# [2940 rows x 7 columns]

# %%
# s3에 업로드
wr.s3.to_csv(result_df, f's3://schoolfriends-bym/result/aggression_norms/aggression_norms_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)
# Out:
# {'paths': ['s3://schoolfriends-bym/result/aggression_norms/aggression_norms_20251001_141111.csv'],
#  'partitions_values': {}}

# %% [markdown]
# ## 평가마다 학생의 공격 지명 * 친구 지명

# %%
# 지명수 구하는 함수
def count_point(df, student_list, item_no) :
    import pandas as pd
    if df['psy_code'].nunique() > 1 :
        raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
    else :
        temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
        count_list = []
        for student in student_list :
            if len(temp_df[temp_df['student_code']==student]) >= 1 :
                freq = len(temp_df[temp_df['student_code']==student])
            elif len(temp_df[temp_df['student_code']==student]) == 0 :
                freq = 0
            count_list.append(freq)
        count_point_df = pd.DataFrame({'student_code': student_list, 'num_point': count_list})
        return count_point_df, df['psy_code'].iloc[0]
    
# 학생 리스트 구하는 함수
def student_list(df) :
    student_list = df['target_code'].unique().tolist()
    return student_list, df['psy_code'].iloc[0]

# %%
query_df
# Out:
#      school_code school_name  school_grade  school_num class_name  \
# 0         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 1         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 2         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 3         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 4         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# ...          ...         ...           ...         ...        ...
# 8489      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8490      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8491      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8492      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 8493      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
#
#           psy_name       psy_code close_yn  student_num           target_code  \
# 0     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 1     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 2     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 3     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 4     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# ...            ...            ...      ...          ...                   ...
# 8489  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8490  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8491  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8492  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 8493  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
#
#              user_testing_no  question_no          student_code
# 0     "557b6318ba464b62be79"            4  AC000120256042D2E003
# 1     "557b6318ba464b62be79"            5  AC000120256042D2E003
# 2     "557b6318ba464b62be79"            6  AC000120256042D2E003
# 3     "557b6318ba464b62be79"            6  AC000120256042D2E009
# 4     "557b6318ba464b62be79"            6  AC000120256042D2E012
# ...                      ...          ...                   ...
# 8489    eeaf384f0e31454cb6d0            6                    ""
# 8490    eeaf384f0e31454cb6d0            7                    ""
# 8491    eeaf384f0e31454cb6d0           14  TC046120256076567012
# 8492    eeaf384f0e31454cb6d0           14  TC046120256076567021
# 8493    eeaf384f0e31454cb6d0           14  TC046120256076567022
#
# [8494 rows x 13 columns]

# %%
import pandas as pd

psy_code_grouped = query_df.groupby('psy_code')
result_df = pd.DataFrame()
for psy_code, group in psy_code_grouped :
    student_list_obj, psy_code = student_list(group)
    aggression_point_df, psy_code = count_point(group, student_list_obj, [4,5,6,7])
    n14_point_df, psy_code = count_point(group, student_list_obj, [14])
    merged_df = pd.merge(aggression_point_df, n14_point_df, on='student_code', suffixes=('_agg', '_14no'))
    merged_df['agg*14no_num_point'] = merged_df['num_point_agg'] * merged_df['num_point_14no']
    merged_df['psy_code'] = psy_code
    print(merged_df)
    result_df = pd.concat([result_df, merged_df])
# Out:
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000000120253017C9D005             10               2                  20
# 1  M1000000120253017C9D004             12               4                  48
# 2  M1000000120253017C9D003              5               3                  15
# 3  M1000000120253017C9D002              5               0                   0
# 4  M1000000120253017C9D001              3               1                   3
#
#         psy_code
# 0  P202507041AFF
# 1  P202507041AFF
# 2  P202507041AFF
# 3  P202507041AFF
# 4  P202507041AFF
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000000120253017C9D005              7               2                  14
# 1  M1000000120253017C9D004              7               2                  14
# 2  M1000000120253017C9D003              7               2                  14
# 3  M1000000120253017C9D002              8               0                   0
# 4  M1000000120253017C9D001              5               0                   0
#
#         psy_code
# 0  P202507046A44
# 1  P202507046A44
# 2  P202507046A44
# 3  P202507046A44
# 4  P202507046A44
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000000120253017C9D004              5               1                   5
# 1  M1000000120253017C9D003              4               2                   8
# 2  M1000000120253017C9D002              1               1                   1
# 3  M1000000120253017C9D001              3               0                   0
#
#         psy_code
# 0  P202507075FAD
# 1  P202507075FAD
# 2  P202507075FAD
# 3  P202507075FAD
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000000120253017C9D007              9               2                  18
# 1  M1000000120253017C9D005              6               1                   6
# 2  M1000000120253017C9D002              1               0                   0
# 3  M1000000120253017C9D001              0               0                   0
#
#         psy_code
# 0  P202507086502
# 1  P202507086502
# 2  P202507086502
# 3  P202507086502
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120256016589025              9               4                  36
# 1   AC000120256016589024             12               2                  24
# 2   AC000120256016589023             19               5                  95
# 3   AC000120256016589022             10               6                  60
# 4   AC000120256016589021             10               2                  20
# 5   AC000120256016589020             13               3                  39
# 6   AC000120256016589019             10               3                  30
# 7   AC000120256016589018             12               1                  12
# 8   AC000120256016589017              9               1                   9
# 9   AC000120256016589016             15               5                  75
# 10  AC000120256016589015             11               3                  33
# 11  AC000120256016589014             14               4                  56
# 12  AC000120256016589013             12               3                  36
# 13  AC000120256016589012             10               5                  50
# 14  AC000120256016589011             10               1                  10
# 15  AC000120256016589010             17               3                  51
# 16  AC000120256016589009             12               3                  36
# 17  AC000120256016589008             16               4                  64
# 18  AC000120256016589007             11               1                  11
# 19  AC000120256016589006              8               0                   0
# 20  AC000120256016589005             12               3                  36
# 21  AC000120256016589004              8               7                  56
# 22  AC000120256016589003             10               2                  20
# 23  AC000120256016589002              9               4                  36
# 24  AC000120256016589001             10               1                  10
#
#          psy_code
# 0   P20250708740B
# 1   P20250708740B
# 2   P20250708740B
# 3   P20250708740B
# 4   P20250708740B
# 5   P20250708740B
# 6   P20250708740B
# 7   P20250708740B
# 8   P20250708740B
# 9   P20250708740B
# 10  P20250708740B
# 11  P20250708740B
# 12  P20250708740B
# 13  P20250708740B
# 14  P20250708740B
# 15  P20250708740B
# 16  P20250708740B
# 17  P20250708740B
# 18  P20250708740B
# 19  P20250708740B
# 20  P20250708740B
# 21  P20250708740B
# 22  P20250708740B
# 23  P20250708740B
# 24  P20250708740B
#            student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  AC0001202530101AF011              0               0                   0
# 1  AC0001202530101AF002              1               0                   0
# 2  AC0001202530101AF001              3               2                   6
#
#         psy_code
# 0  P2025070965A7
# 1  P2025070965A7
# 2  P2025070965A7
#            student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  AC0001202530101AF011              1               1                   1
# 1  AC0001202530101AF002              3               1                   3
# 2  AC0001202530101AF001              3               1                   3
#
#         psy_code
# 0  P202507098064
# 1  P202507098064
# 2  P202507098064
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000005520256019C95003              2               1                   2
# 1  M1000005520256019C95002              4               1                   4
# 2  M1000005520256019C95001              1               0                   0
#
#         psy_code
# 0  P202507118C5B
# 1  P202507118C5B
# 2  P202507118C5B
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000005520256019C95010             16               7                 112
# 1  M1000005520256019C95009             16               3                  48
# 2  M1000005520256019C95008             11               4                  44
# 3  M1000005520256019C95007              7               0                   0
# 4  M1000005520256019C95006              8               1                   8
# 5  M1000005520256019C95005              4               1                   4
# 6  M1000005520256019C95004              6               2                  12
# 7  M1000005520256019C95003             12               3                  36
# 8  M1000005520256019C95002              7               2                  14
# 9  M1000005520256019C95001              2               0                   0
#
#         psy_code
# 0  P20250711FD39
# 1  P20250711FD39
# 2  P20250711FD39
# 3  P20250711FD39
# 4  P20250711FD39
# 5  P20250711FD39
# 6  P20250711FD39
# 7  P20250711FD39
# 8  P20250711FD39
# 9  P20250711FD39
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000006320255020B29024              1               5
# 1   M1000006320255020B29023             22              12
# 2   M1000006320255020B29022              1              13
# 3   M1000006320255020B29021              1               8
# 4   M1000006320255020B29020             10              11
# 5   M1000006320255020B29019              5               3
# 6   M1000006320255020B29018             15              10
# 7   M1000006320255020B29016             16              11
# 8   M1000006320255020B29015              0              10
# 9   M1000006320255020B29014              1              10
# 10  M1000006320255020B29013              2               9
# 11  M1000006320255020B29012              6               6
# 12  M1000006320255020B29011              0               8
# 13  M1000006320255020B29010              1               9
# 14  M1000006320255020B29009             11               7
# 15  M1000006320255020B29008              8               7
# 16  M1000006320255020B29007              4               9
# 17  M1000006320255020B29006              3               6
# 18  M1000006320255020B29005              1               9
# 19  M1000006320255020B29004             14              13
# 20  M1000006320255020B29003             20               8
# 21  M1000006320255020B29002              0               5
# 22  M1000006320255020B29001             23               1
#
#     agg*14no_num_point       psy_code
# 0                    5  P202507154E91
# 1                  264  P202507154E91
# 2                   13  P202507154E91
# 3                    8  P202507154E91
# 4                  110  P202507154E91
# 5                   15  P202507154E91
# 6                  150  P202507154E91
# 7                  176  P202507154E91
# 8                    0  P202507154E91
# 9                   10  P202507154E91
# 10                  18  P202507154E91
# 11                  36  P202507154E91
# 12                   0  P202507154E91
# 13                   9  P202507154E91
# 14                  77  P202507154E91
# 15                  56  P202507154E91
# 16                  36  P202507154E91
# 17                  18  P202507154E91
# 18                   9  P202507154E91
# 19                 182  P202507154E91
# 20                 160  P202507154E91
# 21                   0  P202507154E91
# 22                  23  P202507154E91
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000000120253017C9D001              0               0                   0
#
#         psy_code
# 0  P20250716280A
#                student_code  num_point_agg  num_point_14no  \
# 0   M100000732025501D3CA023              0               5
# 1   M100000732025501D3CA022              4               6
# 2   M100000732025501D3CA021              2              12
# 3   M100000732025501D3CA020              0               5
# 4   M100000732025501D3CA019              2               6
# 5   M100000732025501D3CA018              0               8
# 6   M100000732025501D3CA017              3               7
# 7   M100000732025501D3CA016              0               6
# 8   M100000732025501D3CA015              0               9
# 9   M100000732025501D3CA014              2              11
# 10  M100000732025501D3CA013              0              10
# 11  M100000732025501D3CA012              0               7
# 12  M100000732025501D3CA011              7               9
# 13  M100000732025501D3CA010              0              12
# 14  M100000732025501D3CA009              0              10
# 15  M100000732025501D3CA008             23               4
# 16  M100000732025501D3CA007              0               7
# 17  M100000732025501D3CA006              1               5
# 18  M100000732025501D3CA005              2               7
# 19  M100000732025501D3CA004              0               1
# 20  M100000732025501D3CA003              5               5
# 21  M100000732025501D3CA002              0               2
# 22  M100000732025501D3CA001             19               1
#
#     agg*14no_num_point       psy_code
# 0                    0  P202507169BCD
# 1                   24  P202507169BCD
# 2                   24  P202507169BCD
# 3                    0  P202507169BCD
# 4                   12  P202507169BCD
# 5                    0  P202507169BCD
# 6                   21  P202507169BCD
# 7                    0  P202507169BCD
# 8                    0  P202507169BCD
# 9                   22  P202507169BCD
# 10                   0  P202507169BCD
# 11                   0  P202507169BCD
# 12                  63  P202507169BCD
# 13                   0  P202507169BCD
# 14                   0  P202507169BCD
# 15                  92  P202507169BCD
# 16                   0  P202507169BCD
# 17                   5  P202507169BCD
# 18                  14  P202507169BCD
# 19                   0  P202507169BCD
# 20                  25  P202507169BCD
# 21                   0  P202507169BCD
# 22                  19  P202507169BCD
#                student_code  num_point_agg  num_point_14no  \
# 0   M100000682025602CF1C025              1               7
# 1   M100000682025602CF1C024              1               4
# 2   M100000682025602CF1C023              0               8
# 3   M100000682025602CF1C022              1               7
# 4   M100000682025602CF1C021             23               2
# 5   M100000682025602CF1C020              1               3
# 6   M100000682025602CF1C019              3               9
# 7   M100000682025602CF1C018              3               6
# 8   M100000682025602CF1C017              1               9
# 9   M100000682025602CF1C016              1              11
# 10  M100000682025602CF1C015              1               7
# 11  M100000682025602CF1C014              0              10
# 12  M100000682025602CF1C013              0               5
# 13  M100000682025602CF1C012              2               7
# 14  M100000682025602CF1C011              0               6
# 15  M100000682025602CF1C010              9               5
# 16  M100000682025602CF1C009              9               0
# 17  M100000682025602CF1C008              1               5
# 18  M100000682025602CF1C007             27               5
# 19  M100000682025602CF1C006              0              11
# 20  M100000682025602CF1C005              1               9
# 21  M100000682025602CF1C004              0               7
# 22  M100000682025602CF1C003              0               8
# 23  M100000682025602CF1C002              2               5
# 24  M100000682025602CF1C001              1              11
#
#     agg*14no_num_point       psy_code
# 0                    7  P20250716BB5E
# 1                    4  P20250716BB5E
# 2                    0  P20250716BB5E
# 3                    7  P20250716BB5E
# 4                   46  P20250716BB5E
# 5                    3  P20250716BB5E
# 6                   27  P20250716BB5E
# 7                   18  P20250716BB5E
# 8                    9  P20250716BB5E
# 9                   11  P20250716BB5E
# 10                   7  P20250716BB5E
# 11                   0  P20250716BB5E
# 12                   0  P20250716BB5E
# 13                  14  P20250716BB5E
# 14                   0  P20250716BB5E
# 15                  45  P20250716BB5E
# 16                   0  P20250716BB5E
# 17                   5  P20250716BB5E
# 18                 135  P20250716BB5E
# 19                   0  P20250716BB5E
# 20                   9  P20250716BB5E
# 21                   0  P20250716BB5E
# 22                   0  P20250716BB5E
# 23                  10  P20250716BB5E
# 24                  11  P20250716BB5E
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120256042D2E020              0               1                   0
# 1   AC000120256042D2E019              0               0                   0
# 2   AC000120256042D2E018              1               0                   0
# 3   AC000120256042D2E017              0               0                   0
# 4   AC000120256042D2E016              0               0                   0
# 5   AC000120256042D2E015              1               5                   5
# 6   AC000120256042D2E014              0               3                   0
# 7   AC000120256042D2E013              0               0                   0
# 8   AC000120256042D2E012             28               0                   0
# 9   AC000120256042D2E011              0               0                   0
# 10  AC000120256042D2E010              0               0                   0
# 11  AC000120256042D2E009             27               0                   0
# 12  AC000120256042D2E008              0               0                   0
# 13  AC000120256042D2E007              0               0                   0
# 14  AC000120256042D2E006              1               0                   0
# 15  AC000120256042D2E005              0               4                   0
# 16  AC000120256042D2E004              0               7                   0
# 17  AC000120256042D2E003             57               0                   0
# 18  AC000120256042D2E002              0               0                   0
# 19  AC000120256042D2E001              0              11                   0
#
#          psy_code
# 0   P20250716BE86
# 1   P20250716BE86
# 2   P20250716BE86
# 3   P20250716BE86
# 4   P20250716BE86
# 5   P20250716BE86
# 6   P20250716BE86
# 7   P20250716BE86
# 8   P20250716BE86
# 9   P20250716BE86
# 10  P20250716BE86
# 11  P20250716BE86
# 12  P20250716BE86
# 13  P20250716BE86
# 14  P20250716BE86
# 15  P20250716BE86
# 16  P20250716BE86
# 17  P20250716BE86
# 18  P20250716BE86
# 19  P20250716BE86
#            student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  AC000120256016589001              0               0                   0
#
#         psy_code
# 0  P20250716CD70
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120255019FA1022              4               1                   4
# 1   AC000120255019FA1021              8               1                   8
# 2   AC000120255019FA1020              4               1                   4
# 3   AC000120255019FA1019              8               0                   0
# 4   AC000120255019FA1018              9               1                   9
# 5   AC000120255019FA1017              9               3                  27
# 6   AC000120255019FA1016              2               2                   4
# 7   AC000120255019FA1014              8               3                  24
# 8   AC000120255019FA1013              4               0                   0
# 9   AC000120255019FA1012              9               3                  27
# 10  AC000120255019FA1011              7               4                  28
# 11  AC000120255019FA1010              3               2                   6
# 12  AC000120255019FA1009              3               1                   3
# 13  AC000120255019FA1008              7               3                  21
# 14  AC000120255019FA1007              5               1                   5
# 15  AC000120255019FA1006             10               0                   0
# 16  AC000120255019FA1005              9               2                  18
# 17  AC000120255019FA1004              1               2                   2
# 18  AC000120255019FA1003              7               2                  14
# 19  AC000120255019FA1002              3               2                   6
# 20  AC000120255019FA1001             11               3                  33
#
#          psy_code
# 0   P202507183B0A
# 1   P202507183B0A
# 2   P202507183B0A
# 3   P202507183B0A
# 4   P202507183B0A
# 5   P202507183B0A
# 6   P202507183B0A
# 7   P202507183B0A
# 8   P202507183B0A
# 9   P202507183B0A
# 10  P202507183B0A
# 11  P202507183B0A
# 12  P202507183B0A
# 13  P202507183B0A
# 14  P202507183B0A
# 15  P202507183B0A
# 16  P202507183B0A
# 17  P202507183B0A
# 18  P202507183B0A
# 19  P202507183B0A
# 20  P202507183B0A
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120255019FA1022              4               1                   4
# 1   AC000120255019FA1021              8               1                   8
# 2   AC000120255019FA1020              5               1                   5
# 3   AC000120255019FA1019              9               0                   0
# 4   AC000120255019FA1018              9               1                   9
# 5   AC000120255019FA1017             10               3                  30
# 6   AC000120255019FA1016              2               2                   4
# 7   AC000120255019FA1015              8               0                   0
# 8   AC000120255019FA1014              8               3                  24
# 9   AC000120255019FA1013              4               0                   0
# 10  AC000120255019FA1012              9               3                  27
# 11  AC000120255019FA1011              7               4                  28
# 12  AC000120255019FA1010              4               2                   8
# 13  AC000120255019FA1009              4               1                   4
# 14  AC000120255019FA1008              7               3                  21
# 15  AC000120255019FA1007              5               1                   5
# 16  AC000120255019FA1006             11               0                   0
# 17  AC000120255019FA1005              9               2                  18
# 18  AC000120255019FA1004              1               2                   2
# 19  AC000120255019FA1003              7               2                  14
# 20  AC000120255019FA1002              3               2                   6
# 21  AC000120255019FA1001             11               3                  33
#
#          psy_code
# 0   P20250718B4BE
# 1   P20250718B4BE
# 2   P20250718B4BE
# 3   P20250718B4BE
# 4   P20250718B4BE
# 5   P20250718B4BE
# 6   P20250718B4BE
# 7   P20250718B4BE
# 8   P20250718B4BE
# 9   P20250718B4BE
# 10  P20250718B4BE
# 11  P20250718B4BE
# 12  P20250718B4BE
# 13  P20250718B4BE
# 14  P20250718B4BE
# 15  P20250718B4BE
# 16  P20250718B4BE
# 17  P20250718B4BE
# 18  P20250718B4BE
# 19  P20250718B4BE
# 20  P20250718B4BE
# 21  P20250718B4BE
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000008720256056A20022              0               5
# 1   M1000008720256056A20021              0               3
# 2   M1000008720256056A20020              3               6
# 3   M1000008720256056A20019              0               4
# 4   M1000008720256056A20018             10               6
# 5   M1000008720256056A20017              2               4
# 6   M1000008720256056A20016              2               9
# 7   M1000008720256056A20015              7               9
# 8   M1000008720256056A20014             32               7
# 9   M1000008720256056A20013              1               7
# 10  M1000008720256056A20012              2               4
# 11  M1000008720256056A20011              8               2
# 12  M1000008720256056A20009              9               7
# 13  M1000008720256056A20008              1               0
# 14  M1000008720256056A20006              8               5
# 15  M1000008720256056A20005             18               7
# 16  M1000008720256056A20004              7               9
# 17  M1000008720256056A20003             14               7
# 18  M1000008720256056A20002              4               5
# 19  M1000008720256056A20001              5               4
#
#     agg*14no_num_point       psy_code
# 0                    0  P202507213ACA
# 1                    0  P202507213ACA
# 2                   18  P202507213ACA
# 3                    0  P202507213ACA
# 4                   60  P202507213ACA
# 5                    8  P202507213ACA
# 6                   18  P202507213ACA
# 7                   63  P202507213ACA
# 8                  224  P202507213ACA
# 9                    7  P202507213ACA
# 10                   8  P202507213ACA
# 11                  16  P202507213ACA
# 12                  63  P202507213ACA
# 13                   0  P202507213ACA
# 14                  40  P202507213ACA
# 15                 126  P202507213ACA
# 16                  63  P202507213ACA
# 17                  98  P202507213ACA
# 18                  20  P202507213ACA
# 19                  20  P202507213ACA
#                student_code  num_point_agg  num_point_14no  \
# 0   M10000086202560261A9023              0               2
# 1   M10000086202560261A9022              1               4
# 2   M10000086202560261A9021             31               3
# 3   M10000086202560261A9020              2               8
# 4   M10000086202560261A9019              1               8
# 5   M10000086202560261A9018              3               4
# 6   M10000086202560261A9017              1               8
# 7   M10000086202560261A9016             23               2
# 8   M10000086202560261A9015              1               5
# 9   M10000086202560261A9014              1               7
# 10  M10000086202560261A9013              3               5
# 11  M10000086202560261A9012              3               5
# 12  M10000086202560261A9011              3               5
# 13  M10000086202560261A9010              3               5
# 14  M10000086202560261A9009              2               5
# 15  M10000086202560261A9008              7              10
# 16  M10000086202560261A9007              2               6
# 17  M10000086202560261A9006              3               5
# 18  M10000086202560261A9005             11               4
# 19  M10000086202560261A9004              6               7
# 20  M10000086202560261A9003              2               6
# 21  M10000086202560261A9002              1               6
# 22  M10000086202560261A9001              2               6
#
#     agg*14no_num_point       psy_code
# 0                    0  P202507217086
# 1                    4  P202507217086
# 2                   93  P202507217086
# 3                   16  P202507217086
# 4                    8  P202507217086
# 5                   12  P202507217086
# 6                    8  P202507217086
# 7                   46  P202507217086
# 8                    5  P202507217086
# 9                    7  P202507217086
# 10                  15  P202507217086
# 11                  15  P202507217086
# 12                  15  P202507217086
# 13                  15  P202507217086
# 14                  10  P202507217086
# 15                  70  P202507217086
# 16                  12  P202507217086
# 17                  15  P202507217086
# 18                  44  P202507217086
# 19                  42  P202507217086
# 20                  12  P202507217086
# 21                   6  P202507217086
# 22                  12  P202507217086
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000008820256034F56022              0               0
# 1   M1000008820256034F56021              0               3
# 2   M1000008820256034F56020              0               2
# 3   M1000008820256034F56019              1               7
# 4   M1000008820256034F56018              1               8
# 5   M1000008820256034F56017              6               7
# 6   M1000008820256034F56016              2               4
# 7   M1000008820256034F56015              7               7
# 8   M1000008820256034F56014              1               2
# 9   M1000008820256034F56013             20               5
# 10  M1000008820256034F56012              1               4
# 11  M1000008820256034F56011             19               7
# 12  M1000008820256034F56010              0               3
# 13  M1000008820256034F56009             23               8
# 14  M1000008820256034F56008              1               4
# 15  M1000008820256034F56007              1               2
# 16  M1000008820256034F56006              1               6
# 17  M1000008820256034F56005              4               6
# 18  M1000008820256034F56004              1               5
# 19  M1000008820256034F56003              7               7
# 20  M1000008820256034F56002              1               5
# 21  M1000008820256034F56001              1               2
#
#     agg*14no_num_point       psy_code
# 0                    0  P2025072176E5
# 1                    0  P2025072176E5
# 2                    0  P2025072176E5
# 3                    7  P2025072176E5
# 4                    8  P2025072176E5
# 5                   42  P2025072176E5
# 6                    8  P2025072176E5
# 7                   49  P2025072176E5
# 8                    2  P2025072176E5
# 9                  100  P2025072176E5
# 10                   4  P2025072176E5
# 11                 133  P2025072176E5
# 12                   0  P2025072176E5
# 13                 184  P2025072176E5
# 14                   4  P2025072176E5
# 15                   2  P2025072176E5
# 16                   6  P2025072176E5
# 17                  24  P2025072176E5
# 18                   5  P2025072176E5
# 19                  49  P2025072176E5
# 20                   5  P2025072176E5
# 21                   2  P2025072176E5
#               student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  M1000008720256056A20010              0               0                   0
#
#         psy_code
# 0  P20250721C339
#                student_code  num_point_agg  num_point_14no  \
# 0   M10000092202530442E7023              0               5
# 1   M10000092202530442E7022              8               2
# 2   M10000092202530442E7021              3               7
# 3   M10000092202530442E7020              1               7
# 4   M10000092202530442E7019              1               9
# 5   M10000092202530442E7018              1               7
# 6   M10000092202530442E7017             29               5
# 7   M10000092202530442E7016              2               4
# 8   M10000092202530442E7015              3               7
# 9   M10000092202530442E7014              1               6
# 10  M10000092202530442E7013              2               8
# 11  M10000092202530442E7012              0               6
# 12  M10000092202530442E7011              4               4
# 13  M10000092202530442E7010              2               7
# 14  M10000092202530442E7009              0               4
# 15  M10000092202530442E7008             14               5
# 16  M10000092202530442E7007              2               6
# 17  M10000092202530442E7006              1               6
# 18  M10000092202530442E7005              0               4
# 19  M10000092202530442E7004              2               7
# 20  M10000092202530442E7003             50               3
# 21  M10000092202530442E7002             24               3
# 22  M10000092202530442E7001              3               7
#
#     agg*14no_num_point       psy_code
# 0                    0  P2025072289FD
# 1                   16  P2025072289FD
# 2                   21  P2025072289FD
# 3                    7  P2025072289FD
# 4                    9  P2025072289FD
# 5                    7  P2025072289FD
# 6                  145  P2025072289FD
# 7                    8  P2025072289FD
# 8                   21  P2025072289FD
# 9                    6  P2025072289FD
# 10                  16  P2025072289FD
# 11                   0  P2025072289FD
# 12                  16  P2025072289FD
# 13                  14  P2025072289FD
# 14                   0  P2025072289FD
# 15                  70  P2025072289FD
# 16                  12  P2025072289FD
# 17                   6  P2025072289FD
# 18                   0  P2025072289FD
# 19                  14  P2025072289FD
# 20                 150  P2025072289FD
# 21                  72  P2025072289FD
# 22                  21  P2025072289FD
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   TC046120256076567022             11               4                  44
# 1   TC046120256076567021              5               3                  15
# 2   TC046120256076567020              1               8                   8
# 3   TC046120256076567019              1               8                   8
# 4   TC046120256076567018              4               7                  28
# 5   TC046120256076567015              3               6                  18
# 6   TC046120256076567014             13               7                  91
# 7   TC046120256076567012              4               4                  16
# 8   TC046120256076567011             11               6                  66
# 9   TC046120256076567010              2               8                  16
# 10  TC046120256076567009             14               5                  70
# 11  TC046120256076567008              0               8                   0
# 12  TC046120256076567006              2               2                   4
# 13  TC046120256076567004             15               5                  75
# 14  TC046120256076567003              4               8                  32
# 15  TC046120256076567001              4               4                  16
#
#          psy_code
# 0   P20250722BAB6
# 1   P20250722BAB6
# 2   P20250722BAB6
# 3   P20250722BAB6
# 4   P20250722BAB6
# 5   P20250722BAB6
# 6   P20250722BAB6
# 7   P20250722BAB6
# 8   P20250722BAB6
# 9   P20250722BAB6
# 10  P20250722BAB6
# 11  P20250722BAB6
# 12  P20250722BAB6
# 13  P20250722BAB6
# 14  P20250722BAB6
# 15  P20250722BAB6
#                student_code  num_point_agg  num_point_14no  \
# 0   M100000902025602F30D022              0               6
# 1   M100000902025602F30D021              3               7
# 2   M100000902025602F30D020              6               6
# 3   M100000902025602F30D019             10               6
# 4   M100000902025602F30D018              0               5
# 5   M100000902025602F30D017              0               2
# 6   M100000902025602F30D016              4               4
# 7   M100000902025602F30D015             37               5
# 8   M100000902025602F30D014              0               5
# 9   M100000902025602F30D013              0               5
# 10  M100000902025602F30D012              4               6
# 11  M100000902025602F30D011             25               4
# 12  M100000902025602F30D010              0               4
# 13  M100000902025602F30D009              0               8
# 14  M100000902025602F30D008              0               6
# 15  M100000902025602F30D007              0               6
# 16  M100000902025602F30D006              3               8
# 17  M100000902025602F30D004              4               4
# 18  M100000902025602F30D003             21               2
# 19  M100000902025602F30D002              0               7
# 20  M100000902025602F30D001             15               6
#
#     agg*14no_num_point       psy_code
# 0                    0  P20250722D67F
# 1                   21  P20250722D67F
# 2                   36  P20250722D67F
# 3                   60  P20250722D67F
# 4                    0  P20250722D67F
# 5                    0  P20250722D67F
# 6                   16  P20250722D67F
# 7                  185  P20250722D67F
# 8                    0  P20250722D67F
# 9                    0  P20250722D67F
# 10                  24  P20250722D67F
# 11                 100  P20250722D67F
# 12                   0  P20250722D67F
# 13                   0  P20250722D67F
# 14                   0  P20250722D67F
# 15                   0  P20250722D67F
# 16                  24  P20250722D67F
# 17                  16  P20250722D67F
# 18                  42  P20250722D67F
# 19                   0  P20250722D67F
# 20                  90  P20250722D67F
#                student_code  num_point_agg  num_point_14no  \
# 0   M100000932025602D4F3022              6               2
# 1   M100000932025602D4F3021              7               7
# 2   M100000932025602D4F3020              1               9
# 3   M100000932025602D4F3019              3               6
# 4   M100000932025602D4F3018              2              10
# 5   M100000932025602D4F3017              2               4
# 6   M100000932025602D4F3016              2               4
# 7   M100000932025602D4F3015              1               8
# 8   M100000932025602D4F3014              2               9
# 9   M100000932025602D4F3013              6               7
# 10  M100000932025602D4F3012              2               5
# 11  M100000932025602D4F3011              0               1
# 12  M100000932025602D4F3010              0               5
# 13  M100000932025602D4F3009              2               6
# 14  M100000932025602D4F3008              8              10
# 15  M100000932025602D4F3007              0               6
# 16  M100000932025602D4F3006              1               9
# 17  M100000932025602D4F3005              1               5
# 18  M100000932025602D4F3004              9               7
# 19  M100000932025602D4F3002              3               5
# 20  M100000932025602D4F3001              3               4
#
#     agg*14no_num_point       psy_code
# 0                   12  P2025072408CB
# 1                   49  P2025072408CB
# 2                    9  P2025072408CB
# 3                   18  P2025072408CB
# 4                   20  P2025072408CB
# 5                    8  P2025072408CB
# 6                    8  P2025072408CB
# 7                    8  P2025072408CB
# 8                   18  P2025072408CB
# 9                   42  P2025072408CB
# 10                  10  P2025072408CB
# 11                   0  P2025072408CB
# 12                   0  P2025072408CB
# 13                  12  P2025072408CB
# 14                  80  P2025072408CB
# 15                   0  P2025072408CB
# 16                   9  P2025072408CB
# 17                   5  P2025072408CB
# 18                  63  P2025072408CB
# 19                  15  P2025072408CB
# 20                  12  P2025072408CB
#            student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  AC0001202530101AF011              0               0                   0
#
#         psy_code
# 0  P2025080762D7
#            student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0  AC0001202530101AF011              6               2                  12
# 1  AC0001202530101AF004              5               1                   5
# 2  AC0001202530101AF003              2               1                   2
# 3  AC0001202530101AF002              2               0                   0
# 4  AC0001202530101AF001              1               0                   0
#
#         psy_code
# 0  P202508119E7D
# 1  P202508119E7D
# 2  P202508119E7D
# 3  P202508119E7D
# 4  P202508119E7D
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   DC017620255014BE0022              0               3                   0
# 1   DC017620255014BE0021              0               5                   0
# 2   DC017620255014BE0020              0               7                   0
# 3   DC017620255014BE0019              0               6                   0
# 4   DC017620255014BE0018              0               8                   0
# 5   DC017620255014BE0017              0               5                   0
# 6   DC017620255014BE0016              0               7                   0
# 7   DC017620255014BE0014              0               5                   0
# 8   DC017620255014BE0013              0               8                   0
# 9   DC017620255014BE0012              0               3                   0
# 10  DC017620255014BE0011              0               3                   0
# 11  DC017620255014BE0010              0               6                   0
# 12  DC017620255014BE0009             36               1                  36
# 13  DC017620255014BE0008              0               5                   0
# 14  DC017620255014BE0007             12               5                  60
# 15  DC017620255014BE0006              0               4                   0
# 16  DC017620255014BE0005              0               7                   0
# 17  DC017620255014BE0004              0               6                   0
# 18  DC017620255014BE0003              0               8                   0
# 19  DC017620255014BE0002              0               8                   0
# 20  DC017620255014BE0001              4               6                  24
#
#          psy_code
# 0   P202509103074
# 1   P202509103074
# 2   P202509103074
# 3   P202509103074
# 4   P202509103074
# 5   P202509103074
# 6   P202509103074
# 7   P202509103074
# 8   P202509103074
# 9   P202509103074
# 10  P202509103074
# 11  P202509103074
# 12  P202509103074
# 13  P202509103074
# 14  P202509103074
# 15  P202509103074
# 16  P202509103074
# 17  P202509103074
# 18  P202509103074
# 19  P202509103074
# 20  P202509103074
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000006320255020B29024              0               5
# 1   M1000006320255020B29023             12              12
# 2   M1000006320255020B29021              2              10
# 3   M1000006320255020B29020             11              12
# 4   M1000006320255020B29019              5               5
# 5   M1000006320255020B29018             10              13
# 6   M1000006320255020B29017              2               9
# 7   M1000006320255020B29016             12              11
# 8   M1000006320255020B29015              1              11
# 9   M1000006320255020B29014              0              10
# 10  M1000006320255020B29013              0               8
# 11  M1000006320255020B29012              1               7
# 12  M1000006320255020B29011              1              10
# 13  M1000006320255020B29010              2               8
# 14  M1000006320255020B29009              7               9
# 15  M1000006320255020B29008              4               7
# 16  M1000006320255020B29007              3               9
# 17  M1000006320255020B29006              0               8
# 18  M1000006320255020B29005              3               9
# 19  M1000006320255020B29004              9              13
# 20  M1000006320255020B29002              0              10
# 21  M1000006320255020B29001             14               4
#
#     agg*14no_num_point       psy_code
# 0                    0  P20250915C976
# 1                  144  P20250915C976
# 2                   20  P20250915C976
# 3                  132  P20250915C976
# 4                   25  P20250915C976
# 5                  130  P20250915C976
# 6                   18  P20250915C976
# 7                  132  P20250915C976
# 8                   11  P20250915C976
# 9                    0  P20250915C976
# 10                   0  P20250915C976
# 11                   7  P20250915C976
# 12                  10  P20250915C976
# 13                  16  P20250915C976
# 14                  63  P20250915C976
# 15                  28  P20250915C976
# 16                  27  P20250915C976
# 17                   0  P20250915C976
# 18                  27  P20250915C976
# 19                 117  P20250915C976
# 20                   0  P20250915C976
# 21                  56  P20250915C976
#                student_code  num_point_agg  num_point_14no  \
# 0   M10000184202550292B8038              3               9
# 1   M10000184202550292B8037             39               6
# 2   M10000184202550292B8036              3               7
# 3   M10000184202550292B8035              2               7
# 4   M10000184202550292B8034              0              10
# 5   M10000184202550292B8033              7               9
# 6   M10000184202550292B8032              3               6
# 7   M10000184202550292B8031              1               8
# 8   M10000184202550292B8010             21               4
# 9   M10000184202550292B8009              0               8
# 10  M10000184202550292B8008              0               7
# 11  M10000184202550292B8007              8               1
# 12  M10000184202550292B8006             11               2
# 13  M10000184202550292B8005              1               6
# 14  M10000184202550292B8003              2               7
# 15  M10000184202550292B8002              2               8
# 16  M10000184202550292B8001              0               6
#
#     agg*14no_num_point       psy_code
# 0                   27  P20250919CEAA
# 1                  234  P20250919CEAA
# 2                   21  P20250919CEAA
# 3                   14  P20250919CEAA
# 4                    0  P20250919CEAA
# 5                   63  P20250919CEAA
# 6                   18  P20250919CEAA
# 7                    8  P20250919CEAA
# 8                   84  P20250919CEAA
# 9                    0  P20250919CEAA
# 10                   0  P20250919CEAA
# 11                   8  P20250919CEAA
# 12                  22  P20250919CEAA
# 13                   6  P20250919CEAA
# 14                  14  P20250919CEAA
# 15                  16  P20250919CEAA
# 16                   0  P20250919CEAA
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000018820256011403029              2               6
# 1   M1000018820256011403028              2              10
# 2   M1000018820256011403027              0               6
# 3   M1000018820256011403026              0               7
# 4   M1000018820256011403025              1               3
# 5   M1000018820256011403024              1               5
# 6   M1000018820256011403023              2               8
# 7   M1000018820256011403022             20               5
# 8   M1000018820256011403021              2               4
# 9   M1000018820256011403020              2               4
# 10  M1000018820256011403019              2               7
# 11  M1000018820256011403018             27               4
# 12  M1000018820256011403016              2               6
# 13  M1000018820256011403015             14               7
# 14  M1000018820256011403014              2               4
# 15  M1000018820256011403013              1               9
# 16  M1000018820256011403012             45               7
# 17  M1000018820256011403011              3               7
# 18  M1000018820256011403010              2               4
# 19  M1000018820256011403009              2               7
# 20  M1000018820256011403008              3               5
# 21  M1000018820256011403007              2               4
# 22  M1000018820256011403006              8               9
# 23  M1000018820256011403005              3               6
# 24  M1000018820256011403004              2               8
# 25  M1000018820256011403003              9               5
# 26  M1000018820256011403002              2               8
# 27  M1000018820256011403001              2               5
#
#     agg*14no_num_point       psy_code
# 0                   12  P2025092177FC
# 1                   20  P2025092177FC
# 2                    0  P2025092177FC
# 3                    0  P2025092177FC
# 4                    3  P2025092177FC
# 5                    5  P2025092177FC
# 6                   16  P2025092177FC
# 7                  100  P2025092177FC
# 8                    8  P2025092177FC
# 9                    8  P2025092177FC
# 10                  14  P2025092177FC
# 11                 108  P2025092177FC
# 12                  12  P2025092177FC
# 13                  98  P2025092177FC
# 14                   8  P2025092177FC
# 15                   9  P2025092177FC
# 16                 315  P2025092177FC
# 17                  21  P2025092177FC
# 18                   8  P2025092177FC
# 19                  14  P2025092177FC
# 20                  15  P2025092177FC
# 21                   8  P2025092177FC
# 22                  72  P2025092177FC
# 23                  18  P2025092177FC
# 24                  16  P2025092177FC
# 25                  45  P2025092177FC
# 26                  16  P2025092177FC
# 27                  10  P2025092177FC
#                student_code  num_point_agg  num_point_14no  \
# 0   M100001912025403D5C9025              0               6
# 1   M100001912025403D5C9024              1               6
# 2   M100001912025403D5C9023              2               6
# 3   M100001912025403D5C9022              6               6
# 4   M100001912025403D5C9021              0               6
# 5   M100001912025403D5C9020              0               5
# 6   M100001912025403D5C9019              2               4
# 7   M100001912025403D5C9018             38               1
# ...
# 4   M100002172025505A996030              7              10
# 5   M100002172025505A996029             27               8
# 6   M100002172025505A996028              3               4
# 7   M100002172025505A996027              6              10
# 8   M100002172025505A996026             14               9
# 9   M100002172025505A996025             13               9
# 10  M100002172025505A996024             16               9
# 11  M100002172025505A996023              3              12
# 12  M100002172025505A996022              1               4
# 13  M100002172025505A996021             11               1
# 14  M100002172025505A996020             24              13
# 15  M100002172025505A996019              2              10
# 16  M100002172025505A996018              2               9
# 17  M100002172025505A996017             17              10
# 18  M100002172025505A996016             22              14
# 19  M100002172025505A996015              5               8
# 20  M100002172025505A996014              0               6
# 21  M100002172025505A996013              3              10
# 22  M100002172025505A996012              1               7
# 23  M100002172025505A996011              4              14
# 24  M100002172025505A996010              6               5
# 25  M100002172025505A996009              2               6
# 26  M100002172025505A996008              7              10
# 27  M100002172025505A996007              5              11
# 28  M100002172025505A996006             11               9
# 29  M100002172025505A996005             10               6
# 30  M100002172025505A996004             34               9
# 31  M100002172025505A996003              3               4
# 32  M100002172025505A996002              3               7
# 33  M100002172025505A996001             29               5
#
#     agg*14no_num_point       psy_code
# 0                   70  P202509261CF3
# 1                  143  P202509261CF3
# 2                   20  P202509261CF3
# 3                    9  P202509261CF3
# 4                   70  P202509261CF3
# 5                  216  P202509261CF3
# 6                   12  P202509261CF3
# 7                   60  P202509261CF3
# 8                  126  P202509261CF3
# 9                  117  P202509261CF3
# 10                 144  P202509261CF3
# 11                  36  P202509261CF3
# 12                   4  P202509261CF3
# 13                  11  P202509261CF3
# 14                 312  P202509261CF3
# 15                  20  P202509261CF3
# 16                  18  P202509261CF3
# 17                 170  P202509261CF3
# 18                 308  P202509261CF3
# 19                  40  P202509261CF3
# 20                   0  P202509261CF3
# 21                  30  P202509261CF3
# 22                   7  P202509261CF3
# 23                  56  P202509261CF3
# 24                  30  P202509261CF3
# 25                  12  P202509261CF3
# 26                  70  P202509261CF3
# 27                  55  P202509261CF3
# 28                  99  P202509261CF3
# 29                  60  P202509261CF3
# 30                 306  P202509261CF3
# 31                  12  P202509261CF3
# 32                  21  P202509261CF3
# 33                 145  P202509261CF3
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000021520254044918022              7               9
# 1   M1000021520254044918021              0               4
# 2   M1000021520254044918020              1               8
# 3   M1000021520254044918019              6              11
# 4   M1000021520254044918018              0               5
# 5   M1000021520254044918017              1               7
# 6   M1000021520254044918016              1               6
# 7   M1000021520254044918015              5              10
# 8   M1000021520254044918014              1               6
# 9   M1000021520254044918013             12               9
# 10  M1000021520254044918012              1               6
# 11  M1000021520254044918011              5              10
# 12  M1000021520254044918010              5              11
# 13  M1000021520254044918009              0               4
# 14  M1000021520254044918008              0               7
# 15  M1000021520254044918007              7               1
# 16  M1000021520254044918006              4               2
# 17  M1000021520254044918005              0               5
# 18  M1000021520254044918004              6               7
# 19  M1000021520254044918003              3               6
# 20  M1000021520254044918002              0               7
# 21  M1000021520254044918001              1               8
#
#     agg*14no_num_point       psy_code
# 0                   63  P202509265DB4
# 1                    0  P202509265DB4
# 2                    8  P202509265DB4
# 3                   66  P202509265DB4
# 4                    0  P202509265DB4
# 5                    7  P202509265DB4
# 6                    6  P202509265DB4
# 7                   50  P202509265DB4
# 8                    6  P202509265DB4
# 9                  108  P202509265DB4
# 10                   6  P202509265DB4
# 11                  50  P202509265DB4
# 12                  55  P202509265DB4
# 13                   0  P202509265DB4
# 14                   0  P202509265DB4
# 15                   7  P202509265DB4
# 16                   8  P202509265DB4
# 17                   0  P202509265DB4
# 18                  42  P202509265DB4
# 19                  18  P202509265DB4
# 20                   0  P202509265DB4
# 21                   8  P202509265DB4
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120254041DD8015              1               3                   3
# 1   AC000120254041DD8014              8               3                  24
# 2   AC000120254041DD8013              3               1                   3
# 3   AC000120254041DD8012              1               1                   1
# 4   AC000120254041DD8011              5               2                  10
# 5   AC000120254041DD8010              0               2                   0
# 6   AC000120254041DD8009              9               3                  27
# 7   AC000120254041DD8008              8               0                   0
# 8   AC000120254041DD8007              1               0                   0
# 9   AC000120254041DD8006              8               1                   8
# 10  AC000120254041DD8005              2               1                   2
# 11  AC000120254041DD8004              2               0                   0
# 12  AC000120254041DD8003              4               0                   0
# 13  AC000120254041DD8002              3               0                   0
# 14  AC000120254041DD8001              2               1                   2
#
#          psy_code
# 0   P20250926990C
# 1   P20250926990C
# 2   P20250926990C
# 3   P20250926990C
# 4   P20250926990C
# 5   P20250926990C
# 6   P20250926990C
# 7   P20250926990C
# 8   P20250926990C
# 9   P20250926990C
# 10  P20250926990C
# 11  P20250926990C
# 12  P20250926990C
# 13  P20250926990C
# 14  P20250926990C
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC035020255040D0F065              8               4                  32
# 1   AC035020255040D0F064              4               5                  20
# 2   AC035020255040D0F063             19               5                  95
# 3   AC035020255040D0F060             39               1                  39
# 4   AC035020255040D0F059              9               2                  18
# 5   AC035020255040D0F058              4               5                  20
# 6   AC035020255040D0F057              8               6                  48
# 7   AC035020255040D0F056             12               1                  12
# 8   AC035020255040D0F055              6               7                  42
# 9   AC035020255040D0F054             14               2                  28
# 10  AC035020255040D0F053             13               3                  39
# 11  AC035020255040D0F052             28               0                   0
# 12  AC035020255040D0F051             20               7                 140
# 13  AC035020255040D0F014              0               7                   0
# 14  AC035020255040D0F013              1               7                   7
# 15  AC035020255040D0F012              0               4                   0
# 16  AC035020255040D0F011              8               6                  48
# 17  AC035020255040D0F010              0               7                   0
# 18  AC035020255040D0F009              1               7                   7
# 19  AC035020255040D0F008              3               5                  15
# 20  AC035020255040D0F007              1               5                   5
# 21  AC035020255040D0F005              4               5                  20
# 22  AC035020255040D0F004              0               2                   0
# 23  AC035020255040D0F003              1               6                   6
# 24  AC035020255040D0F002             19               5                  95
#
#          psy_code
# 0   P20250926E621
# 1   P20250926E621
# 2   P20250926E621
# 3   P20250926E621
# 4   P20250926E621
# 5   P20250926E621
# 6   P20250926E621
# 7   P20250926E621
# 8   P20250926E621
# 9   P20250926E621
# 10  P20250926E621
# 11  P20250926E621
# 12  P20250926E621
# 13  P20250926E621
# 14  P20250926E621
# 15  P20250926E621
# 16  P20250926E621
# 17  P20250926E621
# 18  P20250926E621
# 19  P20250926E621
# 20  P20250926E621
# 21  P20250926E621
# 22  P20250926E621
# 23  P20250926E621
# 24  P20250926E621
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   AC000120254041DD8015              4               3                  12
# 1   AC000120254041DD8014              1               1                   1
# 2   AC000120254041DD8013              4               0                   0
# 3   AC000120254041DD8012              4               1                   4
# 4   AC000120254041DD8011              3               3                   9
# 5   AC000120254041DD8010              7               2                  14
# 6   AC000120254041DD8009              6               2                  12
# 7   AC000120254041DD8008              3               1                   3
# 8   AC000120254041DD8007              7               2                  14
# 9   AC000120254041DD8006              3               2                   6
# 10  AC000120254041DD8005              8               1                   8
# 11  AC000120254041DD8004              4               0                   0
# 12  AC000120254041DD8003              5               1                   5
# 13  AC000120254041DD8002              3               2                   6
# 14  AC000120254041DD8001              2               1                   2
#
#          psy_code
# 0   P20250926F99B
# 1   P20250926F99B
# 2   P20250926F99B
# 3   P20250926F99B
# 4   P20250926F99B
# 5   P20250926F99B
# 6   P20250926F99B
# 7   P20250926F99B
# 8   P20250926F99B
# 9   P20250926F99B
# 10  P20250926F99B
# 11  P20250926F99B
# 12  P20250926F99B
# 13  P20250926F99B
# 14  P20250926F99B
#                student_code  num_point_agg  num_point_14no  \
# 0   M10000227202560311ED023              2               5
# 1   M10000227202560311ED022              4               8
# 2   M10000227202560311ED021              2               5
# 3   M10000227202560311ED020              1               2
# 4   M10000227202560311ED019              2               5
# 5   M10000227202560311ED018             11               4
# 6   M10000227202560311ED017             12               7
# 7   M10000227202560311ED016              0               7
# 8   M10000227202560311ED015              8               3
# 9   M10000227202560311ED014              1               7
# 10  M10000227202560311ED013              0               6
# 11  M10000227202560311ED012              3               2
# 12  M10000227202560311ED011              4               1
# 13  M10000227202560311ED010              0               9
# 14  M10000227202560311ED009              1              11
# 15  M10000227202560311ED008              2               7
# 16  M10000227202560311ED007              3               9
# 17  M10000227202560311ED006              3               6
# 18  M10000227202560311ED005              1               6
# 19  M10000227202560311ED004              7               6
# 20  M10000227202560311ED003              7               4
# 21  M10000227202560311ED002              1               4
# 22  M10000227202560311ED001              5               8
#
#     agg*14no_num_point       psy_code
# 0                   10  P202509297849
# 1                   32  P202509297849
# 2                   10  P202509297849
# 3                    2  P202509297849
# 4                   10  P202509297849
# 5                   44  P202509297849
# 6                   84  P202509297849
# 7                    0  P202509297849
# 8                   24  P202509297849
# 9                    7  P202509297849
# 10                   0  P202509297849
# 11                   6  P202509297849
# 12                   4  P202509297849
# 13                   0  P202509297849
# 14                  11  P202509297849
# 15                  14  P202509297849
# 16                  27  P202509297849
# 17                  18  P202509297849
# 18                   6  P202509297849
# 19                  42  P202509297849
# 20                  28  P202509297849
# 21                   4  P202509297849
# 22                  40  P202509297849
#             student_code  num_point_agg  num_point_14no  agg*14no_num_point  \
# 0   DC03142025602FCDA025              1               4                   4
# 1   DC03142025602FCDA024              3               5                  15
# 2   DC03142025602FCDA022             14               7                  98
# 3   DC03142025602FCDA021              1               3                   3
# 4   DC03142025602FCDA020             22               8                 176
# 5   DC03142025602FCDA019              1               3                   3
# 6   DC03142025602FCDA017              2               4                   8
# 7   DC03142025602FCDA016              4               5                  20
# 8   DC03142025602FCDA015              1               5                   5
# 9   DC03142025602FCDA014             20               6                 120
# 10  DC03142025602FCDA013              0               4                   0
# 11  DC03142025602FCDA012             11               3                  33
# 12  DC03142025602FCDA009              0               4                   0
# 13  DC03142025602FCDA008              1               0                   0
# 14  DC03142025602FCDA007              3               3                   9
# 15  DC03142025602FCDA006              5               4                  20
# 16  DC03142025602FCDA005              2               2                   4
# 17  DC03142025602FCDA004              4               8                  32
# 18  DC03142025602FCDA003             17               7                 119
# 19  DC03142025602FCDA002              3               3                   9
# 20  DC03142025602FCDA001              0               2                   0
#
#          psy_code
# 0   P20250929B2C3
# 1   P20250929B2C3
# 2   P20250929B2C3
# 3   P20250929B2C3
# 4   P20250929B2C3
# 5   P20250929B2C3
# 6   P20250929B2C3
# 7   P20250929B2C3
# 8   P20250929B2C3
# 9   P20250929B2C3
# 10  P20250929B2C3
# 11  P20250929B2C3
# 12  P20250929B2C3
# 13  P20250929B2C3
# 14  P20250929B2C3
# 15  P20250929B2C3
# 16  P20250929B2C3
# 17  P20250929B2C3
# 18  P20250929B2C3
# 19  P20250929B2C3
# 20  P20250929B2C3

# %%
print(result_df)
# Out:
#                student_code  num_point_agg  num_point_14no  \
# 0   M1000000120253017C9D005             10               2
# 1   M1000000120253017C9D004             12               4
# 2   M1000000120253017C9D003              5               3
# 3   M1000000120253017C9D002              5               0
# 4   M1000000120253017C9D001              3               1
# ..                      ...            ...             ...
# 16     DC03142025602FCDA005              2               2
# 17     DC03142025602FCDA004              4               8
# 18     DC03142025602FCDA003             17               7
# 19     DC03142025602FCDA002              3               3
# 20     DC03142025602FCDA001              0               2
#
#     agg*14no_num_point       psy_code
# 0                   20  P202507041AFF
# 1                   48  P202507041AFF
# 2                   15  P202507041AFF
# 3                    0  P202507041AFF
# 4                    3  P202507041AFF
# ..                 ...            ...
# 16                   4  P20250929B2C3
# 17                  32  P20250929B2C3
# 18                 119  P20250929B2C3
# 19                   9  P20250929B2C3
# 20                   0  P20250929B2C3
#
# [679 rows x 5 columns]

# %%
# s3에 업로드
wr.s3.to_csv(result_df, f's3://schoolfriends-bym/result/aggression_point/aggression_point_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)
# Out:
# {'paths': ['s3://schoolfriends-bym/result/aggression_point/aggression_point_20251001_141131.csv'],
#  'partitions_values': {}}

# %%
# s3_folder_macro 소스에서 크롤러 생성해서 테이블화
# 특정 크롤러 생성 및 실행
import boto3
# s3 폴더 별로 크롤러 만들어서 아테네 테이블 만들때
glue = boto3.client("glue", region_name="ap-northeast-2")

# 공통 파라미터
role_name = 'arn:aws:iam::932744610695:role/service-role/AWSGlueServiceRole-Schoolfriends'
database_name = 'schoolfriends'
bucket_name = 'schoolfriends-bym'

crawler_name = "crawler_aggression_point"
s3_target_path = f"s3://schoolfriends-bym/result/aggression_point/"

try:
    response = glue.create_crawler(
        Name=crawler_name,
        Role=role_name,
        DatabaseName=database_name,
        Targets={'S3Targets': [{'Path': s3_target_path}]},
        SchemaChangePolicy={
            'UpdateBehavior': 'LOG',
            'DeleteBehavior': 'LOG'
        }
    )
    print(f"Crawler '{crawler_name}' created successfully.")
except glue.exceptions.AlreadyExistsException:
    print(f"Crawler '{crawler_name}' already exists.")
except Exception as e:
    print(f"Error creating crawler '{crawler_name}': {e}")
# Out:
# Crawler 'crawler_aggression_point' created successfully.

# %%
# 크롤러 동작
response = glue.start_crawler(Name=crawler_name)
print(f"Crawler '{crawler_name}' started successfully.")
# Out:
# Crawler 'crawler_aggression_point' started successfully.

# %% [markdown]
# ## 공격성 교범 가중평균(정규화전)

# %%
import awswrangler as wr
df = wr.athena.read_sql_query(
    """
    select a.school_code, a.school_name, b.school_grade, b.school_num, b.class_name, c.psy_name, c.psy_code, c.close_yn, f.student_num, d.target_code, e.user_testing_no, e.question_no, e.student_code 
    from school_info a
    inner join school_class b on a.school_code = b.school_code
    inner join psy_class c on b.class_code = c.class_code
    inner join psy_target d on c.class_code = d.class_code and c.psy_code = d.psy_code
    inner join at_user_testing_paper_pn e on d.user_testing_no = e.user_testing_no
    inner join school_student f on d.target_code = f.student_code and d.class_code = f.class_code
    where c.close_yn = 'Y' and e.question_no in ('4','5','6','7','14')
    """
    , database="schoolfriends")

# %% [markdown]
# # 친사회성 규범 점수

# %%
import awswrangler as wr
query_df = wr.athena.read_sql_query(
    """
    select a.school_code, a.school_name, b.school_grade, b.school_num, b.class_name, c.psy_name, c.psy_code, c.close_yn, f.student_num, d.target_code, e.user_testing_no, e.question_no, e.student_code 
    from school_info a
    inner join school_class b on a.school_code = b.school_code
    inner join psy_class c on b.class_code = c.class_code
    inner join psy_target d on c.class_code = d.class_code and c.psy_code = d.psy_code
    inner join at_user_testing_paper_pn e on d.user_testing_no = e.user_testing_no
    inner join school_student f on d.target_code = f.student_code and d.class_code = f.class_code
    where c.close_yn = 'Y' and e.question_no in (8,9,14)
    """
    , database="schoolfriends"
)

# %%
query_df
# Out:
#      school_code school_name  school_grade  school_num class_name  \
# 0         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 1         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 2         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 3         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# 4         AC0001      학지초등학교          <NA>        <NA>    우리 또래 반
# ...          ...         ...           ...         ...        ...
# 9790      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 9791      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 9792      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 9793      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
# 9794      TC0461    목포부주초등학교          <NA>        <NA>    "6학년7반"
#
#           psy_name       psy_code close_yn  student_num           target_code  \
# 0     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 1     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 2     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 3     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# 4     "25년 7월 1회차"  P20250716BE86        Y         <NA>  AC000120256042D2E020
# ...            ...            ...      ...          ...                   ...
# 9790  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 9791  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 9792  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 9793  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
# 9794  "25년 7월 1회차"  P20250722BAB6        Y         <NA>  TC046120256076567001
#
#              user_testing_no  question_no          student_code
# 0     "557b6318ba464b62be79"            8  AC000120256042D2E004
# 1     "557b6318ba464b62be79"            9  AC000120256042D2E013
# 2     "557b6318ba464b62be79"            9  AC000120256042D2E014
# 3     "557b6318ba464b62be79"           14  AC000120256042D2E001
# 4     "557b6318ba464b62be79"           14  AC000120256042D2E004
# ...                      ...          ...                   ...
# 9790    eeaf384f0e31454cb6d0            8  TC046120256076567022
# 9791    eeaf384f0e31454cb6d0            9  TC046120256076567022
# 9792    eeaf384f0e31454cb6d0           14  TC046120256076567012
# 9793    eeaf384f0e31454cb6d0           14  TC046120256076567021
# 9794    eeaf384f0e31454cb6d0           14  TC046120256076567022
#
# [9795 rows x 13 columns]

# %%
# 지명수 구하는 함수
def count_point(df, student_list, item_no) :
    import pandas as pd
    if df['psy_code'].nunique() > 1 :
        raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
    else :
        temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
        count_list = []
        for student in student_list :
            if len(temp_df[temp_df['student_code']==student]) >= 1 :
                freq = len(temp_df[temp_df['student_code']==student])
            elif len(temp_df[temp_df['student_code']==student]) == 0 :
                freq = 0
            count_list.append(freq)
        count_point_df = pd.DataFrame({'student_code': student_list, 'num_point': count_list})
        return count_point_df, df['psy_code'].iloc[0]

# 학생 리스트 구하는 함수
def student_list(df) :
    student_list = df['target_code'].unique().tolist()
    return student_list, df['psy_code'].iloc[0]

# %%
#df = query_df[query_df['psy_code'].str.contains('P202507183B0A')]
#print(df)
df = query_df

# %%
#! 뭔가 이상해서 추출해 엑셀로 확인
import pandas as pd
df.to_excel(f'scoring_etl_check_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.xlsx', index=False)

# %%
student_list_obj, psy_code = student_list(df)
print(student_list_obj, psy_code)
print(len(student_list_obj))
# Out:
# ['AC000120256042D2E020', 'AC000120256042D2E019', 'AC000120256042D2E018', 'AC000120256042D2E017', 'AC000120256042D2E016', 'AC000120256042D2E015', 'AC000120256042D2E014', 'AC000120256042D2E013', 'AC000120256042D2E012', 'AC000120256042D2E011', 'AC000120256042D2E010', 'AC000120256042D2E009', 'AC000120256042D2E008', 'AC000120256042D2E007', 'AC000120256042D2E006', 'AC000120256042D2E005', 'AC000120256042D2E004', 'AC000120256042D2E003', 'AC000120256042D2E002', 'AC000120256042D2E001', 'AC000120256016589025', 'AC000120256016589024', 'AC000120256016589023', 'AC000120256016589022', 'AC000120256016589021', 'AC000120256016589020', 'AC000120256016589019', 'AC000120256016589018', 'AC000120256016589017', 'AC000120256016589016', 'AC000120256016589015', 'AC000120256016589014', 'AC000120256016589013', 'AC000120256016589012', 'AC000120256016589011', 'AC000120256016589010', 'AC000120256016589009', 'AC000120256016589008', 'AC000120256016589007', 'AC000120256016589006', 'AC000120256016589005', 'AC000120256016589004', 'AC000120256016589003', 'AC000120256016589002', 'AC000120256016589001', 'AC000120255019FA1022', 'AC000120255019FA1021', 'AC000120255019FA1020', 'AC000120255019FA1019', 'AC000120255019FA1018', 'AC000120255019FA1017', 'AC000120255019FA1016', 'AC000120255019FA1015', 'AC000120255019FA1014', 'AC000120255019FA1013', 'AC000120255019FA1012', 'AC000120255019FA1011', 'AC000120255019FA1010', 'AC000120255019FA1009', 'AC000120255019FA1008', 'AC000120255019FA1007', 'AC000120255019FA1006', 'AC000120255019FA1005', 'AC000120255019FA1004', 'AC000120255019FA1003', 'AC000120255019FA1002', 'AC000120255019FA1001', 'AC0001202530101AF011', 'AC0001202530101AF004', 'AC0001202530101AF003', 'AC0001202530101AF002', 'AC0001202530101AF001', 'AC003320254028107005', 'AC003320254028107004', 'AC003320254028107003', 'AC003320254028107002', 'AC003320254028107001', 'AC0033202530170E8005', 'AC0033202530170E8004', 'AC0033202530170E8003', 'AC0033202530170E8002', 'AC0033202530170E8001', 'AC028020256033124005', 'AC028020256033124002', 'AC028020254014067003', 'AC028020254014067002', 'AC03022025503A360004', 'AC03022025503A360003', 'AC03022025503A360002', 'AC03022025503A360001', 'AC030220254020EB9004', 'AC030220254020EB9003', 'AC030220254020EB9002', 'AC030220254020EB9001', 'AC030220253019473004', 'AC030220253019473003', 'AC030220253019473002', 'AC030220253019473001', 'AC03782025403D43A002', 'AC037820254013BEF022', 'AC037820254013BEF012', 'AC037820254013BEF011', 'AC037820254013BEF003', 'AC037820254013BEF002', 'AC037820254013BEF001', 'DC00922025303B742003', 'DC00922025303B742002', 'DC00922025303B742001', 'DC009220253012482016', 'DC009220253012482015', 'DC009220253012482014', 'DC009220253012482010', 'DC009220253012482009', 'DC009220253012482008', 'DC009220253012482003', 'DC009220253012482002', 'DC009220253012482001', 'EC020820253011046004', 'EC020820253011046002', 'EC020820253011046001', 'EC022120253012B84002', 'EC022120253012B84001', 'M100000932025602D4F3022', 'M100000932025602D4F3021', 'M100000932025602D4F3020', 'M100000932025602D4F3019', 'M100000932025602D4F3018', 'M100000932025602D4F3017', 'M100000932025602D4F3016', 'M100000932025602D4F3015', 'M100000932025602D4F3014', 'M100000932025602D4F3013', 'M100000932025602D4F3012', 'M100000932025602D4F3011', 'M100000932025602D4F3010', 'M100000932025602D4F3009', 'M100000932025602D4F3008', 'M100000932025602D4F3007', 'M100000932025602D4F3006', 'M100000932025602D4F3005', 'M100000932025602D4F3004', 'M100000932025602D4F3002', 'M100000932025602D4F3001', 'M10000092202530442E7023', 'M10000092202530442E7022', 'M10000092202530442E7021', 'M10000092202530442E7020', 'M10000092202530442E7019', 'M10000092202530442E7018', 'M10000092202530442E7017', 'M10000092202530442E7016', 'M10000092202530442E7015', 'M10000092202530442E7014', 'M10000092202530442E7013', 'M10000092202530442E7012', 'M10000092202530442E7011', 'M10000092202530442E7010', 'M10000092202530442E7009', 'M10000092202530442E7008', 'M10000092202530442E7007', 'M10000092202530442E7006', 'M1000009220253044 ...
# 392

# %%
prosociality_point_df, psy_code = count_point(df, student_list_obj, ['8','9'])
n14_point_df, psy_code = count_point(df, student_list_obj, ['14'])
print(prosociality_point_df, psy_code)
print(n14_point_df, psy_code)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[177], line 1
# ----> 1 prosociality_point_df, psy_code = count_point(df, student_list_obj, ['8','9'])
#       2 n14_point_df, psy_code = count_point(df, student_list_obj, ['14'])
#       3 print(prosociality_point_df, psy_code)
#
# Cell In[174], line 5, in count_point(df, student_list, item_no)
#       3 import pandas as pd
#       4 if df['psy_code'].nunique() > 1 :
# ----> 5     raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
#       6 else :
#       7     temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
#
# ValueError: psy_code 컬럼에 여러 값이 존재합니다.

# %%
def prosociality_norms(df, celling_parameter=249) :
    import pandas as pd
    student_list_obj, psy_code = student_list(df)
    prosociality_point_df, psy_code = count_point(df, student_list_obj, [8,9])
    n14_point_df, psy_code = count_point(df, student_list_obj, [14])

    prosociality_norms_df = pd.merge(prosociality_point_df, n14_point_df, on='student_code', suffixes=('_prosociality', '_14no'))
    prosociality_norms_df['prosociality*14no_num_point'] = prosociality_norms_df['num_point_prosociality'] * prosociality_norms_df['num_point_14no']
    prosociality_norms_df.sort_values(by='prosociality*14no_num_point', ascending=False, inplace=True)

    top5_prosociality_norms_df = prosociality_norms_df.head(5)
    top5_mean = top5_prosociality_norms_df['prosociality*14no_num_point'].mean()
    total_mean = prosociality_norms_df['prosociality*14no_num_point'].mean()
    weighted_mean = 0.4 * (top5_mean) + 0.6 * (total_mean)
    weighted_mean = 4 * ((min(max(weighted_mean, 0), celling_parameter)-0)/celling_parameter)+1
    result_df = pd.DataFrame({'psy_code': [psy_code], 'top5_mean': [top5_mean], 'total_mean': [total_mean], 'weighted_mean': [weighted_mean]})
    result_df['reg_date'] = pd.Timestamp.now()
    result_df['purpose'] = f'"purpose=calibration;celling_parameter={celling_parameter};author=Yumin"'
    return result_df

# %%
result_df = prosociality_norms(df)
print(result_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[179], line 1
# ----> 1 result_df = prosociality_norms(df)
#       2 print(result_df)
#
# Cell In[178], line 4, in prosociality_norms(df, celling_parameter)
#       2 import pandas as pd
#       3 student_list_obj, psy_code = student_list(df)
# ----> 4 prosociality_point_df, psy_code = count_point(df, student_list_obj, ['8','9'])
#       5 n14_point_df, psy_code = count_point(df, student_list_obj, ['14'])
#       7 prosociality_norms_df = pd.merge(prosociality_point_df, n14_point_df, on='student_code', suffixes=('_prosociality', '_14no'))
#
# Cell In[174], line 5, in count_point(df, student_list, item_no)
#       3 import pandas as pd
#       4 if df['psy_code'].nunique() > 1 :
# ----> 5     raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
#       6 else :
#       7     temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
#
# ValueError: psy_code 컬럼에 여러 값이 존재합니다.

# %%
df
# Out:
#      school_code school_name school_grade school_num class_name      psy_name  \
# 0         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 1         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 2         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 3         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 4         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# ...          ...         ...          ...        ...        ...           ...
# 5062      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5063      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5064      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5065      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5066      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
#
#            psy_code close_yn student_num           target_code  \
# 0     P20250716BE86        Y        "20"  AC000120256042D2E020
# 1     P20250716BE86        Y        "20"  AC000120256042D2E020
# 2     P20250716BE86        Y        "20"  AC000120256042D2E020
# 3     P20250716BE86        Y        "20"  AC000120256042D2E020
# 4     P20250716BE86        Y        "20"  AC000120256042D2E020
# ...             ...      ...         ...                   ...
# 5062  P20250722BAB6        Y         "1"  TC046120256076567001
# 5063  P20250722BAB6        Y         "1"  TC046120256076567001
# 5064  P20250722BAB6        Y         "1"  TC046120256076567001
# 5065  P20250722BAB6        Y         "1"  TC046120256076567001
# 5066  P20250722BAB6        Y         "1"  TC046120256076567001
#
#              user_testing_no question_no          student_code
# 0     "557b6318ba464b62be79"           8  AC000120256042D2E004
# 1     "557b6318ba464b62be79"           9  AC000120256042D2E013
# 2     "557b6318ba464b62be79"           9  AC000120256042D2E014
# 3     "557b6318ba464b62be79"          14  AC000120256042D2E001
# 4     "557b6318ba464b62be79"          14  AC000120256042D2E004
# ...                      ...         ...                   ...
# 5062    eeaf384f0e31454cb6d0           8  TC046120256076567022
# 5063    eeaf384f0e31454cb6d0           9  TC046120256076567022
# 5064    eeaf384f0e31454cb6d0          14  TC046120256076567012
# 5065    eeaf384f0e31454cb6d0          14  TC046120256076567021
# 5066    eeaf384f0e31454cb6d0          14  TC046120256076567022
#
# [5067 rows x 13 columns]

# %%
def search_celling_prosociality_norms(df, celling_parameter) :
    import pandas as pd
    student_list_obj, psy_code = student_list(df)
    prosociality_point_df, psy_code = count_point(df, student_list_obj, [8,9])
    n14_point_df, psy_code = count_point(df, student_list_obj, [14])

    prosociality_norms_df = pd.merge(prosociality_point_df, n14_point_df, on='student_code', suffixes=('_prosociality', '_14no'))
    prosociality_norms_df['prosociality*14no_num_point'] = prosociality_norms_df['num_point_prosociality'] * prosociality_norms_df['num_point_14no']
    prosociality_norms_df.sort_values(by='prosociality*14no_num_point', ascending=False, inplace=True)

    top5_prosociality_norms_df = prosociality_norms_df.head(5)
    top5_mean = top5_prosociality_norms_df['prosociality*14no_num_point'].mean()
    total_mean = prosociality_norms_df['prosociality*14no_num_point'].mean()
    weighted_mean = 0.4 * (top5_mean) + 0.6 * (total_mean)
    weighted_mean_Normalization = 4 * ((min(max(weighted_mean, 0), celling_parameter)-0)/celling_parameter)+1
    result_df = pd.DataFrame({'psy_code': [psy_code], 'top5_mean': [top5_mean], 'total_mean': [total_mean], 'weighted_mean': [weighted_mean], 'weighted_mean_Normalization': [weighted_mean_Normalization]})
    result_df['reg_date'] = pd.Timestamp.now()
    result_df['purpose'] = f'"purpose=calibration;celling_parameter={celling_parameter};author=Yumin"'
    return result_df

# %%
import pandas as pd

psy_code_grouped = df.groupby('psy_code')
result_df = pd.DataFrame()
for parameter in range(67, 250) :
    print(f'celling_parameter: {parameter}')
    for psy_code, group in psy_code_grouped :
        result_df = pd.concat([result_df, search_celling_prosociality_norms(group, celling_parameter=parameter)])
# Out:
# celling_parameter: 67
# celling_parameter: 68
# celling_parameter: 69
# celling_parameter: 70
# celling_parameter: 71
# celling_parameter: 72
# celling_parameter: 73
# celling_parameter: 74
# celling_parameter: 75
# celling_parameter: 76
# celling_parameter: 77
# celling_parameter: 78
# celling_parameter: 79
# celling_parameter: 80
# celling_parameter: 81
# celling_parameter: 82
# celling_parameter: 83
# celling_parameter: 84
# celling_parameter: 85
# celling_parameter: 86
# celling_parameter: 87
# celling_parameter: 88
# celling_parameter: 89
# celling_parameter: 90
# celling_parameter: 91
# celling_parameter: 92
# celling_parameter: 93
# celling_parameter: 94
# celling_parameter: 95
# celling_parameter: 96
# celling_parameter: 97
# celling_parameter: 98
# celling_parameter: 99
# celling_parameter: 100
# celling_parameter: 101
# celling_parameter: 102
# celling_parameter: 103
# celling_parameter: 104
# celling_parameter: 105
# celling_parameter: 106
# celling_parameter: 107
# celling_parameter: 108
# celling_parameter: 109
# celling_parameter: 110
# celling_parameter: 111
# celling_parameter: 112
# celling_parameter: 113
# celling_parameter: 114
# celling_parameter: 115
# celling_parameter: 116
# celling_parameter: 117
# celling_parameter: 118
# celling_parameter: 119
# celling_parameter: 120
# celling_parameter: 121
# celling_parameter: 122
# celling_parameter: 123
# celling_parameter: 124
# celling_parameter: 125
# celling_parameter: 126
# celling_parameter: 127
# celling_parameter: 128
# celling_parameter: 129
# celling_parameter: 130
# celling_parameter: 131
# celling_parameter: 132
# celling_parameter: 133
# celling_parameter: 134
# celling_parameter: 135
# celling_parameter: 136
# celling_parameter: 137
# celling_parameter: 138
# celling_parameter: 139
# celling_parameter: 140
# celling_parameter: 141
# celling_parameter: 142
# celling_parameter: 143
# celling_parameter: 144
# celling_parameter: 145
# celling_parameter: 146
# celling_parameter: 147
# celling_parameter: 148
# celling_parameter: 149
# celling_parameter: 150
# celling_parameter: 151
# celling_parameter: 152
# celling_parameter: 153
# celling_parameter: 154
# celling_parameter: 155
# celling_parameter: 156
# celling_parameter: 157
# celling_parameter: 158
# celling_parameter: 159
# celling_parameter: 160
# celling_parameter: 161
# celling_parameter: 162
# celling_parameter: 163
# celling_parameter: 164
# celling_parameter: 165
# celling_parameter: 166
# celling_parameter: 167
# celling_parameter: 168
# celling_parameter: 169
# celling_parameter: 170
# celling_parameter: 171
# celling_parameter: 172
# celling_parameter: 173
# celling_parameter: 174
# celling_parameter: 175
# celling_parameter: 176
# celling_parameter: 177
# celling_parameter: 178
# celling_parameter: 179
# celling_parameter: 180
# celling_parameter: 181
# celling_parameter: 182
# celling_parameter: 183
# celling_parameter: 184
# celling_parameter: 185
# celling_parameter: 186
# celling_parameter: 187
# celling_parameter: 188
# celling_parameter: 189
# celling_parameter: 190
# celling_parameter: 191
# celling_parameter: 192
# celling_parameter: 193
# celling_parameter: 194
# celling_parameter: 195
# celling_parameter: 196
# celling_parameter: 197
# celling_parameter: 198
# celling_parameter: 199
# celling_parameter: 200
# celling_parameter: 201
# celling_parameter: 202
# celling_parameter: 203
# celling_parameter: 204
# celling_parameter: 205
# celling_parameter: 206
# celling_parameter: 207
# celling_parameter: 208
# celling_parameter: 209
# celling_parameter: 210
# celling_parameter: 211
# celling_parameter: 212
# celling_parameter: 213
# celling_parameter: 214
# celling_parameter: 215
# celling_parameter: 216
# celling_parameter: 217
# celling_parameter: 218
# celling_parameter: 219
# celling_parameter: 220
# celling_parameter: 221
# celling_parameter: 222
# celling_parameter: 223
# celling_parameter: 224
# celling_parameter: 225
# celling_parameter: 226
# celling_parameter: 227
# celling_parameter: 228
# celling_parameter: 229
# celling_parameter: 230
# celling_parameter: 231
# celling_parameter: 232
# celling_parameter: 233
# celling_parameter: 234
# celling_parameter: 235
# celling_parameter: 236
# celling_parameter: 237
# celling_parameter: 238
# celling_parameter: 239
# celling_parameter: 240
# celling_parameter: 241
# celling_parameter: 242
# celling_parameter: 243
# celling_parameter: 244
# celling_parameter: 245
# celling_parameter: 246
# celling_parameter: 247
# celling_parameter: 248
# celling_parameter: 249

# %%
print(result_df)
# Out:
#          psy_code  top5_mean  total_mean  weighted_mean  \
# 0   P202507041AFF       8.80    8.800000       8.800000
# 0   P202507046A44       3.60    3.600000       3.600000
# 0   P202507075FAD       2.50    2.500000       2.500000
# 0   P202507086502       3.25    3.250000       3.250000
# 0   P20250708740B      43.00   20.000000      29.200000
# ..            ...        ...         ...            ...
# 0   P20250926990C       6.40    2.866667       4.280000
# 0   P20250926E621      88.80   45.200000      62.640000
# 0   P20250926F99B       8.00    3.533333       5.320000
# 0   P202509297849     164.80   69.304348     107.502609
# 0   P20250929B2C3      58.40   30.476190      41.645714
#
#     weighted_mean_Normalization                   reg_date  \
# 0                      1.525373 2025-10-01 15:29:57.500020
# 0                      1.214925 2025-10-01 15:29:57.507314
# 0                      1.149254 2025-10-01 15:29:57.513843
# 0                      1.194030 2025-10-01 15:29:57.519754
# 0                      2.743284 2025-10-01 15:29:57.547349
# ..                          ...                        ...
# 0                      1.068755 2025-10-01 15:32:25.206788
# 0                      2.006265 2025-10-01 15:32:25.235480
# 0                      1.085462 2025-10-01 15:32:25.252798
# 0                      2.726950 2025-10-01 15:32:25.278911
# 0                      1.669007 2025-10-01 15:32:25.302747
#
#                                               purpose
# 0   "purpose=calibration;celling_parameter=67;auth...
# 0   "purpose=calibration;celling_parameter=67;auth...
# 0   "purpose=calibration;celling_parameter=67;auth...
# 0   "purpose=calibration;celling_parameter=67;auth...
# 0   "purpose=calibration;celling_parameter=67;auth...
# ..                                                ...
# 0   "purpose=calibration;celling_parameter=249;aut...
# 0   "purpose=calibration;celling_parameter=249;aut...
# 0   "purpose=calibration;celling_parameter=249;aut...
# 0   "purpose=calibration;celling_parameter=249;aut...
# 0   "purpose=calibration;celling_parameter=249;aut...
#
# [7686 rows x 7 columns]

# %%
result_df.to_csv(f'prosociality_norms_celling_parameter_search_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)

# %%
# 결과를 S3에 저장
wr.s3.to_csv(result_df, f's3://schoolfriends-bym/result/prosociality_norms/prosociality_norms_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)
# Out:
# {'paths': ['s3://schoolfriends-bym/result/prosociality_norms/prosociality_norms_20251001_153225.csv'],
#  'partitions_values': {}}

# %%
# 친사회성 지명 데이터 산출
df
# Out:
#      school_code school_name school_grade school_num class_name      psy_name  \
# 0         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 1         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 2         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 3         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# 4         AC0001      학지초등학교          "6"        "4"    우리 또래 반  "25년 7월 1회차"
# ...          ...         ...          ...        ...        ...           ...
# 5062      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5063      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5064      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5065      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
# 5066      TC0461    목포부주초등학교          "6"        "7"    "6학년7반"  "25년 7월 1회차"
#
#            psy_code close_yn student_num           target_code  \
# 0     P20250716BE86        Y        "20"  AC000120256042D2E020
# 1     P20250716BE86        Y        "20"  AC000120256042D2E020
# 2     P20250716BE86        Y        "20"  AC000120256042D2E020
# 3     P20250716BE86        Y        "20"  AC000120256042D2E020
# 4     P20250716BE86        Y        "20"  AC000120256042D2E020
# ...             ...      ...         ...                   ...
# 5062  P20250722BAB6        Y         "1"  TC046120256076567001
# 5063  P20250722BAB6        Y         "1"  TC046120256076567001
# 5064  P20250722BAB6        Y         "1"  TC046120256076567001
# 5065  P20250722BAB6        Y         "1"  TC046120256076567001
# 5066  P20250722BAB6        Y         "1"  TC046120256076567001
#
#              user_testing_no question_no          student_code
# 0     "557b6318ba464b62be79"           8  AC000120256042D2E004
# 1     "557b6318ba464b62be79"           9  AC000120256042D2E013
# 2     "557b6318ba464b62be79"           9  AC000120256042D2E014
# 3     "557b6318ba464b62be79"          14  AC000120256042D2E001
# 4     "557b6318ba464b62be79"          14  AC000120256042D2E004
# ...                      ...         ...                   ...
# 5062    eeaf384f0e31454cb6d0           8  TC046120256076567022
# 5063    eeaf384f0e31454cb6d0           9  TC046120256076567022
# 5064    eeaf384f0e31454cb6d0          14  TC046120256076567012
# 5065    eeaf384f0e31454cb6d0          14  TC046120256076567021
# 5066    eeaf384f0e31454cb6d0          14  TC046120256076567022
#
# [5067 rows x 13 columns]

# %%
# 지명수 구하는 함수
def count_point(df, student_list, item_no) :
    import pandas as pd
    if df['psy_code'].nunique() > 1 :
        raise ValueError('psy_code 컬럼에 여러 값이 존재합니다.')
    else :
        temp_df = df[df['question_no'].isin(item_no)] # 해당 문항 필터링
        count_list = []
        for student in student_list :
            if len(temp_df[temp_df['student_code']==student]) >= 1 :
                freq = len(temp_df[temp_df['student_code']==student])
            elif len(temp_df[temp_df['student_code']==student]) == 0 :
                freq = 0
            count_list.append(freq)
        count_point_df = pd.DataFrame({'student_code': student_list, 'num_point': count_list})
        return count_point_df, df['psy_code'].iloc[0]
    
# 학생 리스트 구하는 함수
def student_list(df) :
    student_list = df['target_code'].unique().tolist()
    return student_list, df['psy_code'].iloc[0]

# %%
import pandas as pd

psy_code_grouped = df.groupby('psy_code')
result_df = pd.DataFrame()
for psy_code, group in psy_code_grouped :
    student_list_obj, psy_code = student_list(group)
    prosociality_point_df, psy_code = count_point(group, student_list_obj, [8,9])
    n14_point_df, psy_code = count_point(group, student_list_obj, [14])
    merged_df = pd.merge(prosociality_point_df, n14_point_df, on='student_code', suffixes=('_prosociality', '_14no'))
    merged_df['prosociality*14no_num_point'] = merged_df['num_point_prosociality'] * merged_df['num_point_14no']
    merged_df['psy_code'] = psy_code
    print(merged_df)
    result_df = pd.concat([result_df, merged_df])
# Out:
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000000120253017C9D005                       4               2
# 1  M1000000120253017C9D004                       5               4
# 2  M1000000120253017C9D003                       5               3
# 3  M1000000120253017C9D002                       1               0
# 4  M1000000120253017C9D001                       1               1
#
#    prosociality*14no_num_point       psy_code
# 0                            8  P202507041AFF
# 1                           20  P202507041AFF
# 2                           15  P202507041AFF
# 3                            0  P202507041AFF
# 4                            1  P202507041AFF
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000000120253017C9D005                       2               2
# 1  M1000000120253017C9D004                       5               2
# 2  M1000000120253017C9D003                       2               2
# 3  M1000000120253017C9D002                       2               0
# 4  M1000000120253017C9D001                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                            4  P202507046A44
# 1                           10  P202507046A44
# 2                            4  P202507046A44
# 3                            0  P202507046A44
# 4                            0  P202507046A44
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000000120253017C9D004                       3               1
# 1  M1000000120253017C9D003                       3               2
# 2  M1000000120253017C9D002                       1               1
# 3  M1000000120253017C9D001                       1               0
#
#    prosociality*14no_num_point       psy_code
# 0                            3  P202507075FAD
# 1                            6  P202507075FAD
# 2                            1  P202507075FAD
# 3                            0  P202507075FAD
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000000120253017C9D007                       5               2
# 1  M1000000120253017C9D005                       3               1
# 2  M1000000120253017C9D002                       0               0
# 3  M1000000120253017C9D001                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                           10  P202507086502
# 1                            3  P202507086502
# 2                            0  P202507086502
# 3                            0  P202507086502
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120256016589025                       5               4
# 1   AC000120256016589024                       9               2
# 2   AC000120256016589023                       8               5
# 3   AC000120256016589022                       3               6
# 4   AC000120256016589021                       8               2
# 5   AC000120256016589020                       6               3
# 6   AC000120256016589019                       5               3
# 7   AC000120256016589018                       4               1
# 8   AC000120256016589017                       9               1
# 9   AC000120256016589016                       8               5
# 10  AC000120256016589015                       5               3
# 11  AC000120256016589014                       9               4
# 12  AC000120256016589013                       3               3
# 13  AC000120256016589012                      10               5
# 14  AC000120256016589011                       2               1
# 15  AC000120256016589010                      10               3
# 16  AC000120256016589009                       6               3
# 17  AC000120256016589008                       9               4
# 18  AC000120256016589007                       9               1
# 19  AC000120256016589006                       4               0
# 20  AC000120256016589005                       2               3
# 21  AC000120256016589004                       7               7
# 22  AC000120256016589003                       8               2
# 23  AC000120256016589002                       4               4
# 24  AC000120256016589001                      10               1
#
#     prosociality*14no_num_point       psy_code
# 0                            20  P20250708740B
# 1                            18  P20250708740B
# 2                            40  P20250708740B
# 3                            18  P20250708740B
# 4                            16  P20250708740B
# 5                            18  P20250708740B
# 6                            15  P20250708740B
# 7                             4  P20250708740B
# 8                             9  P20250708740B
# 9                            40  P20250708740B
# 10                           15  P20250708740B
# 11                           36  P20250708740B
# 12                            9  P20250708740B
# 13                           50  P20250708740B
# 14                            2  P20250708740B
# 15                           30  P20250708740B
# 16                           18  P20250708740B
# 17                           36  P20250708740B
# 18                            9  P20250708740B
# 19                            0  P20250708740B
# 20                            6  P20250708740B
# 21                           49  P20250708740B
# 22                           16  P20250708740B
# 23                           16  P20250708740B
# 24                           10  P20250708740B
#            student_code  num_point_prosociality  num_point_14no  \
# 0  AC0001202530101AF011                       0               0
# 1  AC0001202530101AF002                       1               0
# 2  AC0001202530101AF001                       3               2
#
#    prosociality*14no_num_point       psy_code
# 0                            0  P2025070965A7
# 1                            0  P2025070965A7
# 2                            6  P2025070965A7
#            student_code  num_point_prosociality  num_point_14no  \
# 0  AC0001202530101AF011                       1               1
# 1  AC0001202530101AF002                       1               1
# 2  AC0001202530101AF001                       2               1
#
#    prosociality*14no_num_point       psy_code
# 0                            1  P202507098064
# 1                            1  P202507098064
# 2                            2  P202507098064
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000005520256019C95003                       1               1
# 1  M1000005520256019C95002                       1               1
# 2  M1000005520256019C95001                       2               0
#
#    prosociality*14no_num_point       psy_code
# 0                            1  P202507118C5B
# 1                            1  P202507118C5B
# 2                            0  P202507118C5B
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000005520256019C95010                       6               7
# 1  M1000005520256019C95009                       3               3
# 2  M1000005520256019C95008                       7               4
# 3  M1000005520256019C95007                       4               0
# 4  M1000005520256019C95006                       5               1
# 5  M1000005520256019C95005                       8               1
# 6  M1000005520256019C95004                       5               2
# 7  M1000005520256019C95003                       4               3
# 8  M1000005520256019C95002                       4               2
# 9  M1000005520256019C95001                       2               0
#
#    prosociality*14no_num_point       psy_code
# 0                           42  P20250711FD39
# 1                            9  P20250711FD39
# 2                           28  P20250711FD39
# 3                            0  P20250711FD39
# 4                            5  P20250711FD39
# 5                            8  P20250711FD39
# 6                           10  P20250711FD39
# 7                           12  P20250711FD39
# 8                            8  P20250711FD39
# 9                            0  P20250711FD39
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000006320255020B29024                      13               5
# 1   M1000006320255020B29023                      19              12
# 2   M1000006320255020B29022                      22              13
# 3   M1000006320255020B29021                      16               8
# 4   M1000006320255020B29020                      15              11
# 5   M1000006320255020B29019                       8               3
# 6   M1000006320255020B29018                      14              10
# 7   M1000006320255020B29016                      18              11
# 8   M1000006320255020B29015                      14              10
# 9   M1000006320255020B29014                      20              10
# 10  M1000006320255020B29013                      13               9
# 11  M1000006320255020B29012                      10               6
# 12  M1000006320255020B29011                      16               8
# 13  M1000006320255020B29010                      18               9
# 14  M1000006320255020B29009                      12               7
# 15  M1000006320255020B29008                      10               7
# 16  M1000006320255020B29007                      19               9
# 17  M1000006320255020B29006                      14               6
# 18  M1000006320255020B29005                      17               9
# 19  M1000006320255020B29004                      13              13
# 20  M1000006320255020B29003                      14               8
# 21  M1000006320255020B29002                      29               5
# 22  M1000006320255020B29001                       3               1
#
#     prosociality*14no_num_point       psy_code
# 0                            65  P202507154E91
# 1                           228  P202507154E91
# 2                           286  P202507154E91
# 3                           128  P202507154E91
# 4                           165  P202507154E91
# 5                            24  P202507154E91
# 6                           140  P202507154E91
# 7                           198  P202507154E91
# 8                           140  P202507154E91
# 9                           200  P202507154E91
# 10                          117  P202507154E91
# 11                           60  P202507154E91
# 12                          128  P202507154E91
# 13                          162  P202507154E91
# 14                           84  P202507154E91
# 15                           70  P202507154E91
# 16                          171  P202507154E91
# 17                           84  P202507154E91
# 18                          153  P202507154E91
# 19                          169  P202507154E91
# 20                          112  P202507154E91
# 21                          145  P202507154E91
# 22                            3  P202507154E91
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000000120253017C9D001                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                            0  P20250716280A
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M100000732025501D3CA023                      11               5
# 1   M100000732025501D3CA022                       3               6
# 2   M100000732025501D3CA021                      24              12
# 3   M100000732025501D3CA020                      14               5
# 4   M100000732025501D3CA019                      10               6
# 5   M100000732025501D3CA018                      14               8
# 6   M100000732025501D3CA017                       9               7
# 7   M100000732025501D3CA016                      14               6
# 8   M100000732025501D3CA015                      13               9
# 9   M100000732025501D3CA014                       6              11
# 10  M100000732025501D3CA013                      14              10
# 11  M100000732025501D3CA012                      18               7
# 12  M100000732025501D3CA011                      11               9
# 13  M100000732025501D3CA010                      22              12
# 14  M100000732025501D3CA009                      12              10
# 15  M100000732025501D3CA008                       2               4
# 16  M100000732025501D3CA007                      13               7
# 17  M100000732025501D3CA006                      10               5
# 18  M100000732025501D3CA005                       8               7
# 19  M100000732025501D3CA004                       3               1
# 20  M100000732025501D3CA003                       8               5
# 21  M100000732025501D3CA002                       7               2
# 22  M100000732025501D3CA001                       1               1
#
#     prosociality*14no_num_point       psy_code
# 0                            55  P202507169BCD
# 1                            18  P202507169BCD
# 2                           288  P202507169BCD
# 3                            70  P202507169BCD
# 4                            60  P202507169BCD
# 5                           112  P202507169BCD
# 6                            63  P202507169BCD
# 7                            84  P202507169BCD
# 8                           117  P202507169BCD
# 9                            66  P202507169BCD
# 10                          140  P202507169BCD
# 11                          126  P202507169BCD
# 12                           99  P202507169BCD
# 13                          264  P202507169BCD
# 14                          120  P202507169BCD
# 15                            8  P202507169BCD
# 16                           91  P202507169BCD
# 17                           50  P202507169BCD
# 18                           56  P202507169BCD
# 19                            3  P202507169BCD
# 20                           40  P202507169BCD
# 21                           14  P202507169BCD
# 22                            1  P202507169BCD
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M100000682025602CF1C025                       7               7
# 1   M100000682025602CF1C024                      10               4
# 2   M100000682025602CF1C023                       6               8
# 3   M100000682025602CF1C022                      15               7
# 4   M100000682025602CF1C021                       2               2
# 5   M100000682025602CF1C020                       5               3
# 6   M100000682025602CF1C019                      18               9
# 7   M100000682025602CF1C018                       9               6
# 8   M100000682025602CF1C017                      10               9
# 9   M100000682025602CF1C016                      16              11
# 10  M100000682025602CF1C015                      19               7
# 11  M100000682025602CF1C014                      10              10
# 12  M100000682025602CF1C013                       9               5
# 13  M100000682025602CF1C012                       3               7
# 14  M100000682025602CF1C011                       4               6
# 15  M100000682025602CF1C010                       6               5
# 16  M100000682025602CF1C009                       2               0
# 17  M100000682025602CF1C008                      10               5
# 18  M100000682025602CF1C007                       4               5
# 19  M100000682025602CF1C006                      25              11
# 20  M100000682025602CF1C005                      19               9
# 21  M100000682025602CF1C004                      18               7
# 22  M100000682025602CF1C003                       4               8
# 23  M100000682025602CF1C002                       6               5
# 24  M100000682025602CF1C001                      22              11
#
#     prosociality*14no_num_point       psy_code
# 0                            49  P20250716BB5E
# 1                            40  P20250716BB5E
# 2                            48  P20250716BB5E
# 3                           105  P20250716BB5E
# 4                             4  P20250716BB5E
# 5                            15  P20250716BB5E
# 6                           162  P20250716BB5E
# 7                            54  P20250716BB5E
# 8                            90  P20250716BB5E
# 9                           176  P20250716BB5E
# 10                          133  P20250716BB5E
# 11                          100  P20250716BB5E
# 12                           45  P20250716BB5E
# 13                           21  P20250716BB5E
# 14                           24  P20250716BB5E
# 15                           30  P20250716BB5E
# 16                            0  P20250716BB5E
# 17                           50  P20250716BB5E
# 18                           20  P20250716BB5E
# 19                          275  P20250716BB5E
# 20                          171  P20250716BB5E
# 21                          126  P20250716BB5E
# 22                           32  P20250716BB5E
# 23                           30  P20250716BB5E
# 24                          242  P20250716BB5E
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120256042D2E020                       7               1
# 1   AC000120256042D2E019                      12               0
# 2   AC000120256042D2E018                       0               0
# 3   AC000120256042D2E017                       0               0
# 4   AC000120256042D2E016                       0               0
# 5   AC000120256042D2E015                       0               5
# 6   AC000120256042D2E014                       8               3
# 7   AC000120256042D2E013                      12               0
# 8   AC000120256042D2E012                       0               0
# 9   AC000120256042D2E011                       0               0
# 10  AC000120256042D2E010                       0               0
# 11  AC000120256042D2E009                       0               0
# 12  AC000120256042D2E008                       0               0
# 13  AC000120256042D2E007                       0               0
# 14  AC000120256042D2E006                       0               0
# 15  AC000120256042D2E005                       9               4
# 16  AC000120256042D2E004                      13               7
# 17  AC000120256042D2E003                       0               0
# 18  AC000120256042D2E002                       0               0
# 19  AC000120256042D2E001                       0              11
#
#     prosociality*14no_num_point       psy_code
# 0                             7  P20250716BE86
# 1                             0  P20250716BE86
# 2                             0  P20250716BE86
# 3                             0  P20250716BE86
# 4                             0  P20250716BE86
# 5                             0  P20250716BE86
# 6                            24  P20250716BE86
# 7                             0  P20250716BE86
# 8                             0  P20250716BE86
# 9                             0  P20250716BE86
# 10                            0  P20250716BE86
# 11                            0  P20250716BE86
# 12                            0  P20250716BE86
# 13                            0  P20250716BE86
# 14                            0  P20250716BE86
# 15                           36  P20250716BE86
# 16                           91  P20250716BE86
# 17                            0  P20250716BE86
# 18                            0  P20250716BE86
# 19                            0  P20250716BE86
#            student_code  num_point_prosociality  num_point_14no  \
# 0  AC000120256016589001                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                            0  P20250716CD70
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120255019FA1022                       3               1
# 1   AC000120255019FA1021                       0               1
# 2   AC000120255019FA1020                       3               1
# 3   AC000120255019FA1019                       7               0
# 4   AC000120255019FA1018                       4               1
# 5   AC000120255019FA1017                       5               3
# 6   AC000120255019FA1016                       2               2
# 7   AC000120255019FA1014                       1               3
# 8   AC000120255019FA1013                       2               0
# 9   AC000120255019FA1012                       0               3
# 10  AC000120255019FA1011                       1               4
# 11  AC000120255019FA1010                       0               2
# 12  AC000120255019FA1009                       3               1
# 13  AC000120255019FA1008                       3               3
# 14  AC000120255019FA1007                       3               1
# 15  AC000120255019FA1006                       2               0
# 16  AC000120255019FA1005                       2               2
# 17  AC000120255019FA1004                       3               2
# 18  AC000120255019FA1003                       8               2
# 19  AC000120255019FA1002                       3               2
# 20  AC000120255019FA1001                       2               3
#
#     prosociality*14no_num_point       psy_code
# 0                             3  P202507183B0A
# 1                             0  P202507183B0A
# 2                             3  P202507183B0A
# 3                             0  P202507183B0A
# 4                             4  P202507183B0A
# 5                            15  P202507183B0A
# 6                             4  P202507183B0A
# 7                             3  P202507183B0A
# 8                             0  P202507183B0A
# 9                             0  P202507183B0A
# 10                            4  P202507183B0A
# 11                            0  P202507183B0A
# 12                            3  P202507183B0A
# 13                            9  P202507183B0A
# 14                            3  P202507183B0A
# 15                            0  P202507183B0A
# 16                            4  P202507183B0A
# 17                            6  P202507183B0A
# 18                           16  P202507183B0A
# 19                            6  P202507183B0A
# 20                            6  P202507183B0A
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120255019FA1022                       3               1
# 1   AC000120255019FA1021                       0               1
# 2   AC000120255019FA1020                       3               1
# 3   AC000120255019FA1019                       7               0
# 4   AC000120255019FA1018                       4               1
# 5   AC000120255019FA1017                       5               3
# 6   AC000120255019FA1016                       2               2
# 7   AC000120255019FA1015                       2               0
# 8   AC000120255019FA1014                       1               3
# 9   AC000120255019FA1013                       2               0
# 10  AC000120255019FA1012                       0               3
# 11  AC000120255019FA1011                       2               4
# 12  AC000120255019FA1010                       0               2
# 13  AC000120255019FA1009                       3               1
# 14  AC000120255019FA1008                       3               3
# 15  AC000120255019FA1007                       3               1
# 16  AC000120255019FA1006                       2               0
# 17  AC000120255019FA1005                       2               2
# 18  AC000120255019FA1004                       3               2
# 19  AC000120255019FA1003                       8               2
# 20  AC000120255019FA1002                       3               2
# 21  AC000120255019FA1001                       2               3
#
#     prosociality*14no_num_point       psy_code
# 0                             3  P20250718B4BE
# 1                             0  P20250718B4BE
# 2                             3  P20250718B4BE
# 3                             0  P20250718B4BE
# 4                             4  P20250718B4BE
# 5                            15  P20250718B4BE
# 6                             4  P20250718B4BE
# 7                             0  P20250718B4BE
# 8                             3  P20250718B4BE
# 9                             0  P20250718B4BE
# 10                            0  P20250718B4BE
# 11                            8  P20250718B4BE
# 12                            0  P20250718B4BE
# 13                            3  P20250718B4BE
# 14                            9  P20250718B4BE
# 15                            3  P20250718B4BE
# 16                            0  P20250718B4BE
# 17                            4  P20250718B4BE
# 18                            6  P20250718B4BE
# 19                           16  P20250718B4BE
# 20                            6  P20250718B4BE
# 21                            6  P20250718B4BE
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000008720256056A20022                      11               5
# 1   M1000008720256056A20021                      12               3
# 2   M1000008720256056A20020                      12               6
# 3   M1000008720256056A20019                      10               4
# 4   M1000008720256056A20018                      10               6
# 5   M1000008720256056A20017                      15               4
# 6   M1000008720256056A20016                      21               9
# 7   M1000008720256056A20015                      13               9
# 8   M1000008720256056A20014                       6               7
# 9   M1000008720256056A20013                      18               7
# 10  M1000008720256056A20012                      12               4
# 11  M1000008720256056A20011                       1               2
# 12  M1000008720256056A20009                      11               7
# 13  M1000008720256056A20008                       7               0
# 14  M1000008720256056A20006                       5               5
# 15  M1000008720256056A20005                      11               7
# 16  M1000008720256056A20004                      13               9
# 17  M1000008720256056A20003                       6               7
# 18  M1000008720256056A20002                      11               5
# 19  M1000008720256056A20001                       8               4
#
#     prosociality*14no_num_point       psy_code
# 0                            55  P202507213ACA
# 1                            36  P202507213ACA
# 2                            72  P202507213ACA
# 3                            40  P202507213ACA
# 4                            60  P202507213ACA
# 5                            60  P202507213ACA
# 6                           189  P202507213ACA
# 7                           117  P202507213ACA
# 8                            42  P202507213ACA
# 9                           126  P202507213ACA
# 10                           48  P202507213ACA
# 11                            2  P202507213ACA
# 12                           77  P202507213ACA
# 13                            0  P202507213ACA
# 14                           25  P202507213ACA
# 15                           77  P202507213ACA
# 16                          117  P202507213ACA
# 17                           42  P202507213ACA
# 18                           55  P202507213ACA
# 19                           32  P202507213ACA
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M10000086202560261A9023                       8               2
# 1   M10000086202560261A9022                       9               4
# 2   M10000086202560261A9021                       3               3
# 3   M10000086202560261A9020                       9               8
# 4   M10000086202560261A9019                      13               8
# 5   M10000086202560261A9018                       7               4
# 6   M10000086202560261A9017                      11               8
# 7   M10000086202560261A9016                       1               2
# 8   M10000086202560261A9015                      14               5
# 9   M10000086202560261A9014                      13               7
# 10  M10000086202560261A9013                       4               5
# 11  M10000086202560261A9012                       3               5
# 12  M10000086202560261A9011                       4               5
# 13  M10000086202560261A9010                       5               5
# 14  M10000086202560261A9009                      12               5
# 15  M10000086202560261A9008                      10              10
# 16  M10000086202560261A9007                       6               6
# 17  M10000086202560261A9006                       3               5
# 18  M10000086202560261A9005                       3               4
# 19  M10000086202560261A9004                       3               7
# 20  M10000086202560261A9003                       4               6
# 21  M10000086202560261A9002                       6               6
# 22  M10000086202560261A9001                       4               6
#
#     prosociality*14no_num_point       psy_code
# 0                            16  P202507217086
# 1                            36  P202507217086
# 2                             9  P202507217086
# 3                            72  P202507217086
# 4                           104  P202507217086
# 5                            28  P202507217086
# 6                            88  P202507217086
# 7                             2  P202507217086
# 8                            70  P202507217086
# 9                            91  P202507217086
# 10                           20  P202507217086
# 11                           15  P202507217086
# 12                           20  P202507217086
# 13                           25  P202507217086
# 14                           60  P202507217086
# 15                          100  P202507217086
# 16                           36  P202507217086
# 17                           15  P202507217086
# 18                           12  P202507217086
# 19                           21  P202507217086
# 20                           24  P202507217086
# 21                           36  P202507217086
# 22                           24  P202507217086
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000008820256034F56022                       0               0
# 1   M1000008820256034F56021                       3               3
# 2   M1000008820256034F56020                       2               2
# 3   M1000008820256034F56019                       4               7
# 4   M1000008820256034F56018                       5               8
# 5   M1000008820256034F56017                       7               7
# 6   M1000008820256034F56016                       6               4
# 7   M1000008820256034F56015                       5               7
# 8   M1000008820256034F56014                       1               2
# 9   M1000008820256034F56013                       3               5
# 10  M1000008820256034F56012                       2               4
# 11  M1000008820256034F56011                       6               7
# 12  M1000008820256034F56010                       3               3
# 13  M1000008820256034F56009                       6               8
# 14  M1000008820256034F56008                      10               4
# 15  M1000008820256034F56007                       0               2
# 16  M1000008820256034F56006                       6               6
# 17  M1000008820256034F56005                      14               6
# 18  M1000008820256034F56004                       1               5
# 19  M1000008820256034F56003                       7               7
# 20  M1000008820256034F56002                      10               5
# 21  M1000008820256034F56001                       3               2
#
#     prosociality*14no_num_point       psy_code
# 0                             0  P2025072176E5
# 1                             9  P2025072176E5
# 2                             4  P2025072176E5
# 3                            28  P2025072176E5
# 4                            40  P2025072176E5
# 5                            49  P2025072176E5
# 6                            24  P2025072176E5
# 7                            35  P2025072176E5
# 8                             2  P2025072176E5
# 9                            15  P2025072176E5
# 10                            8  P2025072176E5
# 11                           42  P2025072176E5
# 12                            9  P2025072176E5
# 13                           48  P2025072176E5
# 14                           40  P2025072176E5
# 15                            0  P2025072176E5
# 16                           36  P2025072176E5
# 17                           84  P2025072176E5
# 18                            5  P2025072176E5
# 19                           49  P2025072176E5
# 20                           50  P2025072176E5
# 21                            6  P2025072176E5
#               student_code  num_point_prosociality  num_point_14no  \
# 0  M1000008720256056A20010                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                            0  P20250721C339
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M10000092202530442E7023                       8               5
# 1   M10000092202530442E7022                       4               2
# 2   M10000092202530442E7021                       9               7
# 3   M10000092202530442E7020                       8               7
# 4   M10000092202530442E7019                      13               9
# 5   M10000092202530442E7018                      10               7
# 6   M10000092202530442E7017                       4               5
# 7   M10000092202530442E7016                       6               4
# 8   M10000092202530442E7015                      12               7
# 9   M10000092202530442E7014                       9               6
# 10  M10000092202530442E7013                      12               8
# 11  M10000092202530442E7012                      11               6
# 12  M10000092202530442E7011                       8               4
# 13  M10000092202530442E7010                      12               7
# 14  M10000092202530442E7009                      12               4
# 15  M10000092202530442E7008                       5               5
# 16  M10000092202530442E7007                      10               6
# 17  M10000092202530442E7006                       6               6
# 18  M10000092202530442E7005                       8               4
# 19  M10000092202530442E7004                      14               7
# 20  M10000092202530442E7003                       5               3
# 21  M10000092202530442E7002                       5               3
# 22  M10000092202530442E7001                      11               7
#
#     prosociality*14no_num_point       psy_code
# 0                            40  P2025072289FD
# 1                             8  P2025072289FD
# 2                            63  P2025072289FD
# 3                            56  P2025072289FD
# 4                           117  P2025072289FD
# 5                            70  P2025072289FD
# 6                            20  P2025072289FD
# 7                            24  P2025072289FD
# 8                            84  P2025072289FD
# 9                            54  P2025072289FD
# 10                           96  P2025072289FD
# 11                           66  P2025072289FD
# 12                           32  P2025072289FD
# 13                           84  P2025072289FD
# 14                           48  P2025072289FD
# 15                           25  P2025072289FD
# 16                           60  P2025072289FD
# 17                           36  P2025072289FD
# 18                           32  P2025072289FD
# 19                           98  P2025072289FD
# 20                           15  P2025072289FD
# 21                           15  P2025072289FD
# 22                           77  P2025072289FD
#             student_code  num_point_prosociality  num_point_14no  \
# 0   TC046120256076567022                       6               4
# 1   TC046120256076567021                       8               3
# 2   TC046120256076567020                      10               8
# 3   TC046120256076567019                       6               8
# 4   TC046120256076567018                       6               7
# 5   TC046120256076567015                      10               6
# 6   TC046120256076567014                      13               7
# 7   TC046120256076567012                       3               4
# 8   TC046120256076567011                       8               6
# 9   TC046120256076567010                       7               8
# 10  TC046120256076567009                       8               5
# 11  TC046120256076567008                      14               8
# 12  TC046120256076567006                       4               2
# 13  TC046120256076567004                       8               5
# 14  TC046120256076567003                      11               8
# 15  TC046120256076567001                       4               4
#
#     prosociality*14no_num_point       psy_code
# 0                            24  P20250722BAB6
# 1                            24  P20250722BAB6
# 2                            80  P20250722BAB6
# 3                            48  P20250722BAB6
# 4                            42  P20250722BAB6
# 5                            60  P20250722BAB6
# 6                            91  P20250722BAB6
# 7                            12  P20250722BAB6
# 8                            48  P20250722BAB6
# 9                            56  P20250722BAB6
# 10                           40  P20250722BAB6
# 11                          112  P20250722BAB6
# 12                            8  P20250722BAB6
# 13                           40  P20250722BAB6
# 14                           88  P20250722BAB6
# 15                           16  P20250722BAB6
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M100000902025602F30D022                       6               6
# 1   M100000902025602F30D021                       7               7
# 2   M100000902025602F30D020                       3               6
# 3   M100000902025602F30D019                       8               6
# 4   M100000902025602F30D018                      27               5
# 5   M100000902025602F30D017                      13               2
# 6   M100000902025602F30D016                       4               4
# 7   M100000902025602F30D015                       5               5
# 8   M100000902025602F30D014                       5               5
# 9   M100000902025602F30D013                      21               5
# 10  M100000902025602F30D012                       9               6
# 11  M100000902025602F30D011                       4               4
# 12  M100000902025602F30D010                      13               4
# 13  M100000902025602F30D009                      23               8
# 14  M100000902025602F30D008                      14               6
# 15  M100000902025602F30D007                      10               6
# 16  M100000902025602F30D006                      19               8
# 17  M100000902025602F30D004                      11               4
# 18  M100000902025602F30D003                       3               2
# 19  M100000902025602F30D002                       8               7
# 20  M100000902025602F30D001                       1               6
#
#     prosociality*14no_num_point       psy_code
# 0                            36  P20250722D67F
# 1                            49  P20250722D67F
# 2                            18  P20250722D67F
# 3                            48  P20250722D67F
# 4                           135  P20250722D67F
# 5                            26  P20250722D67F
# 6                            16  P20250722D67F
# 7                            25  P20250722D67F
# 8                            25  P20250722D67F
# 9                           105  P20250722D67F
# 10                           54  P20250722D67F
# 11                           16  P20250722D67F
# 12                           52  P20250722D67F
# 13                          184  P20250722D67F
# 14                           84  P20250722D67F
# 15                           60  P20250722D67F
# 16                          152  P20250722D67F
# 17                           44  P20250722D67F
# 18                            6  P20250722D67F
# 19                           56  P20250722D67F
# 20                            6  P20250722D67F
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M100000932025602D4F3022                       4               2
# 1   M100000932025602D4F3021                       7               7
# 2   M100000932025602D4F3020                      13               9
# 3   M100000932025602D4F3019                       5               6
# 4   M100000932025602D4F3018                      12              10
# 5   M100000932025602D4F3017                       3               4
# 6   M100000932025602D4F3016                      14               4
# 7   M100000932025602D4F3015                      10               8
# 8   M100000932025602D4F3014                      12               9
# 9   M100000932025602D4F3013                       9               7
# 10  M100000932025602D4F3012                      15               5
# 11  M100000932025602D4F3011                      16               1
# 12  M100000932025602D4F3010                      11               5
# 13  M100000932025602D4F3009                      11               6
# 14  M100000932025602D4F3008                      12              10
# 15  M100000932025602D4F3007                      15               6
# 16  M100000932025602D4F3006                      13               9
# 17  M100000932025602D4F3005                      12               5
# 18  M100000932025602D4F3004                      14               7
# 19  M100000932025602D4F3002                      15               5
# 20  M100000932025602D4F3001                       3               4
#
#     prosociality*14no_num_point       psy_code
# 0                             8  P2025072408CB
# 1                            49  P2025072408CB
# 2                           117  P2025072408CB
# 3                            30  P2025072408CB
# 4                           120  P2025072408CB
# 5                            12  P2025072408CB
# 6                            56  P2025072408CB
# 7                            80  P2025072408CB
# 8                           108  P2025072408CB
# 9                            63  P2025072408CB
# 10                           75  P2025072408CB
# 11                           16  P2025072408CB
# 12                           55  P2025072408CB
# 13                           66  P2025072408CB
# 14                          120  P2025072408CB
# 15                           90  P2025072408CB
# 16                          117  P2025072408CB
# 17                           60  P2025072408CB
# 18                           98  P2025072408CB
# 19                           75  P2025072408CB
# 20                           12  P2025072408CB
#            student_code  num_point_prosociality  num_point_14no  \
# 0  AC0001202530101AF011                       0               0
#
#    prosociality*14no_num_point       psy_code
# 0                            0  P2025080762D7
#            student_code  num_point_prosociality  num_point_14no  \
# 0  AC0001202530101AF011                       4               2
# 1  AC0001202530101AF004                       4               1
# 2  AC0001202530101AF003                       1               1
# 3  AC0001202530101AF002                       2               0
# 4  AC0001202530101AF001                       3               0
#
#    prosociality*14no_num_point       psy_code
# 0                            8  P202508119E7D
# 1                            4  P202508119E7D
# 2                            1  P202508119E7D
# 3                            0  P202508119E7D
# 4                            0  P202508119E7D
#             student_code  num_point_prosociality  num_point_14no  \
# 0   DC017620255014BE0022                       6               3
# 1   DC017620255014BE0021                       7               5
# 2   DC017620255014BE0020                       9               7
# 3   DC017620255014BE0019                       7               6
# 4   DC017620255014BE0018                       9               8
# 5   DC017620255014BE0017                       6               5
# 6   DC017620255014BE0016                       3               7
# 7   DC017620255014BE0014                       5               5
# 8   DC017620255014BE0013                       8               8
# 9   DC017620255014BE0012                       7               3
# 10  DC017620255014BE0011                       1               3
# 11  DC017620255014BE0010                       4               6
# 12  DC017620255014BE0009                       0               1
# 13  DC017620255014BE0008                       4               5
# 14  DC017620255014BE0007                       2               5
# 15  DC017620255014BE0006                       1               4
# 16  DC017620255014BE0005                       8               7
# 17  DC017620255014BE0004                       8               6
# 18  DC017620255014BE0003                       8               8
# 19  DC017620255014BE0002                      12               8
# 20  DC017620255014BE0001                       7               6
#
#     prosociality*14no_num_point       psy_code
# 0                            18  P202509103074
# 1                            35  P202509103074
# 2                            63  P202509103074
# 3                            42  P202509103074
# 4                            72  P202509103074
# 5                            30  P202509103074
# 6                            21  P202509103074
# 7                            25  P202509103074
# 8                            64  P202509103074
# 9                            21  P202509103074
# 10                            3  P202509103074
# 11                           24  P202509103074
# 12                            0  P202509103074
# 13                           20  P202509103074
# 14                           10  P202509103074
# 15                            4  P202509103074
# 16                           56  P202509103074
# 17                           48  P202509103074
# 18                           64  P202509103074
# 19                           96  P202509103074
# 20                           42  P202509103074
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000006320255020B29024                      14               5
# 1   M1000006320255020B29023                      16              12
# 2   M1000006320255020B29021                      29              10
# 3   M1000006320255020B29020                      16              12
# 4   M1000006320255020B29019                      12               5
# 5   M1000006320255020B29018                      15              13
# ...
# 14                          299  P202509261CF3
# 15                          200  P202509261CF3
# 16                          252  P202509261CF3
# 17                          200  P202509261CF3
# 18                          266  P202509261CF3
# 19                          128  P202509261CF3
# 20                           66  P202509261CF3
# 21                          300  P202509261CF3
# 22                          161  P202509261CF3
# 23                          532  P202509261CF3
# 24                          100  P202509261CF3
# 25                           78  P202509261CF3
# 26                          250  P202509261CF3
# 27                          231  P202509261CF3
# 28                          117  P202509261CF3
# 29                          114  P202509261CF3
# 30                           90  P202509261CF3
# 31                           28  P202509261CF3
# 32                          140  P202509261CF3
# 33                           50  P202509261CF3
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000021520254044918022                       5               9
# 1   M1000021520254044918021                       8               4
# 2   M1000021520254044918020                       9               8
# 3   M1000021520254044918019                       7              11
# 4   M1000021520254044918018                       4               5
# 5   M1000021520254044918017                      19               7
# 6   M1000021520254044918016                      16               6
# 7   M1000021520254044918015                       5              10
# 8   M1000021520254044918014                       8               6
# 9   M1000021520254044918013                       7               9
# 10  M1000021520254044918012                      13               6
# 11  M1000021520254044918011                       9              10
# 12  M1000021520254044918010                      11              11
# 13  M1000021520254044918009                      16               4
# 14  M1000021520254044918008                      17               7
# 15  M1000021520254044918007                       2               1
# 16  M1000021520254044918006                       2               2
# 17  M1000021520254044918005                      19               5
# 18  M1000021520254044918004                       7               7
# 19  M1000021520254044918003                      21               6
# 20  M1000021520254044918002                      10               7
# 21  M1000021520254044918001                      18               8
#
#     prosociality*14no_num_point       psy_code
# 0                            45  P202509265DB4
# 1                            32  P202509265DB4
# 2                            72  P202509265DB4
# 3                            77  P202509265DB4
# 4                            20  P202509265DB4
# 5                           133  P202509265DB4
# 6                            96  P202509265DB4
# 7                            50  P202509265DB4
# 8                            48  P202509265DB4
# 9                            63  P202509265DB4
# 10                           78  P202509265DB4
# 11                           90  P202509265DB4
# 12                          121  P202509265DB4
# 13                           64  P202509265DB4
# 14                          119  P202509265DB4
# 15                            2  P202509265DB4
# 16                            4  P202509265DB4
# 17                           95  P202509265DB4
# 18                           49  P202509265DB4
# 19                          126  P202509265DB4
# 20                           70  P202509265DB4
# 21                          144  P202509265DB4
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120254041DD8015                       2               3
# 1   AC000120254041DD8014                       2               3
# 2   AC000120254041DD8013                       2               1
# 3   AC000120254041DD8012                       3               1
# 4   AC000120254041DD8011                       2               2
# 5   AC000120254041DD8010                       5               2
# 6   AC000120254041DD8009                       2               3
# 7   AC000120254041DD8008                       2               0
# 8   AC000120254041DD8007                       2               0
# 9   AC000120254041DD8006                       4               1
# 10  AC000120254041DD8005                       0               1
# 11  AC000120254041DD8004                       1               0
# 12  AC000120254041DD8003                       2               0
# 13  AC000120254041DD8002                       6               0
# 14  AC000120254041DD8001                       2               1
#
#     prosociality*14no_num_point       psy_code
# 0                             6  P20250926990C
# 1                             6  P20250926990C
# 2                             2  P20250926990C
# 3                             3  P20250926990C
# 4                             4  P20250926990C
# 5                            10  P20250926990C
# 6                             6  P20250926990C
# 7                             0  P20250926990C
# 8                             0  P20250926990C
# 9                             4  P20250926990C
# 10                            0  P20250926990C
# 11                            0  P20250926990C
# 12                            0  P20250926990C
# 13                            0  P20250926990C
# 14                            2  P20250926990C
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC035020255040D0F065                      10               4
# 1   AC035020255040D0F064                       9               5
# 2   AC035020255040D0F063                       9               5
# 3   AC035020255040D0F060                       2               1
# 4   AC035020255040D0F059                       4               2
# 5   AC035020255040D0F058                       9               5
# 6   AC035020255040D0F057                       9               6
# 7   AC035020255040D0F056                      13               1
# 8   AC035020255040D0F055                       8               7
# 9   AC035020255040D0F054                       3               2
# 10  AC035020255040D0F053                       2               3
# 11  AC035020255040D0F052                       2               0
# 12  AC035020255040D0F051                       5               7
# 13  AC035020255040D0F014                      16               7
# 14  AC035020255040D0F013                      10               7
# 15  AC035020255040D0F012                      11               4
# 16  AC035020255040D0F011                       7               6
# 17  AC035020255040D0F010                      11               7
# 18  AC035020255040D0F009                      11               7
# 19  AC035020255040D0F008                      20               5
# 20  AC035020255040D0F007                      13               5
# 21  AC035020255040D0F005                      10               5
# 22  AC035020255040D0F004                      15               2
# 23  AC035020255040D0F003                      13               6
# 24  AC035020255040D0F002                       6               5
#
#     prosociality*14no_num_point       psy_code
# 0                            40  P20250926E621
# 1                            45  P20250926E621
# 2                            45  P20250926E621
# 3                             2  P20250926E621
# 4                             8  P20250926E621
# 5                            45  P20250926E621
# 6                            54  P20250926E621
# 7                            13  P20250926E621
# 8                            56  P20250926E621
# 9                             6  P20250926E621
# 10                            6  P20250926E621
# 11                            0  P20250926E621
# 12                           35  P20250926E621
# 13                          112  P20250926E621
# 14                           70  P20250926E621
# 15                           44  P20250926E621
# 16                           42  P20250926E621
# 17                           77  P20250926E621
# 18                           77  P20250926E621
# 19                          100  P20250926E621
# 20                           65  P20250926E621
# 21                           50  P20250926E621
# 22                           30  P20250926E621
# 23                           78  P20250926E621
# 24                           30  P20250926E621
#             student_code  num_point_prosociality  num_point_14no  \
# 0   AC000120254041DD8015                       2               3
# 1   AC000120254041DD8014                       0               1
# 2   AC000120254041DD8013                       1               0
# 3   AC000120254041DD8012                       5               1
# 4   AC000120254041DD8011                       5               3
# 5   AC000120254041DD8010                       0               2
# 6   AC000120254041DD8009                       2               2
# 7   AC000120254041DD8008                       1               1
# 8   AC000120254041DD8007                       1               2
# 9   AC000120254041DD8006                       5               2
# 10  AC000120254041DD8005                       1               1
# 11  AC000120254041DD8004                       1               0
# 12  AC000120254041DD8003                       3               1
# 13  AC000120254041DD8002                       1               2
# 14  AC000120254041DD8001                       4               1
#
#     prosociality*14no_num_point       psy_code
# 0                             6  P20250926F99B
# 1                             0  P20250926F99B
# 2                             0  P20250926F99B
# 3                             5  P20250926F99B
# 4                            15  P20250926F99B
# 5                             0  P20250926F99B
# 6                             4  P20250926F99B
# 7                             1  P20250926F99B
# 8                             2  P20250926F99B
# 9                            10  P20250926F99B
# 10                            1  P20250926F99B
# 11                            0  P20250926F99B
# 12                            3  P20250926F99B
# 13                            2  P20250926F99B
# 14                            4  P20250926F99B
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M10000227202560311ED023                       7               5
# 1   M10000227202560311ED022                      22               8
# 2   M10000227202560311ED021                       6               5
# 3   M10000227202560311ED020                      12               2
# 4   M10000227202560311ED019                       8               5
# 5   M10000227202560311ED018                       5               4
# 6   M10000227202560311ED017                       5               7
# 7   M10000227202560311ED016                      18               7
# 8   M10000227202560311ED015                       9               3
# 9   M10000227202560311ED014                      19               7
# 10  M10000227202560311ED013                      10               6
# 11  M10000227202560311ED012                       6               2
# 12  M10000227202560311ED011                       6               1
# 13  M10000227202560311ED010                      20               9
# 14  M10000227202560311ED009                      19              11
# 15  M10000227202560311ED008                      10               7
# 16  M10000227202560311ED007                      13               9
# 17  M10000227202560311ED006                       8               6
# 18  M10000227202560311ED005                      13               6
# 19  M10000227202560311ED004                       8               6
# 20  M10000227202560311ED003                       7               4
# 21  M10000227202560311ED002                       7               4
# 22  M10000227202560311ED001                       8               8
#
#     prosociality*14no_num_point       psy_code
# 0                            35  P202509297849
# 1                           176  P202509297849
# 2                            30  P202509297849
# 3                            24  P202509297849
# 4                            40  P202509297849
# 5                            20  P202509297849
# 6                            35  P202509297849
# 7                           126  P202509297849
# 8                            27  P202509297849
# 9                           133  P202509297849
# 10                           60  P202509297849
# 11                           12  P202509297849
# 12                            6  P202509297849
# 13                          180  P202509297849
# 14                          209  P202509297849
# 15                           70  P202509297849
# 16                          117  P202509297849
# 17                           48  P202509297849
# 18                           78  P202509297849
# 19                           48  P202509297849
# 20                           28  P202509297849
# 21                           28  P202509297849
# 22                           64  P202509297849
#             student_code  num_point_prosociality  num_point_14no  \
# 0   DC03142025602FCDA025                       4               4
# 1   DC03142025602FCDA024                       5               5
# 2   DC03142025602FCDA022                       6               7
# 3   DC03142025602FCDA021                      12               3
# 4   DC03142025602FCDA020                       9               8
# 5   DC03142025602FCDA019                       8               3
# 6   DC03142025602FCDA017                       7               4
# 7   DC03142025602FCDA016                       5               5
# 8   DC03142025602FCDA015                       9               5
# 9   DC03142025602FCDA014                       9               6
# 10  DC03142025602FCDA013                       4               4
# 11  DC03142025602FCDA012                       4               3
# 12  DC03142025602FCDA009                      10               4
# 13  DC03142025602FCDA008                       8               0
# 14  DC03142025602FCDA007                       7               3
# 15  DC03142025602FCDA006                       4               4
# 16  DC03142025602FCDA005                       7               2
# 17  DC03142025602FCDA004                       9               8
# 18  DC03142025602FCDA003                       7               7
# 19  DC03142025602FCDA002                       5               3
# 20  DC03142025602FCDA001                       9               2
#
#     prosociality*14no_num_point       psy_code
# 0                            16  P20250929B2C3
# 1                            25  P20250929B2C3
# 2                            42  P20250929B2C3
# 3                            36  P20250929B2C3
# 4                            72  P20250929B2C3
# 5                            24  P20250929B2C3
# 6                            28  P20250929B2C3
# 7                            25  P20250929B2C3
# 8                            45  P20250929B2C3
# 9                            54  P20250929B2C3
# 10                           16  P20250929B2C3
# 11                           12  P20250929B2C3
# 12                           40  P20250929B2C3
# 13                            0  P20250929B2C3
# 14                           21  P20250929B2C3
# 15                           16  P20250929B2C3
# 16                           14  P20250929B2C3
# 17                           72  P20250929B2C3
# 18                           49  P20250929B2C3
# 19                           15  P20250929B2C3
# 20                           18  P20250929B2C3

# %%
print(result_df)
# Out:
#                student_code  num_point_prosociality  num_point_14no  \
# 0   M1000000120253017C9D005                       4               2
# 1   M1000000120253017C9D004                       5               4
# 2   M1000000120253017C9D003                       5               3
# 3   M1000000120253017C9D002                       1               0
# 4   M1000000120253017C9D001                       1               1
# ..                      ...                     ...             ...
# 16     DC03142025602FCDA005                       7               2
# 17     DC03142025602FCDA004                       9               8
# 18     DC03142025602FCDA003                       7               7
# 19     DC03142025602FCDA002                       5               3
# 20     DC03142025602FCDA001                       9               2
#
#     prosociality*14no_num_point       psy_code
# 0                             8  P202507041AFF
# 1                            20  P202507041AFF
# 2                            15  P202507041AFF
# 3                             0  P202507041AFF
# 4                             1  P202507041AFF
# ..                          ...            ...
# 16                           14  P20250929B2C3
# 17                           72  P20250929B2C3
# 18                           49  P20250929B2C3
# 19                           15  P20250929B2C3
# 20                           18  P20250929B2C3
#
# [679 rows x 5 columns]

# %%
# s3에 업로드
wr.s3.to_csv(result_df, f's3://schoolfriends-bym/result/prosociality_point/prosociality_point_{pd.Timestamp.now().strftime("%Y%m%d_%H%M%S")}.csv', index=False)
# Out:
# {'paths': ['s3://schoolfriends-bym/result/prosociality_point/prosociality_point_20251001_153226.csv'],
#  'partitions_values': {}}

# %%
# s3_folder_macro 소스에서 크롤러 생성해서 테이블화
# 특정 크롤러 생성 및 실행
import boto3
# s3 폴더 별로 크롤러 만들어서 아테네 테이블 만들때
glue = boto3.client("glue", region_name="ap-northeast-2")

# 공통 파라미터
role_name = 'arn:aws:iam::932744610695:role/service-role/AWSGlueServiceRole-Schoolfriends'
database_name = 'schoolfriends'
bucket_name = 'schoolfriends-bym'

crawler_name = "crawler_prosociality_norms"
s3_target_path = f"s3://schoolfriends-bym/result/prosociality_norms/"

try:
    response = glue.create_crawler(
        Name=crawler_name,
        Role=role_name,
        DatabaseName=database_name,
        Targets={'S3Targets': [{'Path': s3_target_path}]},
        SchemaChangePolicy={
            'UpdateBehavior': 'LOG',
            'DeleteBehavior': 'LOG'
        }
    )
    print(f"Crawler '{crawler_name}' created successfully.")
except glue.exceptions.AlreadyExistsException:
    print(f"Crawler '{crawler_name}' already exists.")
except Exception as e:
    print(f"Error creating crawler '{crawler_name}': {e}")
# Out:
# Crawler 'crawler_prosociality_norms' created successfully.

# %%
# 크롤러 동작
response = glue.start_crawler(Name=crawler_name)
print(f"Crawler '{crawler_name}' started successfully.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # 크롤러 동작
# ----> 2 response = glue.start_crawler(Name=crawler_name)
#       3 print(f"Crawler '{crawler_name}' started successfully.")
#
# NameError: name 'glue' is not defined
