# %%
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoAlertPresentException
import pandas as pd
from datetime import datetime
import math
import re
import os
import csv

# %%
# 날짜 형식을 변환하는 함수 정의
def convert_date_format(date_str):
    pattern = r"(\d{4})(\d{2})(\d{2})"
    return re.sub(pattern, r"\1-\2-\3", date_str)

def load_and_preprocess_data(filepath):
    data = pd.read_excel(filepath)
    print("케이스의 수 : ", len(data))
    
    # 성별 전처리
    data.loc[data.iloc[:, 2] == '남', data.columns[2]] = 'M'
    data.loc[data.iloc[:, 2] == '여', data.columns[2]] = 'F'
    
    # NAME 텍스트 변환
    data['NAME'] = data['NAME'].astype(str)
    
   
    # 생년월일 전처리
    data['BIRTHDAY'] = data['BIRTHDAY'].astype(str)
    data['BIRTHDAY'] = data['BIRTHDAY'].apply(convert_date_format)
    data['BIRTHDAY'] = pd.to_datetime(data['BIRTHDAY'],format='%Y-%m-%d')
    
    # 검사일 컬럼 추가 및 오늘 날짜로 설정
    data.insert(5,'검사일', pd.to_datetime(datetime.today().strftime('%Y-%m-%d')))
    
    
    return data

# %%
def create_usertestingNo_list(driver, data):
    # 검사 실시 화면으로 전환
    window_handles = driver.window_handles
    print(window_handles)
    window_handle = window_handles[1]
    driver.switch_to.window(window_handle)
    print(window_handle)
        
    usertestingNo_list = []    
    
      # 파일이 존재하지 않으면 헤더 추가
    current_dir = os.getcwd()
    file_path = os.path.join(current_dir, 'usertestingNo_list.csv')
    if not os.path.exists(file_path):
        with open(file_path, mode='w', newline='') as file:
            writer = csv.writer(file)
            writer.writerow(["Row Number", "User Testing No"])  # 헤더 작성
    
    for row in range(len(data)):
        RESPONE = data.iloc[row, :].to_list()
        RESPONE = ["" if (isinstance(value, float) and math.isnan(value)) else value for value in RESPONE]
        time.sleep(1)   
            
        try:
            # 인적사항 입력
            print("실행 행 : ", row+1)
            print(RESPONE[1])
            
            #이름
            name_box = driver.find_element(By.ID, 'name')
            name_box.send_keys(RESPONE[1])
            
            # 성별 선택 - 라벨 클릭 방식
            label_index = 1 if RESPONE[2] == 'M' else 2
            radio_label = driver.find_element(By.XPATH, '//*[@id="firstTable"]/tbody/tr[5]/td/label[{}]'.format(label_index))
            radio_label.click()
        
            
            # 생년월일 클릭
            birthday_box = driver.find_element(By.ID, 'birthday')
            birthday_box.click()

            # 년 드롭다운 요소 선택
            dropdown_year = driver.find_element(By.CLASS_NAME, 'ui-datepicker-year')
            dropdown_year = Select(dropdown_year) # Select 객체 생성
            dropdown_year.select_by_visible_text("{}".format(RESPONE[4].strftime('%Y'))) # 옵션 선택

            # 월 드롭다운 요소 선택
            dropdown_month = driver.find_element(By.CLASS_NAME, 'ui-datepicker-month')
            dropdown_month = Select(dropdown_month) # Select 객체 생성
            dropdown_month.select_by_visible_text("{}".format(RESPONE[4].strftime('%#m월'))) # 옵션 선택

            # 일 클릭
            day_element = driver.find_element(By.XPATH, "//a[@class='ui-state-default' and text()='{}']".format(RESPONE[4].strftime('%#d')))
            day_element.click()


            
            # 지역
            dropdown_element = driver.find_element(By.ID, 'atRegionCd') # 드롭다운 요소 선택 
            dropdown = Select(dropdown_element) # Select 객체 생성
            dropdown.select_by_visible_text("{}".format(RESPONE[3]))
            
            # 다음
            next_box = driver.find_element(By.ID, 'submitBtn')
            next_box.click()
            time.sleep(1)
            
            # 검사실시
            next_box = driver.find_element(By.ID, 'formSubmitBtn')
            next_box.click()
            time.sleep(1)
            
            
            # 문항입력
            for Q_num in range(0, len(RESPONE[6:])):
                choice = '//*[@id="test-area"]/div/ul/li[{0}]/div[2]/ul/li[{1}]'.format(2 * Q_num + 1, RESPONE[6:][Q_num])
                choice = driver.find_element(By.XPATH, choice)
                actions = ActionChains(driver)
                actions.move_to_element(choice).perform()
                choice.click()

            # 온코 리스트화
            element = driver.find_element(By.XPATH, "//*[@id='userTestingNo']")
            value = element.get_attribute("value")
            usertestingNo_list.append(value)
            
            # 온코 csv 파일 기록
            with open(file_path, mode='a', newline='') as file:
                writer = csv.writer(file)
                writer.writerow([row+1, value])

            # 제출
            next_box = driver.find_element(By.XPATH, '//*[@id="test-control"]/div/div[3]/ul')
            next_box.click()
            next_box = driver.find_element(By.XPATH, '//*[@id="modal3"]/div/div[2]/a[2]')
            next_box.click()            
            time.sleep(1)
            next_box = driver.find_element(By.XPATH, '/html/body/div/div/div/div/div[3]/a[1]')
            next_box.click()
            time.sleep(1)
            driver.switch_to.alert.accept()
            time.sleep(1)
            
        except Exception as e:
            print(f"{row}행에서 오류 발생 : {e}. 코드 실행 종료.")
            raise
    
    return usertestingNo_list

# %%
def save_report(driver, usertestingNo_list):
    for onco in usertestingNo_list:
        # 결과보기 리스트업 화면 전환(초기 화면)
        window_handles = driver.window_handles
        window_handle = window_handles[0]
        driver.switch_to.window(window_handle)

        # 해당 온코의 결과보고서 팝업
        box = driver.find_element(By.XPATH, f'//*[@id="{onco}"]')
        actions = ActionChains(driver)
        actions.move_to_element(box).perform()
        box.click()

        # 해당 온코의 결과보고서 핸들 가져오기
        window_handles = driver.window_handles
        window_handle = window_handles[-1]
        driver.switch_to.window(window_handle)

        time.sleep(3)
        # 저장 버튼
        save_button = driver.find_element(By.XPATH, '//*[@id="OZViewer"]/div[1]/input[1]')
        save_button.click()

        # html 형식으로 저장(드롭다운)
        dropdown_element = driver.find_element(By.XPATH, '//*[@id="oztab_exportdlg_filetype"]')
        dropdown = Select(dropdown_element)
        dropdown.select_by_visible_text("Web Page(*.html)")

        # 저장 클릭
        save_confirm = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/button[2]/span')
        save_confirm.click()

# %% [markdown]
# <span style="font-size:20px;">**첫번째, driver=initialize_driver() 실행**</span>
#
# 로그인->자동응답하고자 하는 검사 검사 선택->검사 실시 초기화면(ex 버전선택 등)
#
# <img src="attachment:3efd778d-fbef-46d7-9771-cb9154c5f0e6.png" alt="description" width="500" height="300">

# %%
pip install webdriver-manager
# Out:
# Requirement already satisfied: webdriver-manager in c:\users\user\anaconda3\lib\site-packages (4.0.2)
# Requirement already satisfied: requests in c:\users\user\anaconda3\lib\site-packages (from webdriver-manager) (2.32.3)
# Requirement already satisfied: python-dotenv in c:\users\user\anaconda3\lib\site-packages (from webdriver-manager) (0.21.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from webdriver-manager) (23.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests->webdriver-manager) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service

# ChromeDriver를 자동으로 업데이트하고 실행
def start_browser():
    # ChromeDriverManager를 통해 ChromeDriver 설치 및 관리
    service = Service(ChromeDriverManager().install())
    
    # Chrome 웹 드라이버를 설정
    options = webdriver.ChromeOptions()
    driver = webdriver.Chrome(service=service, options=options)
    
    return driver

# 예시: 브라우저 열기
driver = start_browser()
driver.get('https://inpsyt.co.kr/psy/onlineCodeSum/list')

# %% [markdown]
# <span style="font-size:20px;">**두번째, data=load_and_preprocess_data 실행**</span>
#
# 케이스가 담겨 있는 엑셀 파일 불러오기(경로 확인 필수), 전처리

# %%
data=load_and_preprocess_data("C:/Users/USER/Desktop/Inspection/PASHE.xlsx")
pd.set_option('display.max_rows', 20)   # 항상 10개만 출력
pd.set_option('display.max_columns', 20)
data
# Out:
# 케이스의 수 :  228
#     Unnamed: 0  NAME SEX   REGION   BIRTHDAY        검사일  Q1  Q2  Q3  Q4  ...  \
# 0         V1.0    C1   M      경기도 2005-03-12 2025-06-17   1   1   1   3  ...
# 1         V1.0    C4   M    인천광역시 2001-03-06 2025-06-17   2   2   2   3  ...
# 2         V1.0    C6   M    부산광역시 2004-10-21 2025-06-17   2   1   2   2  ...
# 3         V1.0   C12   M    서울특별시 2001-11-11 2025-06-17   2   2   2   3  ...
# 4         V1.0   C13   M     경상남도 2007-05-26 2025-06-17   1   2   3   2  ...
# ..         ...   ...  ..      ...        ...        ...  ..  ..  ..  ..  ...
# 223       V1.0   C39   M    인천광역시 2002-10-06 2025-06-17   3   1   1   2  ...
# 224       V1.0  C151   M      경기도 1995-06-18 2025-06-17   1   3   3   2  ...
# 225       V1.0  C152   M    광주광역시 1998-11-03 2025-06-17   3   1   3   1  ...
# 226       V1.0  C153   M    대구광역시 1997-08-15 2025-06-17   1   1   3   3  ...
# 227       V1.0  C154   M  제주특별자치도 1997-11-17 2025-06-17   3   2   1   1  ...
#
#      Q241  Q242  Q243  Q244  Q245  Q246  Q247  Q248  Q249  Q250
# 0       3     1     3     3     3     3     3     3     2     3
# 1       2     3     3     1     3     3     1     1     1     2
# 2       2     1     1     3     1     3     3     2     2     2
# 3       2     3     3     1     3     3     1     1     1     2
# 4       2     1     3     1     2     1     2     2     1     3
# ..    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 223     3     2     3     3     3     1     3     1     1     1
# 224     2     1     3     2     1     2     3     1     3     3
# 225     1     1     1     3     3     2     3     2     2     2
# 226     2     2     1     1     3     1     2     3     3     3
# 227     1     2     3     1     3     3     3     3     1     1
#
# [228 rows x 256 columns]

# %% [markdown]
# <span style="font-size:20px;">**세번째, usertestingNo_list=create_usertestingNo_list(driver, data) 실행**</span>
#
# 케이스 엑셀 파일로 자동응답 실시하면서 해당 usertesting no 리스트화

# %%
usertestingNo_list=create_usertestingNo_list(driver, data)
# Out:
# ['D4A62A89F982909EF626555CA153DCB5', 'EBAC837D014F124E86915F46A6D6AFED']
# EBAC837D014F124E86915F46A6D6AFED
# 실행 행 :  1
# C1
# 실행 행 :  2
# C4
# 실행 행 :  3
# C6
# 실행 행 :  4
# C12
# 실행 행 :  5
# C13
# 실행 행 :  6
# C16
# 실행 행 :  7
# C17
# 실행 행 :  8
# C19
# 실행 행 :  9
# C21
# 실행 행 :  10
# C22
# 실행 행 :  11
# C23
# 실행 행 :  12
# C24
# 실행 행 :  13
# C25
# 실행 행 :  14
# C26
# 실행 행 :  15
# C34
# 실행 행 :  16
# C35
# 실행 행 :  17
# C45
# 실행 행 :  18
# C48
# 실행 행 :  19
# C58
# 실행 행 :  20
# C59
# 실행 행 :  21
# C63
# 실행 행 :  22
# C64
# 실행 행 :  23
# C66
# 실행 행 :  24
# C68
# 실행 행 :  25
# C70
# 실행 행 :  26
# C74
# 실행 행 :  27
# C75
# 실행 행 :  28
# C77
# 실행 행 :  29
# C78
# 실행 행 :  30
# C80
# 실행 행 :  31
# C81
# 실행 행 :  32
# C83
# 실행 행 :  33
# C84
# 실행 행 :  34
# C86
# 실행 행 :  35
# C88
# 실행 행 :  36
# C89
# 실행 행 :  37
# C90
# 실행 행 :  38
# C92
# 실행 행 :  39
# C93
# 실행 행 :  40
# C97
# 실행 행 :  41
# C98
# 실행 행 :  42
# C99
# 실행 행 :  43
# C100
# 실행 행 :  44
# C104
# 실행 행 :  45
# C105
# 실행 행 :  46
# C106
# 실행 행 :  47
# C107
# 실행 행 :  48
# C110
# 실행 행 :  49
# C111
# 실행 행 :  50
# C115
# 실행 행 :  51
# C119
# 실행 행 :  52
# C122
# 실행 행 :  53
# C123
# 실행 행 :  54
# C124
# 실행 행 :  55
# C125
# 실행 행 :  56
# C126
# 실행 행 :  57
# C128
# 실행 행 :  58
# C129
# 실행 행 :  59
# C132
# 실행 행 :  60
# C138
# 실행 행 :  61
# C140
# 실행 행 :  62
# C143
# 실행 행 :  63
# C144
# 실행 행 :  64
# C149
# 실행 행 :  65
# C158
# 실행 행 :  66
# C160
# 실행 행 :  67
# C161
# 실행 행 :  68
# C163
# 실행 행 :  69
# C166
# 실행 행 :  70
# C167
# 실행 행 :  71
# C169
# 실행 행 :  72
# C170
# 실행 행 :  73
# C171
# 실행 행 :  74
# C173
# 실행 행 :  75
# C174
# 실행 행 :  76
# C179
# 실행 행 :  77
# C183
# 실행 행 :  78
# C187
# 실행 행 :  79
# C189
# 실행 행 :  80
# C190
# 실행 행 :  81
# C191
# 실행 행 :  82
# C192
# 실행 행 :  83
# C195
# 실행 행 :  84
# C199
# 실행 행 :  85
# C200
# 실행 행 :  86
# C202
# 실행 행 :  87
# C203
# 실행 행 :  88
# C206
# 실행 행 :  89
# C207
# 실행 행 :  90
# C209
# 실행 행 :  91
# C210
# 실행 행 :  92
# C211
# 실행 행 :  93
# C218
# 실행 행 :  94
# C220
# 실행 행 :  95
# C222
# 실행 행 :  96
# C226
# 실행 행 :  97
# C230
# 실행 행 :  98
# C231
# 실행 행 :  99
# C232
# 실행 행 :  100
# C233
# 실행 행 :  101
# C234
# 실행 행 :  102
# C235
# 실행 행 :  103
# C241
# 실행 행 :  104
# C245
# 실행 행 :  105
# C246
# 실행 행 :  106
# C248
# 실행 행 :  107
# C251
# 실행 행 :  108
# C253
# 실행 행 :  109
# C256
# 실행 행 :  110
# C257
# 실행 행 :  111
# C258
# 실행 행 :  112
# C261
# 실행 행 :  113
# C265
# 실행 행 :  114
# C266
# 실행 행 :  115
# C267
# 실행 행 :  116
# C268
# 실행 행 :  117
# C269
# 실행 행 :  118
# C274
# 실행 행 :  119
# C275
# 실행 행 :  120
# C278
# 실행 행 :  121
# C279
# 실행 행 :  122
# C280
# 실행 행 :  123
# C281
# 실행 행 :  124
# C282
# 실행 행 :  125
# C284
# 실행 행 :  126
# C285
# 실행 행 :  127
# C287
# 실행 행 :  128
# C288
# 실행 행 :  129
# C293
# 실행 행 :  130
# C294
# 실행 행 :  131
# C297
# 실행 행 :  132
# C298
# 실행 행 :  133
# C299
# 실행 행 :  134
# C300
# 실행 행 :  135
# C301
# 실행 행 :  136
# C302
# 실행 행 :  137
# C305
# 실행 행 :  138
# C306
# 실행 행 :  139
# C307
# 실행 행 :  140
# C308
# 실행 행 :  141
# C309
# 실행 행 :  142
# C311
# 실행 행 :  143
# C313
# 실행 행 :  144
# C314
# 실행 행 :  145
# C316
# 실행 행 :  146
# C317
# 실행 행 :  147
# C320
# 실행 행 :  148
# C321
# 실행 행 :  149
# C322
# 실행 행 :  150
# C323
# 실행 행 :  151
# C324
# 실행 행 :  152
# C325
# 실행 행 :  153
# C329
# 실행 행 :  154
# C334
# 실행 행 :  155
# C335
# 실행 행 :  156
# C336
# 실행 행 :  157
# C337
# 실행 행 :  158
# C338
# 실행 행 :  159
# C340
# 실행 행 :  160
# C341
# 실행 행 :  161
# C344
# 실행 행 :  162
# C345
# 실행 행 :  163
# C348
# 실행 행 :  164
# C349
# 실행 행 :  165
# C350
# 실행 행 :  166
# C353
# 실행 행 :  167
# C354
# 실행 행 :  168
# C357
# 실행 행 :  169
# C368
# 실행 행 :  170
# C373
# 실행 행 :  171
# C376
# 실행 행 :  172
# C377
# 실행 행 :  173
# C378
# 실행 행 :  174
# C381
# 실행 행 :  175
# C382
# 실행 행 :  176
# C383
# 실행 행 :  177
# C384
# 실행 행 :  178
# C389
# 실행 행 :  179
# C390
# 실행 행 :  180
# C392
# 실행 행 :  181
# C393
# 실행 행 :  182
# C394
# 실행 행 :  183
# C395
# 실행 행 :  184
# C397
# 실행 행 :  185
# C399
# 실행 행 :  186
# C400
# 실행 행 :  187
# C403
# 실행 행 :  188
# C405
# 실행 행 :  189
# C406
# 실행 행 :  190
# C407
# 실행 행 :  191
# C410
# 실행 행 :  192
# C411
# 실행 행 :  193
# C413
# 실행 행 :  194
# C414
# 실행 행 :  195
# C416
# 실행 행 :  196
# C419
# 실행 행 :  197
# C421
# 실행 행 :  198
# C426
# 실행 행 :  199
# C427
# 실행 행 :  200
# C429
# 실행 행 :  201
# C430
# 실행 행 :  202
# C431
# 실행 행 :  203
# C433
# 실행 행 :  204
# C436
# 실행 행 :  205
# C437
# 실행 행 :  206
# C438
# 실행 행 :  207
# C440
# 실행 행 :  208
# C442
# 실행 행 :  209
# C445
# 실행 행 :  210
# C446
# 실행 행 :  211
# C447
# 실행 행 :  212
# C449
# 실행 행 :  213
# C450
# 실행 행 :  214
# C451
# 실행 행 :  215
# C452
# 실행 행 :  216
# C453
# 실행 행 :  217
# C454
# 실행 행 :  218
# C455
# 실행 행 :  219
# C456
# 실행 행 :  220
# C460
# 실행 행 :  221
# C36
# 실행 행 :  222
# C37
# 실행 행 :  223
# C38
# 실행 행 :  224
# C39
# 실행 행 :  225
# C151
# 실행 행 :  226
# C152
# 실행 행 :  227
# C153
# 실행 행 :  228
# C154

# %%
usertestingNo_list
# Out:
# ['723f660af264402e9820',
#  'a1ebbd9e4b1c45d9a950',
#  '240503b9bb534fa2aaf3',
#  '5c26789e8a324a5bb83a',
#  '8b50058e07324d359f1c',
#  '4625995eee004c9da1f8',
#  'c3653c7c34fa45f28175',
#  'd21d0eb05ed743378d13',
#  '116e0818692342ecbcda',
#  '310cfdf45ff84f38915b',
#  '967da11de7ea4d8086ea',
#  '3398a69cddc547eda971',
#  '0af5efc4fa62485d912f',
#  'feecee0659614217943e',
#  '6a50315f3bfd44939721',
#  '02c03090c554496e83e4',
#  '4ee880d9654b4f90ab4b',
#  '431ef6d4bcfa4e739f62',
#  '5d05decac07548848cd0',
#  'b69caea36cf2401d9c18',
#  'b51155529d5a430ebb59',
#  '33b800e7cf2b4f9f90f2',
#  '2a9e3066745b460cb0b1',
#  'cdf1409fba414b32b4e7',
#  '39a37a83ad584bf3b88c',
#  '2c56111f64d74d5daed8',
#  '0698e205120c402599dc',
#  '99d3a7564e3f4286ac06',
#  'c7e250dc6b604e0a98e8',
#  '44804156b83c4baea364',
#  '0e19d2077ec84765a101',
#  '76b67575441a46c3839c',
#  '5a4c141750ee4dedace0',
#  'c29d9dabfb624e789882',
#  '39f9609f0cd74da38c85',
#  '63e142c7dea5447588ff',
#  'cd07260adae44e97a15a',
#  '9d3cfe3f92e5470b9b21',
#  'd2aad96281334abd9458',
#  'aeb59014bf9e4104b4a5',
#  'bd9865927d634ad993f7',
#  'd3fe533f334c400f8186',
#  '3b8ed36501e54087b722',
#  'a62d2fd96b214e13b446',
#  'f785eaca883b404d8ec7',
#  '0945f2664d774411b6d2',
#  'a8bebe23897b491981b0',
#  'a962a98849884347ba94',
#  '6163fb465c884cde877c',
#  'b1da3cee96c74a48af17',
#  '9360c9db9d6d4630a458',
#  '14458fd32d0041688741',
#  'db7cd6691b464ce2a715',
#  '6ef72f545adb4f249dfd',
#  '419da2bacc59499b8d64',
#  '4fed5ea890e543bbaf7c',
#  '53fee19e1dfb45b385c2',
#  'a9c93b1e8c6b4c078807',
#  '47920e8d19bf4d208ddc',
#  'd765cb551f9f40a88153',
#  'bfaf70d495c74585b101',
#  '88553d50ca274d2898c6',
#  '9f059263aea54586a527',
#  '3c4daad1a2f84e13a282',
#  '99da6f284423403197bf',
#  '2e8dc5415ed04ed4b3a2',
#  'ac01443bb68346e8a0cd',
#  '9dadff98783f4d0cbf8b',
#  'd04470c537d84a878dcf',
#  '50bba5908dae4428a7ee',
#  '55f68c6879a34e25a892',
#  '91e1e4c362fe462e84b0',
#  'bbe8938c60e74cfd8d4d',
#  '08f158bfab2e41b8ba49',
#  '51295b69b0314b639406',
#  '97e8e7df2e9c427382e5',
#  '69b56c03b7be4b539ba2',
#  '57583a2b01e94edd8c6a',
#  '0a0718b084d44cacacaa',
#  '7cabbb335a594d65aef2',
#  '6d0b8b42a08645a59e7e',
#  '0f6263e77a7f4801a9b6',
#  '57b9fb8698094fad94d4',
#  '6c0ed1d1afbc4a5c8a68',
#  '8aed8cbfe9d947888259',
#  'd9a658b7b5b140d4a891',
#  '349e5e57008b45168f1e',
#  '220f451b6761457796dc',
#  '2f395c09ae1a443794c2',
#  '53cdabb11d434fb6a887',
#  '845added15074432b040',
#  '164926baef674739ac63',
#  '66a39aa924aa4617887a',
#  '2368026876344b88a818',
#  'e380481f797345bbad48',
#  'd4ae2b351a114799aadf',
#  'f021762ab17b40c8b592',
#  '168935688e2a4694801d',
#  '7811294bb0b54972b1d7',
#  '5d6e64045aaa400ba568',
#  '9d88f40466ce46278c0a',
#  '9810fdefc65047c6b37b',
#  'f70cf8bdc6c449958ed3',
#  '1ef7c2663a2d44b4a393',
#  'd7fdc6a80bc84bccacc0',
#  'd8125821fb3c46b48caa',
#  'e2746cc4ac4240d4b412',
#  'a6c8f94520bb48dcb8d7',
#  'cb137b2cfd0249bd8ba5',
#  '9be0cd7127fe4fc7b937',
#  'b8ddff768d804e73ad53',
#  'f86659884b76494d8581',
#  'ec1dea3be1354ebe831a',
#  'aad96fbb9a1a4a2b913d',
#  '614b8140d20040fb8e7f',
#  'f5b133a4b9194baabb0f',
#  'bb42ca15aac74a559b87',
#  '9898c4dcb7574b36a71a',
#  'e9b675c6838c41ab85dd',
#  'ad7f3c48c9ca4c5486aa',
#  'c717deea95f14fefa6d0',
#  'f33c9da8883e4c5c94c0',
#  'ba67f0abddef462b949a',
#  '4d8a2e7903dd4d4d885b',
#  'fd2244e98b4d486da1e0',
#  '2a2106bc8bcb4f03a2a6',
#  '5ef90a6c337f447dbd41',
#  '95a7fe308c104dfc929b',
#  '6ff51fb4eede4c3c8dff',
#  '62df835569f7444b901b',
#  'a5fe848ecfa349d7b90e',
#  'db2dc255a84d4aa8a61e',
#  'dc2dd97071474dda868d',
#  'e444e10e307244e09fbb',
#  'e5cda6826bd44b3bb2f3',
#  '91cd2fdf6e2449978301',
#  '847f2578b3394e10bb25',
#  'd0af37fb71a74f0e87cc',
#  '36372a8d948e46998bf8',
#  '0c79c86d3117443d82a8',
#  'e48c753e30a841f68e4f',
#  '63de39a2900942b2a75c',
#  '425cb7c2a0c54a87b51f',
#  '26bf64db03ff4ee6bab6',
#  'f59928b6dadf4dcaa319',
#  '1b2b60cd08264236ad0f',
#  '7abcaf1814b549069f1a',
#  '4ed8ac5805f748a18905',
#  'fcbf1e1523dc4153bfde',
#  '11801057165c4bf99a30',
#  '4ce3987406774b0794dd',
#  '8d88332052084285a11d',
#  'c0bc5b6f30dd457e99fd',
#  '49ef128b88f641de96ca',
#  '2f98af2a8b8d44f4b1a5',
#  'afde238114684f68b134',
#  'ea2ac6fee85f4e9a95f9',
#  '361469fd550f432999c6',
#  '6d659d28ed4147f9a823',
#  '2b1f69e5b26343199562',
#  '13a86f2bc9e64849a862',
#  '9e084b43ba3c4c8da45a',
#  '2b6afa233fb54228983b',
#  '7e2aedf5a34c470b9a61',
#  '8defe6748935485c99fa',
#  '1e42b72585514b6781c1',
#  'bb2303c637b8484fb229',
#  'cbf783300f6a44138a29',
#  '98bbd312c0014c1a8cb8',
#  '9c4cebbe464345518964',
#  'abc9bbb4d42245f1a80d',
#  'e07aa0ea5d1249a495a7',
#  '95f61aad052346f08092',
#  '88d083f6e8f443d7a42f',
#  'b4661b794d484589acab',
#  '6d982accc7c8456dab17',
#  '420ca9e51cef4f0b8243',
#  '8a258935a95b4639a28a',
#  '7d0904bf89de41bfbde5',
#  'd92b86d0985b49349032',
#  '3c154fcf75ac47809df3',
#  'beff08d2863f44b893c1',
#  'a6ffbd4550b54890bf57',
#  'd58caae136e94f1ca926',
#  'dbd556e9fbdf42d09599',
#  'b451f77b1efa438aa2d2',
#  '932ac1a5843f4876bfaa',
#  '64a9d62943554d26bae3',
#  '935611fe194842a3b187',
#  'dd359a7362df4f14bb3f',
#  '888ecb83784942f59689',
#  'e97975e471be4fc893fe',
#  '2a640d963bac4b15985e',
#  '2c32d4e1280440de82fb',
#  'f6947ceb29e84c3abec1',
#  'a3e77edd3fe242a2b38b',
#  'a9d2dcdf8da64dbeb6b7',
#  '07c0c9e3748d429b9d9b',
#  '6c4b726f28a541f2a1b2',
#  'b3f4bcfbddff4a379268',
#  '57cef8a9da2840a2a89b',
#  'dfe9812378394156b990',
#  '0c1df67b02aa4c3eb490',
#  '388525c3882f4d85ba5f',
#  '147cffdf31f94b96857d',
#  '857ecf466c304aba9ba2',
#  '7896f17635344ae8b526',
#  '0e032224c932488bada2',
#  '0c472d938d2d4fcb9127',
#  '072efc9615f74d3abdb6',
#  '7a68005785cf4cb6b546',
#  'ca89cc8c9e914c8ba0ac',
#  'be86ce607dd941ec8e47',
#  'eeacb0bb68234850a6f4',
#  'f973f190240a4d7abc3a',
#  '2ca6549e293142fdad56',
#  '6d3ce161893b4d789b3c',
#  'de5b0e37e3e04844b2ae',
#  'b41c4a089647447785ea',
#  'dd1f94e6186d416aaf24',
#  'eba37b007c8b48e38120',
#  '2b807db23724497da30a',
#  '3f03177b7e3d47018ffd',
#  '85ed7cc91af147c6b791',
#  '101688b445c44dbe8749',
#  '70f208a7d0c040f59578',
#  '05f7a84920fd4461b36d',
#  '5e07c5745e304016a61d']

# %%
# 중단되었을 때
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user\\Desktop\\Inspection'

# %% [markdown]
# <span style="font-size:20px;">**네번째, save_report(driver, usertestingNo_list) 실행**</span>
#
# <span style="color:red;">저장하고자 하는 검사 결과 목록 화면에서 목록 개수 최대화 하고 대기
#
# 자동응답 실시한 usertesting no 별로 결과보고서 html 형식으로 저장
#
# <img src="attachment:e44aaa4f-0cf8-4579-b73f-c67e07eb2f48.png" alt="description" width="500" height="300">

# %%
save_report(driver, usertestingNo_list)

# %% [markdown]
# <span style="font-size:20px;">**다섯번째, 하단 셀 실행**</span>
#
# <span style="color:red;">다운받아진 결과보고서(html) 모두 result_inspection 폴더에 이동
#
# 저장한 결과보고서를 크롤링하여 엑셀화
#
# 결과보고서가 어디에 저장되어 있는지 <span style="color:red;">directory = 'C:/Users/USER/Desktop/result_inspection'</span>
# 크롤링한 엑셀을 어디에 저장할지 <span style="color:red;">excel_path = 'C:/Users/USER/Desktop/result_inspection/PASHE_OZ_DATA.xlsx'</span>
# 어떤 검사를 크롤링할지 <span style="color:red;">html_pattern = '*PASHE*.html'</span>
# 건들지 마세요 <span style="color:red;">xpath = '//*[starts-with(@id, "f_") and contains(@id, "s0")]//nobr'</span>
#
# 잘 설정되어 있는지 확인

# %%
import selenium
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
import os
import glob
import pandas as pd
from selenium.webdriver.common.by import By

def find_html_files(directory, pattern):
    search_pattern = os.path.join(directory, pattern)
    html_files = glob.glob(search_pattern)
    re_html_files = [html_file.replace("\\", "/") for html_file in html_files]
    return re_html_files

def extract_data_from_html(html_file_path, driver, xpath):
    driver.get(html_file_path)
    elements = driver.find_elements(By.XPATH, xpath)
    if elements:
        return [element.text for element in elements]
    else:
        return []

def save_to_excel(dataframe, excel_path):
    dataframe.to_excel(excel_path, index=False)

def main(directory, excel_path, html_pattern, xpath):
    service = Service(ChromeDriverManager().install())
    # 브라우저 옵션
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # 브라우저를 백그라운드에서 실행
    driver = webdriver.Chrome(service=service, options=options)
    
    # HTML 파일 찾기
    html_files = find_html_files(directory, html_pattern)
    
    # 결과를 저장할 빈 데이터프레임
    result_df = pd.DataFrame()

    # 각 HTML 파일에서 데이터 추출
    for html_file_path in html_files:
        print(f"Processing file: {html_file_path}")
        values = extract_data_from_html('file:///' + html_file_path, driver, xpath)
        if values:
            df = pd.DataFrame([values])
            result_df = pd.concat([result_df, df], axis=0, ignore_index=True)
        else:
            print(f"No elements found in {html_file_path} with the given XPath.")
    
    # 브라우저 종료
    driver.quit()
    
    # 결과를 엑셀 파일로 저장
    save_to_excel(result_df, excel_path)
    print(f"Data saved to {excel_path}")

if __name__ == "__main__":
    # 메인 함수 인자 설정
    directory = 'C:/Users/USER/Desktop/result_inspection'
    excel_path = 'C:/Users/USER/Desktop/result_inspection/PASHE_OZ_DATA.xlsx'
    html_pattern = '*PASHE*.html'
    xpath = '//*[starts-with(@id, "f_") and contains(@id, "s0")]//nobr'
    
    main(directory, excel_path, html_pattern, xpath)
# Out:
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (1).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (10).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (100).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (11).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (12).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (13).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (14).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (15).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (16).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (17).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (18).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (19).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (2).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (20).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (21).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (22).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (23).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (24).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (25).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (26).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (27).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (28).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (29).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (3).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (30).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (31).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (32).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (33).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (34).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (35).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (36).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (37).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (38).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (39).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (4).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (40).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (41).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (42).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (43).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (44).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (45).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (46).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (47).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (48).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (49).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (5).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (50).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (51).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (52).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (53).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (54).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (55).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (56).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (57).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (58).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (59).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (6).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (60).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (61).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (62).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (63).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (64).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (65).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (66).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (67).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (68).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (69).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (7).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (70).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (71).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (72).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (73).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (74).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (75).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (76).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (77).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (78).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (79).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (8).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (80).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (81).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (82).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (83).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (84).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (85).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (86).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (87).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (88).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (89).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (9).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (90).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (91).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (92).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (93).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (94).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (95).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (96).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (97).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (98).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE (99).html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160617.632.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160622.226.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160626.808.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160631.396.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160635.933.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160640.489.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160645.192.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160649.824.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160654.439.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160659.059.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160703.595.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160708.184.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160712.836.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160717.417.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160722.036.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160726.709.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160731.323.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160735.898.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160740.557.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160745.217.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160749.797.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160754.486.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160759.044.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160803.622.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160808.251.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160812.774.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160817.285.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160821.854.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160826.526.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160831.062.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160835.543.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160840.210.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160844.780.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160849.264.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160853.722.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160858.220.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160902.802.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160907.234.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160911.772.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160916.276.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160920.866.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160925.462.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160930.019.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160934.708.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160939.387.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160944.015.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160948.666.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160953.224.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T160957.816.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161002.401.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161006.965.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161011.541.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161016.123.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161020.637.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161025.106.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161029.674.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161034.198.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161038.842.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161043.316.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161047.907.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161052.478.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161057.124.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161101.718.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161106.280.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161110.850.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161115.495.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161120.018.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161124.732.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161129.361.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161133.954.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161138.588.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161143.223.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161147.777.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161152.437.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161156.982.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161201.612.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161206.193.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161210.743.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161215.303.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161219.893.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161224.501.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161229.141.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161233.651.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161238.312.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161242.945.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161247.546.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161252.157.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161256.761.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161301.320.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161305.967.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161310.643.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161315.377.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161320.025.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161324.717.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161329.322.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161333.968.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161338.515.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161343.111.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161347.792.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161352.351.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161356.885.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161401.486.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161406.103.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161410.675.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161415.303.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161419.949.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161424.699.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161429.256.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161433.896.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161438.583.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161443.056.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161447.650.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161452.185.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161456.805.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161501.286.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161505.867.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161510.467.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161514.982.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161519.583.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161524.167.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161528.671.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161533.151.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161537.691.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161542.351.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161546.823.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161551.507.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE - 2025-06-17T161556.121.html
# Processing file: C:/Users/USER/Desktop/result_inspection/PASHE.html
# Data saved to C:/Users/USER/Desktop/result_inspection/PASHE_OZ_DATA.xlsx
