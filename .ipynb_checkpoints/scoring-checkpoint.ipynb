# %% [markdown]
# 채점해볼 수 있는 페이크 데이터 생성

# %%
# 지명 데이터 생성
# 지명 문항은 PN1-PN19까지 총 19문항
# 지명 문항 데이터 불러오기
import pandas as pd
import requests
from io import BytesIO
url = "https://github.com/Byumin/peer/raw/refs/heads/item/250217_item_scale_info.xlsx"
response = requests.get(url)
response.raise_for_status()
df = pd.read_excel(BytesIO(response.content))
df
# Out:
#               척도                    해당 문항 및 계산 방식          보고방식 인포그램 참고 페이지
# 0         지각된 인기                   PN1. 가장 인기가 있는          또래지명           1
# 1         사회적 선호                 PN2. 가장 같이 놀고 싶은          또래지명         NaN
# 2         사회적 선호                 PN3. 가장 같이 놀기 싫은          또래지명         NaN
# 3        외현적 공격성     PN4. 문제를 일으키는/학교의 규칙을 지키지 않는          또래지명         NaN
# 4        외현적 공격성                      PN5. 싸움을 하는          또래지명         NaN
# ..           ...                              ...           ...         ...
# 121  또래관계 교사 민감성  TR6. 이 아이는 친구를 괴롭히는 행동을 시작한다.    자기보고(5점 리커트)         NaN
# 122  또래관계 교사 민감성     TR7. 이 아이는 친구들에게 자주 놀림을 당한다.  자기보고(5점 리커트)         NaN
# 123  또래관계 교사 민감성                 TR8. 이 아이는 친절하다.  자기보고(5점 리커트)         NaN
# 124  또래관계 교사 민감성       TR9. 이 아이는 학교에서 잘하려고 노력한다.  자기보고(5점 리커트)         NaN
# 125  또래관계 교사 민감성   TR10. 이 아이는 수업 시간에 기분이 좋아 보인다.  자기보고(5점 리커트)         NaN
#
# [126 rows x 4 columns]

# %%
point_df = df['보고방식
